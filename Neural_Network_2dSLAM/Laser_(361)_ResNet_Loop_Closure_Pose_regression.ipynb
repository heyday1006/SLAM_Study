# %% [markdown]
# <a href="https://colab.research.google.com/github/heyday1006/2D-Lidar-DNN/blob/main/Laser_(361)_ResNet_Loop_Closure_Pose_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import os, re, math, json, shutil, pprint
import PIL.Image, PIL.ImageFont, PIL.ImageDraw
import IPython.display as display
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.4.1

# %% [markdown]
# # Section 1: Data Extraction

# %% [markdown]
# Data is saved to multiple csv files.

# %%
# !gdown --id 1kMnzpnvonfZg-WBuzCO9QXhCRFb-6KXG #174lnAK9zW-L-vI7BgQPc42mVcVo7VWuv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1kMnzpnvonfZg-WBuzCO9QXhCRFb-6KXG
# To: /content/pose0220.zip
# 1.43GB [00:15, 91.8MB/s]

# %%
import zipfile
dir_name='pose0220' #'data_pickle.zip'
local_zip = dir_name+'.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall(dir_name)
zip_ref.close()

# %%
# !pip3 install pickle5
# Out:
# Collecting pickle5
#   Downloading https://files.pythonhosted.org/packages/f7/4c/5c4dd0462c8d3a6bc4af500a6af240763c2ebd1efdc736fc2c946d44b70a/pickle5-0.0.11.tar.gz (132kB)
#      |████████████████████████████████| 133kB 16.0MB/s
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp37-cp37m-linux_x86_64.whl size=219249 sha256=f5775e17cd6348c122ff5a49cbb44a1e4fbdf107fca064d919ca10b8e19a7dbb
#   Stored in directory: /root/.cache/pip/wheels/a6/90/95/f889ca4aa8b0e0c7f21c8470b6f5d6032f0390a3a141a9a3bd
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11

# %%
import pickle5 as pickle
def read_from_pickle(dir_name,type_name):
  with open(dir_name+'/'+dir_name+'/'+type_name+'_range_pairs.pickle', 'rb') as handle:
      range_pairs_all = pickle.load(handle)

  with open(dir_name+'/'+dir_name+'/'+type_name+'_pose_rels.pickle', 'rb') as handle:
      pose_rels_all = pickle.load(handle)
  range_pairs = np.swapaxes(range_pairs_all, 1, 2)
  translation_rels=np.round(np.double(pose_rels_all[:,0:2]),4)
  rotation_rels=np.double(pose_rels_all[:,2])
  range_pairs = range_pairs[:,::2,:]
  range_pairs = range_pairs[:,90:451,:]
  print("for %s dataset",type_name)
  print("size of range_pairs: ", range_pairs.shape)
  print("size of pose_rels: ", translation_rels.shape)
  print("size of rotation_rels: ", rotation_rels.shape)
  print("<------------->")
  return range_pairs,translation_rels,rotation_rels

range_pairs,pose_rels,rotation_rels = read_from_pickle(dir_name,'train')
# Out:
# for %s dataset train
# size of range_pairs:  (147344, 361, 2)
# size of pose_rels:  (147344, 2)
# size of rotation_rels:  (147344,)
# <------------->

# %% [markdown]
# ## Remove inbalanced values

# %%
#too many zeros!!!
from numpy import linalg as LA
import math
# range_pairs = np.double(np.swapaxes(range_pairs_all, 1, 2))
# pose_rels=np.double(pose_rels_all[:,0:2])
# rotation_rels=np.double(pose_rels_all[:,2])

pose_rels_norm=LA.norm(pose_rels, axis=1)
nonzeros_indices=np.where((pose_rels_norm>1e-4) | (np.abs(rotation_rels)>1e-4))
nonfar_indices=np.where((rotation_rels<=1.0) & (rotation_rels>=-1.0) )
chosen_indices=np.intersect1d(nonzeros_indices,nonfar_indices)
pose_rels=pose_rels[chosen_indices]
rotation_rels=rotation_rels[chosen_indices]
range_pairs=range_pairs[chosen_indices]
print("size of pose_rels: ", pose_rels.shape)
# Out:
# size of pose_rels:  (127570, 2)

# %% [markdown]
# ## Convert to grid coordinates

# %%
print(min(pose_rels[:,0]),max(pose_rels[:,0]))
print(min(pose_rels[:,1]),max(pose_rels[:,1]))
#discretize the values
grid_offset=np.array([-1.8,-1.2])
grid_spacing=np.array([0.05,0.05])
grid_indices=np.round((np.array(pose_rels)-grid_offset)/grid_spacing)
pose_rels_grid=np.array(grid_indices)
print(np.shape(pose_rels_grid))
pose_rels_grid=pose_rels_grid.astype(int)
# Out:
# -1.7247 1.6685
# -0.9242 0.7726
# (127570, 2)

# %%
# with rotations
rotation_gridspace=0.5
rotation_rels=np.round(np.double(rotation_rels*180/math.pi),4)
rotation_rels_grid=np.array(np.round((np.array(rotation_rels)-np.array([-1.0*180/math.pi]))/rotation_gridspace))
rotation_rels_grid=rotation_rels_grid.astype(int)

# %% [markdown]
# ## Check discretized label distributions

# %% [markdown]
# Visualize the distribution of discretized values

# %%
pose_rels_1d=pose_rels_grid[:,0]*(np.max(pose_rels_grid[:,1])+1)+pose_rels_grid[:,1]
pose_rels_1d_bincount=np.bincount((pose_rels_1d).astype(int))
x_dim=np.int(np.max(pose_rels_grid[:,0])+1)
y_dim=np.int(np.max(pose_rels_grid[:,1])+1)
pose_rels_1d_bincount_full=np.zeros(x_dim*y_dim)
pose_rels_1d_bincount_full[:len(pose_rels_1d_bincount)]=pose_rels_1d_bincount
print(x_dim,y_dim,np.shape(pose_rels_1d_bincount))
pose_rels_2d_bincount=np.reshape(pose_rels_1d_bincount_full, [x_dim,-1], order='C')
#setup the 2D grid with Numpy
x_grid, y_grid = np.meshgrid(np.arange(-1.8,1.7,0.05), np.arange(-1.2,0.8,0.05))
#convert intensity (list of lists) to a numpy array for plotting
intensity = np.array(pose_rels_2d_bincount)
#now just plug the data into pcolormesh, it's that easy!
plt.pcolormesh(x_grid, y_grid, np.swapaxes(intensity,0,1))
plt.colorbar() #need a colorbar to show the intensity scale
plt.show() #boom
# Out:
# 70 40 (2786,)

# %%
#rotation
plt.hist(rotation_rels_grid,bins=20);

# %%
pose_rels_grid=pose_rels_1d
print(np.max(pose_rels_grid))
print(np.max(rotation_rels_grid))
# Out:
# 2785
# 229

# %% [markdown]
# ## Compressive Sensing

# %%
x=np.array([[1,2,3],[3,4,5]])
y=np.array([0,1])
mask = np.ones(x.shape,dtype=bool) #np.ones_like(a,dtype=bool)
mask[:,y] = False
x[mask] = 999
print(x)
# Out:
# [[  1   2 999]
#  [  3   4 999]]

# %%
import random
# Flag_compression=False
# if Flag_compression:
#   percent_compresed=0.1
#   indices_pre=np.array(random.sample(range(1,539),np.int(1079*percent_compresed/2)))
#   indices_pre=np.append(2*indices_pre,2*indices_pre+1)
#   print(np.shape(indices_pre))
#   indices=np.array(np.append(1,np.sort(indices_pre),1081))
#   range_pairs_compressed=np.array(range_pairs.copy())#=range_pairs[:,indices,:]
#   mask=np.ones(range_pairs_compressed.shape,dtype=bool)
#   mask[:,indices,:]=False
#   range_pairs_compressed[mask]=0
# else:
#   range_pairs_compressed=range_pairs

#   print("size of range_pairs_compressed: ", range_pairs_compressed.shape)
Flag_compression=True
Karaman_method = False
def laser_compression(range_pairs,Flag_compression,Karaman_method):
  if Flag_compression:
    percent_compressed=0.5
    range_pairs_compressed=np.array(range_pairs.copy())#=range_pairs[:,indices,:]
    mask=np.ones(range_pairs_compressed.shape,dtype=bool)
    if Karaman_method:
      indices_pre=np.array(random.sample(range(1,539),np.int(1079*percent_compresed/2)))
      indices_pre=np.append(2*indices_pre,2*indices_pre+1)
      print(np.shape(indices_pre))
      indices=np.array(np.append(1,np.sort(indices_pre),1081))
      mask[:,indices,:]=False
    else:
      # for irow in range(2):
        for isample in range(range_pairs_compressed.shape[0]):
          indices=np.random.choice(range(361),np.int(361*percent_compressed))
          # print(indices)
          mask[isample,indices,:]=False
    range_pairs_compressed[mask]=0
    range_pairs_compressed = np.concatenate((range_pairs_compressed,np.double(mask[:,:,0])[:,:,np.newaxis]),axis=-1)
  else:
    range_pairs_compressed=range_pairs

  print("size of range_pairs_compressed: ", range_pairs_compressed.shape)
  return range_pairs_compressed
range_pairs_compressed = laser_compression(range_pairs,Flag_compression,Karaman_method)
# Out:
# size of range_pairs_compressed:  (127570, 361, 3)

# %%
plt.figure(1)
plt.subplot(211)
plt.scatter([range(361)], [range_pairs[500,:,1]], s=0.1, label="original")
plt.subplot(212)
plt.scatter([range(361)], [range_pairs_compressed[500,:,1]], s=0.1, label="compressive")
# if Flag_compression:
#   for xc in indices:
#     plt.axvline(x=xc,c='r',linewidth=0.1,linestyle='-.')
    
plt.show()

# %% [markdown]
# # Section 2: Data Preparation

# %%
from sklearn.utils import shuffle
#pose_rels_grid_all=np.hstack((np.expand_dims(pose_rels_grid, axis=1),np.expand_dims(rotation_rels, axis=1)))
pose_rels_value_all=np.hstack((pose_rels,np.expand_dims(rotation_rels, axis=1)))
#print(np.shape(range_pairs_compressed),np.shape(pose_rels_grid),np.shape(rotation_rels_grid),np.shape(pose_rels_grid_all),np.shape(pose_rels_all))
xs, ys, ys_ground_truth = shuffle(range_pairs_compressed, pose_rels_value_all, pose_rels_value_all) #shuffling the dataset
xs=np.clip(xs, a_min=None, a_max=40)    #remove the inf value of range to a large number

percent_of_trainSet=0.99*0.85
percent_of_validationSet=0.99*0.15
percent_of_testSet=0.01
num_of_trainSet=np.int(ys.shape[0]*percent_of_trainSet)
num_of_validationSet=np.int(ys.shape[0]*percent_of_validationSet)
num_of_testSet=np.int(ys.shape[0]*percent_of_testSet)

x_training = np.array(xs[0:num_of_trainSet], dtype=float)
y_training = np.array(ys[0:num_of_trainSet], dtype=float)
y_training_ground_truth = np.array(ys_ground_truth[0:num_of_trainSet], dtype=float)
print('Size of training data: ', x_training.shape)
print('Size of training labels: ',y_training.shape)

x_validation = np.array(xs[num_of_trainSet:num_of_trainSet+num_of_validationSet], dtype=float)
y_validation = np.array(ys[num_of_trainSet:num_of_trainSet+num_of_validationSet], dtype=float)
y_validation_ground_truth = np.array(ys_ground_truth[num_of_trainSet:num_of_trainSet+num_of_validationSet], dtype=float)
print('Size of validation data: ', x_validation.shape)
print('Size of validation labels: ',y_validation.shape)

x_testing = np.array(xs[num_of_trainSet+num_of_validationSet:], dtype=float)
y_testing = np.array(ys[num_of_trainSet+num_of_validationSet:], dtype=float)
y_testing_ground_truth=np.array(ys_ground_truth[num_of_trainSet+num_of_validationSet:], dtype=float)
print('Size of testing data: ', x_testing.shape)
print('Size of testing labels: ',y_testing.shape)
# Out:
# Size of training data:  (107350, 361, 3)
# Size of training labels:  (107350, 3)
# Size of validation data:  (18944, 361, 3)
# Size of validation labels:  (18944, 3)
# Size of testing data:  (1276, 361, 3)
# Size of testing labels:  (1276, 3)

# %% [markdown]
# # Section 3: Model Traning

# %%
BATCH_SIZE = 32
training_dataset = tf.data.Dataset.from_tensor_slices((x_training,(y_training[:,0:2],y_training[:,2]))).batch(BATCH_SIZE)#
validation_dataset = tf.data.Dataset.from_tensor_slices((x_validation, (y_validation[:,0:2],y_validation[:,2]))).batch(BATCH_SIZE)

# %%
from tensorflow.keras.layers import Input, Conv1D, Activation, MaxPooling1D, Add, AveragePooling1D, Dense, Dropout, Flatten
from tensorflow.keras import Model
def residual_block(x):
      temp = x
      x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(x)
      x = Conv1D(filters=64, kernel_size=3, padding='same')(x)
      x = Add()([Activation('relu')(x), temp])
      return x

class SoftArgmax(tf.keras.layers.Layer):
    def __init__(self, name):
        super(SoftArgmax, self).__init__()
        self._name = name
    
    def call(self, input):
        # range
        x = input
        input_size=tf.shape(input)
        pos = tf.convert_to_tensor(range(input_size[1]),dtype=tf.float32)
        x *= pos
        x = tf.reduce_sum(x, axis=1, keepdims=True)
        return x

def Res1DFlat(dropout_rate,input_shape):
  # input size = (batch_size, 2, 1081)
  input_data = Input(shape=input_shape)
  #x = Dense(1024, activation='relu')(1081)
  # first resnet block
  x = Conv1D(filters=64, kernel_size=7, strides=3, activation='relu', padding='same')(input_data)
  x = MaxPooling1D(pool_size=3)(x)
  x=residual_block(x)
  # second resnet block
  x=residual_block(x)
  # third resnet block
  x=residual_block(x)
  # fourth resnet block
  x=residual_block(x)
  # fifth resnet block
  x=residual_block(x)

  # Average pooling
  x = AveragePooling1D(pool_size=7)(x)
  x = Flatten()(x) # (batch_size, 2, channel)

  # Dense Layers
  x = Dense(1024, activation='relu')(x)
  x = Dropout(dropout_rate)(x)
  x = Dense(1024, activation='relu')(x)
  x = Dropout(dropout_rate)(x)

  x1 = Dense(512, activation='relu')(x)
  x1 = Dropout(dropout_rate)(x1)
  #output1 = Dense(2786, activation='softmax', name='pose')(x1)
  output1 = Dense(2, activation=None, name='pose')(x1)

  x2 = Dense(512, activation='relu')(x)
  x2 = Dropout(dropout_rate)(x2)
  output2 = Dense(1, activation=None,name='rotation')(x2)
  #x2 = Dense(230, activation='softmax')(x2)
  #output2 = SoftArgmax(name='rotation')(x2,10)#Dense(230, activation='softmax', name='rotation')(x2)

  model = Model(inputs=input_data, outputs=[output1, output2])
  return model

# %% [markdown]
# check if the soft-argmax function is working

# %%
x = tf.convert_to_tensor([[0.2, 0.3, 0.5],[0.1,0.3,0.6]])
#x = tf.nn.softmax(x)
x = SoftArgmax(name='trial')(x)
x
# Out:
# <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[1.3],
#        [1.5]], dtype=float32)>

# %%
import tensorflow.keras.backend as kb
from tensorflow.keras.losses import MSE
from tensorflow import stack,argmax,cast

dropout_rate=0.2
optimizer_lr=0.001
model = Res1DFlat(dropout_rate,np.shape(x_training[0]))
optimizer = tf.keras.optimizers.Adam(optimizer_lr)
model.compile(optimizer=optimizer,
              loss={"pose": keras.losses.mse, "rotation": keras.losses.mse},#sparse_categorical_crossentropy,losses.mse},
              loss_weights=[10.0, 0.05],
              metrics={"pose": tf.keras.metrics.MeanAbsoluteError(), "rotation": tf.keras.metrics.MeanAbsoluteError()})#SparseCategoricalAccuracy,MeanAbsoluteError()})
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 361, 3)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 121, 64)      1408        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 40, 64)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 40, 64)       12352       max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 40, 64)       12352       conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 40, 64)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 40, 64)       0           activation[0][0]
#                                                                  max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 40, 64)       12352       add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 40, 64)       12352       conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 40, 64)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 40, 64)       0           activation_1[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 40, 64)       12352       add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 40, 64)       12352       conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 40, 64)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 40, 64)       0           activation_2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 40, 64)       12352       add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 40, 64)       12352       conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 40, 64)       0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 40, 64)       0           activation_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 40, 64)       12352       add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 40, 64)       12352       conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 40, 64)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 40, 64)       0           activation_4[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# average_pooling1d (AveragePooli (None, 5, 64)        0           add_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         328704      flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         1049600     dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          524800      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# pose (Dense)                    (None, 2)            1026        dropout_2[0][0]
# __________________________________________________________________________________________________
# rotation (Dense)                (None, 1)            513         dropout_3[0][0]
# ==================================================================================================
# Total params: 2,554,371
# Trainable params: 2,554,371
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# lr decay function
def lr_decay(epoch):
  return 0.001 * math.pow(0.9, np.floor(epoch/5))
# lr schedule callback
lr_decay_callback = tf.keras.callbacks.LearningRateScheduler(lr_decay, verbose=True)

EPOCHS=100
early_stopper = tf.keras.callbacks.EarlyStopping(monitor='val_pose_mean_absolute_error', mode='min', patience=7, restore_best_weights=True, verbose=1)
model.fit(training_dataset, validation_data=validation_dataset, epochs=EPOCHS, callbacks=[early_stopper,lr_decay_callback])
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 39s 7ms/step - loss: 13.7256 - pose_loss: 0.3538 - rotation_loss: 203.7589 - pose_mean_absolute_error: 0.2645 - rotation_mean_absolute_error: 9.0435 - val_loss: 4.5361 - val_pose_loss: 0.0949 - val_rotation_loss: 71.7356 - val_pose_mean_absolute_error: 0.1781 - val_rotation_mean_absolute_error: 4.7529
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 4.5408 - pose_loss: 0.0875 - rotation_loss: 73.3195 - pose_mean_absolute_error: 0.1722 - rotation_mean_absolute_error: 4.9211 - val_loss: 2.8651 - val_pose_loss: 0.0633 - val_rotation_loss: 44.6412 - val_pose_mean_absolute_error: 0.1399 - val_rotation_mean_absolute_error: 3.5669
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 3.0345 - pose_loss: 0.0681 - rotation_loss: 47.0722 - pose_mean_absolute_error: 0.1484 - rotation_mean_absolute_error: 3.9089 - val_loss: 2.3080 - val_pose_loss: 0.0514 - val_rotation_loss: 35.8747 - val_pose_mean_absolute_error: 0.1250 - val_rotation_mean_absolute_error: 3.2489
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 23s 7ms/step - loss: 2.3983 - pose_loss: 0.0571 - rotation_loss: 36.5363 - pose_mean_absolute_error: 0.1351 - rotation_mean_absolute_error: 3.4299 - val_loss: 2.1912 - val_pose_loss: 0.0492 - val_rotation_loss: 33.9801 - val_pose_mean_absolute_error: 0.1229 - val_rotation_mean_absolute_error: 3.2183
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 2.0237 - pose_loss: 0.0504 - rotation_loss: 30.3971 - pose_mean_absolute_error: 0.1264 - rotation_mean_absolute_error: 3.1560 - val_loss: 1.7335 - val_pose_loss: 0.0442 - val_rotation_loss: 25.8229 - val_pose_mean_absolute_error: 0.1135 - val_rotation_mean_absolute_error: 2.9196
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 1.6200 - pose_loss: 0.0438 - rotation_loss: 23.6356 - pose_mean_absolute_error: 0.1173 - rotation_mean_absolute_error: 2.8317 - val_loss: 1.6148 - val_pose_loss: 0.0372 - val_rotation_loss: 24.8538 - val_pose_mean_absolute_error: 0.1041 - val_rotation_mean_absolute_error: 2.8050
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 1.5553 - pose_loss: 0.0411 - rotation_loss: 22.8958 - pose_mean_absolute_error: 0.1138 - rotation_mean_absolute_error: 2.7562 - val_loss: 1.0520 - val_pose_loss: 0.0281 - val_rotation_loss: 15.4178 - val_pose_mean_absolute_error: 0.0886 - val_rotation_mean_absolute_error: 2.1714
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 1.3559 - pose_loss: 0.0362 - rotation_loss: 19.8720 - pose_mean_absolute_error: 0.1071 - rotation_mean_absolute_error: 2.5896 - val_loss: 0.9939 - val_pose_loss: 0.0285 - val_rotation_loss: 14.1840 - val_pose_mean_absolute_error: 0.0912 - val_rotation_mean_absolute_error: 2.1716
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 1.0869 - pose_loss: 0.0320 - rotation_loss: 15.3364 - pose_mean_absolute_error: 0.1011 - rotation_mean_absolute_error: 2.3699 - val_loss: 1.7742 - val_pose_loss: 0.0427 - val_rotation_loss: 26.9365 - val_pose_mean_absolute_error: 0.1160 - val_rotation_mean_absolute_error: 2.9242
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 1.1118 - pose_loss: 0.0324 - rotation_loss: 15.7509 - pose_mean_absolute_error: 0.1021 - rotation_mean_absolute_error: 2.3935 - val_loss: 0.7069 - val_pose_loss: 0.0224 - val_rotation_loss: 9.6627 - val_pose_mean_absolute_error: 0.0807 - val_rotation_mean_absolute_error: 1.7996
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.9576 - pose_loss: 0.0286 - rotation_loss: 13.4223 - pose_mean_absolute_error: 0.0956 - rotation_mean_absolute_error: 2.2478 - val_loss: 1.0497 - val_pose_loss: 0.0273 - val_rotation_loss: 15.5331 - val_pose_mean_absolute_error: 0.0893 - val_rotation_mean_absolute_error: 2.2277
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.9371 - pose_loss: 0.0281 - rotation_loss: 13.1205 - pose_mean_absolute_error: 0.0950 - rotation_mean_absolute_error: 2.1952 - val_loss: 2.7415 - val_pose_loss: 0.0661 - val_rotation_loss: 41.6008 - val_pose_mean_absolute_error: 0.1480 - val_rotation_mean_absolute_error: 3.2854
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.9539 - pose_loss: 0.0278 - rotation_loss: 13.5211 - pose_mean_absolute_error: 0.0950 - rotation_mean_absolute_error: 2.2144 - val_loss: 0.8121 - val_pose_loss: 0.0209 - val_rotation_loss: 12.0648 - val_pose_mean_absolute_error: 0.0795 - val_rotation_mean_absolute_error: 1.8839
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.7988 - pose_loss: 0.0242 - rotation_loss: 11.1269 - pose_mean_absolute_error: 0.0894 - rotation_mean_absolute_error: 2.0649 - val_loss: 0.6261 - val_pose_loss: 0.0182 - val_rotation_loss: 8.8878 - val_pose_mean_absolute_error: 0.0749 - val_rotation_mean_absolute_error: 1.6595
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.8385 - pose_loss: 0.0245 - rotation_loss: 11.8643 - pose_mean_absolute_error: 0.0902 - rotation_mean_absolute_error: 2.1044 - val_loss: 0.5951 - val_pose_loss: 0.0176 - val_rotation_loss: 8.3914 - val_pose_mean_absolute_error: 0.0715 - val_rotation_mean_absolute_error: 1.6704
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.6382 - pose_loss: 0.0203 - rotation_loss: 8.6948 - pose_mean_absolute_error: 0.0819 - rotation_mean_absolute_error: 1.8759 - val_loss: 0.7211 - val_pose_loss: 0.0171 - val_rotation_loss: 11.0036 - val_pose_mean_absolute_error: 0.0697 - val_rotation_mean_absolute_error: 1.8812
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.6917 - pose_loss: 0.0208 - rotation_loss: 9.6769 - pose_mean_absolute_error: 0.0828 - rotation_mean_absolute_error: 1.9284 - val_loss: 0.6159 - val_pose_loss: 0.0180 - val_rotation_loss: 8.7153 - val_pose_mean_absolute_error: 0.0729 - val_rotation_mean_absolute_error: 1.7354
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.6203 - pose_loss: 0.0199 - rotation_loss: 8.4349 - pose_mean_absolute_error: 0.0805 - rotation_mean_absolute_error: 1.8619 - val_loss: 0.8806 - val_pose_loss: 0.0280 - val_rotation_loss: 12.0072 - val_pose_mean_absolute_error: 0.0949 - val_rotation_mean_absolute_error: 1.9605
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.6198 - pose_loss: 0.0200 - rotation_loss: 8.4027 - pose_mean_absolute_error: 0.0816 - rotation_mean_absolute_error: 1.8495 - val_loss: 0.5132 - val_pose_loss: 0.0150 - val_rotation_loss: 7.2659 - val_pose_mean_absolute_error: 0.0664 - val_rotation_mean_absolute_error: 1.5661
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.5851 - pose_loss: 0.0188 - rotation_loss: 7.9466 - pose_mean_absolute_error: 0.0793 - rotation_mean_absolute_error: 1.7933 - val_loss: 0.9339 - val_pose_loss: 0.0229 - val_rotation_loss: 14.0907 - val_pose_mean_absolute_error: 0.0813 - val_rotation_mean_absolute_error: 2.0439
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.6087 - pose_loss: 0.0189 - rotation_loss: 8.3934 - pose_mean_absolute_error: 0.0790 - rotation_mean_absolute_error: 1.8228 - val_loss: 0.5045 - val_pose_loss: 0.0144 - val_rotation_loss: 7.2192 - val_pose_mean_absolute_error: 0.0674 - val_rotation_mean_absolute_error: 1.5305
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.5051 - pose_loss: 0.0164 - rotation_loss: 6.8243 - pose_mean_absolute_error: 0.0744 - rotation_mean_absolute_error: 1.6986 - val_loss: 0.5199 - val_pose_loss: 0.0132 - val_rotation_loss: 7.7676 - val_pose_mean_absolute_error: 0.0637 - val_rotation_mean_absolute_error: 1.6022
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.5221 - pose_loss: 0.0163 - rotation_loss: 7.1774 - pose_mean_absolute_error: 0.0740 - rotation_mean_absolute_error: 1.7199 - val_loss: 0.4965 - val_pose_loss: 0.0140 - val_rotation_loss: 7.1386 - val_pose_mean_absolute_error: 0.0640 - val_rotation_mean_absolute_error: 1.4748
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.4892 - pose_loss: 0.0160 - rotation_loss: 6.5831 - pose_mean_absolute_error: 0.0731 - rotation_mean_absolute_error: 1.6689 - val_loss: 0.5357 - val_pose_loss: 0.0161 - val_rotation_loss: 7.4932 - val_pose_mean_absolute_error: 0.0677 - val_rotation_mean_absolute_error: 1.5506
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.5067 - pose_loss: 0.0160 - rotation_loss: 6.9328 - pose_mean_absolute_error: 0.0736 - rotation_mean_absolute_error: 1.6970 - val_loss: 0.3724 - val_pose_loss: 0.0109 - val_rotation_loss: 5.2743 - val_pose_mean_absolute_error: 0.0568 - val_rotation_mean_absolute_error: 1.3519
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.4397 - pose_loss: 0.0141 - rotation_loss: 5.9643 - pose_mean_absolute_error: 0.0694 - rotation_mean_absolute_error: 1.5915 - val_loss: 0.4272 - val_pose_loss: 0.0122 - val_rotation_loss: 6.0948 - val_pose_mean_absolute_error: 0.0600 - val_rotation_mean_absolute_error: 1.4078
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.4599 - pose_loss: 0.0145 - rotation_loss: 6.3013 - pose_mean_absolute_error: 0.0702 - rotation_mean_absolute_error: 1.6089 - val_loss: 0.6055 - val_pose_loss: 0.0173 - val_rotation_loss: 8.6528 - val_pose_mean_absolute_error: 0.0749 - val_rotation_mean_absolute_error: 1.8049
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.4158 - pose_loss: 0.0136 - rotation_loss: 5.5883 - pose_mean_absolute_error: 0.0682 - rotation_mean_absolute_error: 1.5593 - val_loss: 0.3877 - val_pose_loss: 0.0107 - val_rotation_loss: 5.6106 - val_pose_mean_absolute_error: 0.0561 - val_rotation_mean_absolute_error: 1.3518
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.4222 - pose_loss: 0.0135 - rotation_loss: 5.7423 - pose_mean_absolute_error: 0.0681 - rotation_mean_absolute_error: 1.5699 - val_loss: 0.3998 - val_pose_loss: 0.0103 - val_rotation_loss: 5.9335 - val_pose_mean_absolute_error: 0.0548 - val_rotation_mean_absolute_error: 1.3814
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 23s 7ms/step - loss: 0.4213 - pose_loss: 0.0133 - rotation_loss: 5.7689 - pose_mean_absolute_error: 0.0672 - rotation_mean_absolute_error: 1.5501 - val_loss: 0.8101 - val_pose_loss: 0.0239 - val_rotation_loss: 11.4312 - val_pose_mean_absolute_error: 0.0863 - val_rotation_mean_absolute_error: 1.7906
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.000531441.
# 3355/3355 [==============================] - 23s 7ms/step - loss: 0.4316 - pose_loss: 0.0137 - rotation_loss: 5.8913 - pose_mean_absolute_error: 0.0685 - rotation_mean_absolute_error: 1.5626 - val_loss: 0.3770 - val_pose_loss: 0.0103 - val_rotation_loss: 5.4897 - val_pose_mean_absolute_error: 0.0539 - val_rotation_mean_absolute_error: 1.2909
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.000531441.
# 3355/3355 [==============================] - 23s 7ms/step - loss: 0.3614 - pose_loss: 0.0120 - rotation_loss: 4.8318 - pose_mean_absolute_error: 0.0641 - rotation_mean_absolute_error: 1.4656 - val_loss: 0.3840 - val_pose_loss: 0.0096 - val_rotation_loss: 5.7595 - val_pose_mean_absolute_error: 0.0537 - val_rotation_mean_absolute_error: 1.3579
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.000531441.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.3659 - pose_loss: 0.0118 - rotation_loss: 4.9670 - pose_mean_absolute_error: 0.0633 - rotation_mean_absolute_error: 1.4658 - val_loss: 0.3939 - val_pose_loss: 0.0107 - val_rotation_loss: 5.7374 - val_pose_mean_absolute_error: 0.0587 - val_rotation_mean_absolute_error: 1.3068
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.000531441.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.3465 - pose_loss: 0.0112 - rotation_loss: 4.6854 - pose_mean_absolute_error: 0.0626 - rotation_mean_absolute_error: 1.4412 - val_loss: 0.3507 - val_pose_loss: 0.0107 - val_rotation_loss: 4.8762 - val_pose_mean_absolute_error: 0.0566 - val_rotation_mean_absolute_error: 1.2467
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.000531441.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.3806 - pose_loss: 0.0123 - rotation_loss: 5.1452 - pose_mean_absolute_error: 0.0647 - rotation_mean_absolute_error: 1.4773 - val_loss: 0.3364 - val_pose_loss: 0.0085 - val_rotation_loss: 5.0291 - val_pose_mean_absolute_error: 0.0519 - val_rotation_mean_absolute_error: 1.2265
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0004782969000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.3231 - pose_loss: 0.0107 - rotation_loss: 4.3273 - pose_mean_absolute_error: 0.0609 - rotation_mean_absolute_error: 1.3875 - val_loss: 0.3165 - val_pose_loss: 0.0088 - val_rotation_loss: 4.5781 - val_pose_mean_absolute_error: 0.0511 - val_rotation_mean_absolute_error: 1.2255
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0004782969000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.3293 - pose_loss: 0.0108 - rotation_loss: 4.4321 - pose_mean_absolute_error: 0.0608 - rotation_mean_absolute_error: 1.3957 - val_loss: 0.3502 - val_pose_loss: 0.0092 - val_rotation_loss: 5.1595 - val_pose_mean_absolute_error: 0.0522 - val_rotation_mean_absolute_error: 1.2963
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0004782969000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.3451 - pose_loss: 0.0110 - rotation_loss: 4.6968 - pose_mean_absolute_error: 0.0615 - rotation_mean_absolute_error: 1.4100 - val_loss: 0.3405 - val_pose_loss: 0.0084 - val_rotation_loss: 5.1369 - val_pose_mean_absolute_error: 0.0499 - val_rotation_mean_absolute_error: 1.2675
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0004782969000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.3108 - pose_loss: 0.0100 - rotation_loss: 4.2201 - pose_mean_absolute_error: 0.0593 - rotation_mean_absolute_error: 1.3733 - val_loss: 0.3206 - val_pose_loss: 0.0087 - val_rotation_loss: 4.6759 - val_pose_mean_absolute_error: 0.0507 - val_rotation_mean_absolute_error: 1.1897
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0004782969000000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.3447 - pose_loss: 0.0113 - rotation_loss: 4.6356 - pose_mean_absolute_error: 0.0614 - rotation_mean_absolute_error: 1.4159 - val_loss: 0.2998 - val_pose_loss: 0.0079 - val_rotation_loss: 4.4189 - val_pose_mean_absolute_error: 0.0484 - val_rotation_mean_absolute_error: 1.1600
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0004304672100000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2986 - pose_loss: 0.0095 - rotation_loss: 4.0666 - pose_mean_absolute_error: 0.0577 - rotation_mean_absolute_error: 1.3399 - val_loss: 0.3201 - val_pose_loss: 0.0091 - val_rotation_loss: 4.5865 - val_pose_mean_absolute_error: 0.0536 - val_rotation_mean_absolute_error: 1.1804
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0004304672100000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2800 - pose_loss: 0.0091 - rotation_loss: 3.7740 - pose_mean_absolute_error: 0.0568 - rotation_mean_absolute_error: 1.3083 - val_loss: 0.2998 - val_pose_loss: 0.0074 - val_rotation_loss: 4.5229 - val_pose_mean_absolute_error: 0.0451 - val_rotation_mean_absolute_error: 1.1689
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0004304672100000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2859 - pose_loss: 0.0095 - rotation_loss: 3.8279 - pose_mean_absolute_error: 0.0573 - rotation_mean_absolute_error: 1.3152 - val_loss: 0.2892 - val_pose_loss: 0.0074 - val_rotation_loss: 4.3015 - val_pose_mean_absolute_error: 0.0469 - val_rotation_mean_absolute_error: 1.1493
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0004304672100000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2748 - pose_loss: 0.0090 - rotation_loss: 3.7014 - pose_mean_absolute_error: 0.0562 - rotation_mean_absolute_error: 1.2957 - val_loss: 0.2751 - val_pose_loss: 0.0073 - val_rotation_loss: 4.0444 - val_pose_mean_absolute_error: 0.0467 - val_rotation_mean_absolute_error: 1.1393
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0004304672100000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2816 - pose_loss: 0.0090 - rotation_loss: 3.8396 - pose_mean_absolute_error: 0.0561 - rotation_mean_absolute_error: 1.3069 - val_loss: 0.2815 - val_pose_loss: 0.0080 - val_rotation_loss: 4.0380 - val_pose_mean_absolute_error: 0.0501 - val_rotation_mean_absolute_error: 1.1017
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0003874204890000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2595 - pose_loss: 0.0084 - rotation_loss: 3.5005 - pose_mean_absolute_error: 0.0544 - rotation_mean_absolute_error: 1.2616 - val_loss: 0.2812 - val_pose_loss: 0.0071 - val_rotation_loss: 4.2035 - val_pose_mean_absolute_error: 0.0452 - val_rotation_mean_absolute_error: 1.1283
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0003874204890000001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.2556 - pose_loss: 0.0085 - rotation_loss: 3.4138 - pose_mean_absolute_error: 0.0546 - rotation_mean_absolute_error: 1.2488 - val_loss: 0.2801 - val_pose_loss: 0.0070 - val_rotation_loss: 4.1930 - val_pose_mean_absolute_error: 0.0436 - val_rotation_mean_absolute_error: 1.1436
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0003874204890000001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.2559 - pose_loss: 0.0083 - rotation_loss: 3.4654 - pose_mean_absolute_error: 0.0539 - rotation_mean_absolute_error: 1.2521 - val_loss: 0.3641 - val_pose_loss: 0.0098 - val_rotation_loss: 5.3320 - val_pose_mean_absolute_error: 0.0515 - val_rotation_mean_absolute_error: 1.3160
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0003874204890000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2850 - pose_loss: 0.0091 - rotation_loss: 3.8711 - pose_mean_absolute_error: 0.0564 - rotation_mean_absolute_error: 1.2932 - val_loss: 0.2737 - val_pose_loss: 0.0063 - val_rotation_loss: 4.2205 - val_pose_mean_absolute_error: 0.0416 - val_rotation_mean_absolute_error: 1.1211
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0003874204890000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2439 - pose_loss: 0.0080 - rotation_loss: 3.2842 - pose_mean_absolute_error: 0.0531 - rotation_mean_absolute_error: 1.2204 - val_loss: 0.2702 - val_pose_loss: 0.0072 - val_rotation_loss: 3.9725 - val_pose_mean_absolute_error: 0.0441 - val_rotation_mean_absolute_error: 1.0861
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0003486784401000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2446 - pose_loss: 0.0081 - rotation_loss: 3.2724 - pose_mean_absolute_error: 0.0531 - rotation_mean_absolute_error: 1.2194 - val_loss: 0.2682 - val_pose_loss: 0.0062 - val_rotation_loss: 4.1159 - val_pose_mean_absolute_error: 0.0414 - val_rotation_mean_absolute_error: 1.1107
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0003486784401000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2333 - pose_loss: 0.0077 - rotation_loss: 3.1348 - pose_mean_absolute_error: 0.0519 - rotation_mean_absolute_error: 1.1991 - val_loss: 0.2516 - val_pose_loss: 0.0064 - val_rotation_loss: 3.7450 - val_pose_mean_absolute_error: 0.0431 - val_rotation_mean_absolute_error: 1.0886
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0003486784401000001.
# 3355/3355 [==============================] - 23s 7ms/step - loss: 0.2350 - pose_loss: 0.0076 - rotation_loss: 3.1776 - pose_mean_absolute_error: 0.0517 - rotation_mean_absolute_error: 1.2029 - val_loss: 0.2564 - val_pose_loss: 0.0060 - val_rotation_loss: 3.9362 - val_pose_mean_absolute_error: 0.0412 - val_rotation_mean_absolute_error: 1.0427
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0003486784401000001.
# 3355/3355 [==============================] - 23s 7ms/step - loss: 0.2252 - pose_loss: 0.0074 - rotation_loss: 3.0324 - pose_mean_absolute_error: 0.0513 - rotation_mean_absolute_error: 1.1798 - val_loss: 0.2591 - val_pose_loss: 0.0060 - val_rotation_loss: 3.9776 - val_pose_mean_absolute_error: 0.0440 - val_rotation_mean_absolute_error: 1.0786
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0003486784401000001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2340 - pose_loss: 0.0075 - rotation_loss: 3.1749 - pose_mean_absolute_error: 0.0516 - rotation_mean_absolute_error: 1.1933 - val_loss: 0.2667 - val_pose_loss: 0.0064 - val_rotation_loss: 4.0552 - val_pose_mean_absolute_error: 0.0429 - val_rotation_mean_absolute_error: 1.0933
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0003138105960900001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2212 - pose_loss: 0.0073 - rotation_loss: 2.9552 - pose_mean_absolute_error: 0.0507 - rotation_mean_absolute_error: 1.1683 - val_loss: 0.2584 - val_pose_loss: 0.0054 - val_rotation_loss: 4.0960 - val_pose_mean_absolute_error: 0.0388 - val_rotation_mean_absolute_error: 1.0326
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0003138105960900001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2169 - pose_loss: 0.0070 - rotation_loss: 2.9385 - pose_mean_absolute_error: 0.0498 - rotation_mean_absolute_error: 1.1638 - val_loss: 0.2685 - val_pose_loss: 0.0065 - val_rotation_loss: 4.0650 - val_pose_mean_absolute_error: 0.0424 - val_rotation_mean_absolute_error: 1.0693
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0003138105960900001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2110 - pose_loss: 0.0068 - rotation_loss: 2.8568 - pose_mean_absolute_error: 0.0492 - rotation_mean_absolute_error: 1.1506 - val_loss: 0.2656 - val_pose_loss: 0.0058 - val_rotation_loss: 4.1505 - val_pose_mean_absolute_error: 0.0412 - val_rotation_mean_absolute_error: 1.0686
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0003138105960900001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2126 - pose_loss: 0.0068 - rotation_loss: 2.8978 - pose_mean_absolute_error: 0.0492 - rotation_mean_absolute_error: 1.1538 - val_loss: 0.2278 - val_pose_loss: 0.0060 - val_rotation_loss: 3.3637 - val_pose_mean_absolute_error: 0.0407 - val_rotation_mean_absolute_error: 1.0308
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0003138105960900001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2124 - pose_loss: 0.0067 - rotation_loss: 2.8994 - pose_mean_absolute_error: 0.0491 - rotation_mean_absolute_error: 1.1487 - val_loss: 0.2628 - val_pose_loss: 0.0061 - val_rotation_loss: 4.0367 - val_pose_mean_absolute_error: 0.0414 - val_rotation_mean_absolute_error: 1.0848
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0002824295364810001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.2058 - pose_loss: 0.0066 - rotation_loss: 2.7983 - pose_mean_absolute_error: 0.0485 - rotation_mean_absolute_error: 1.1358 - val_loss: 0.2210 - val_pose_loss: 0.0055 - val_rotation_loss: 3.3139 - val_pose_mean_absolute_error: 0.0384 - val_rotation_mean_absolute_error: 0.9835
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0002824295364810001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.1967 - pose_loss: 0.0064 - rotation_loss: 2.6608 - pose_mean_absolute_error: 0.0476 - rotation_mean_absolute_error: 1.1155 - val_loss: 0.2134 - val_pose_loss: 0.0052 - val_rotation_loss: 3.2333 - val_pose_mean_absolute_error: 0.0375 - val_rotation_mean_absolute_error: 1.0062
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0002824295364810001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1991 - pose_loss: 0.0063 - rotation_loss: 2.7145 - pose_mean_absolute_error: 0.0478 - rotation_mean_absolute_error: 1.1156 - val_loss: 0.2184 - val_pose_loss: 0.0053 - val_rotation_loss: 3.3072 - val_pose_mean_absolute_error: 0.0393 - val_rotation_mean_absolute_error: 0.9793
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0002824295364810001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1925 - pose_loss: 0.0062 - rotation_loss: 2.6135 - pose_mean_absolute_error: 0.0472 - rotation_mean_absolute_error: 1.1007 - val_loss: 0.2434 - val_pose_loss: 0.0057 - val_rotation_loss: 3.7207 - val_pose_mean_absolute_error: 0.0392 - val_rotation_mean_absolute_error: 1.0245
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0002824295364810001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1911 - pose_loss: 0.0064 - rotation_loss: 2.5483 - pose_mean_absolute_error: 0.0475 - rotation_mean_absolute_error: 1.0968 - val_loss: 0.2284 - val_pose_loss: 0.0053 - val_rotation_loss: 3.5064 - val_pose_mean_absolute_error: 0.0379 - val_rotation_mean_absolute_error: 1.0078
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0002541865828329001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1921 - pose_loss: 0.0062 - rotation_loss: 2.6022 - pose_mean_absolute_error: 0.0470 - rotation_mean_absolute_error: 1.1014 - val_loss: 0.2264 - val_pose_loss: 0.0051 - val_rotation_loss: 3.5061 - val_pose_mean_absolute_error: 0.0371 - val_rotation_mean_absolute_error: 0.9879
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0002541865828329001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1865 - pose_loss: 0.0059 - rotation_loss: 2.5457 - pose_mean_absolute_error: 0.0461 - rotation_mean_absolute_error: 1.0836 - val_loss: 0.2524 - val_pose_loss: 0.0059 - val_rotation_loss: 3.8710 - val_pose_mean_absolute_error: 0.0405 - val_rotation_mean_absolute_error: 1.0192
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0002541865828329001.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.1797 - pose_loss: 0.0059 - rotation_loss: 2.4138 - pose_mean_absolute_error: 0.0461 - rotation_mean_absolute_error: 1.0678 - val_loss: 0.2431 - val_pose_loss: 0.0053 - val_rotation_loss: 3.7965 - val_pose_mean_absolute_error: 0.0368 - val_rotation_mean_absolute_error: 0.9926
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0002541865828329001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1826 - pose_loss: 0.0059 - rotation_loss: 2.4771 - pose_mean_absolute_error: 0.0460 - rotation_mean_absolute_error: 1.0735 - val_loss: 0.2403 - val_pose_loss: 0.0059 - val_rotation_loss: 3.6353 - val_pose_mean_absolute_error: 0.0412 - val_rotation_mean_absolute_error: 1.0006
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0002541865828329001.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1850 - pose_loss: 0.0059 - rotation_loss: 2.5136 - pose_mean_absolute_error: 0.0460 - rotation_mean_absolute_error: 1.0777 - val_loss: 0.2820 - val_pose_loss: 0.0072 - val_rotation_loss: 4.2043 - val_pose_mean_absolute_error: 0.0440 - val_rotation_mean_absolute_error: 1.1294
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0002287679245496101.
# 3355/3355 [==============================] - 22s 6ms/step - loss: 0.1841 - pose_loss: 0.0060 - rotation_loss: 2.4913 - pose_mean_absolute_error: 0.0461 - rotation_mean_absolute_error: 1.0746 - val_loss: 0.2106 - val_pose_loss: 0.0051 - val_rotation_loss: 3.2012 - val_pose_mean_absolute_error: 0.0371 - val_rotation_mean_absolute_error: 0.9805
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0002287679245496101.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1810 - pose_loss: 0.0056 - rotation_loss: 2.4905 - pose_mean_absolute_error: 0.0450 - rotation_mean_absolute_error: 1.0659 - val_loss: 0.2172 - val_pose_loss: 0.0049 - val_rotation_loss: 3.3662 - val_pose_mean_absolute_error: 0.0360 - val_rotation_mean_absolute_error: 0.9675
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0002287679245496101.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1727 - pose_loss: 0.0056 - rotation_loss: 2.3269 - pose_mean_absolute_error: 0.0450 - rotation_mean_absolute_error: 1.0418 - val_loss: 0.2178 - val_pose_loss: 0.0049 - val_rotation_loss: 3.3811 - val_pose_mean_absolute_error: 0.0350 - val_rotation_mean_absolute_error: 0.9631
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0002287679245496101.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1727 - pose_loss: 0.0055 - rotation_loss: 2.3577 - pose_mean_absolute_error: 0.0445 - rotation_mean_absolute_error: 1.0493 - val_loss: 0.2538 - val_pose_loss: 0.0052 - val_rotation_loss: 4.0403 - val_pose_mean_absolute_error: 0.0381 - val_rotation_mean_absolute_error: 0.9803
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0002287679245496101.
# 3355/3355 [==============================] - 23s 7ms/step - loss: 0.1737 - pose_loss: 0.0055 - rotation_loss: 2.3669 - pose_mean_absolute_error: 0.0447 - rotation_mean_absolute_error: 1.0482 - val_loss: 0.2188 - val_pose_loss: 0.0048 - val_rotation_loss: 3.4106 - val_pose_mean_absolute_error: 0.0353 - val_rotation_mean_absolute_error: 0.9857
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0002058911320946491.
# 3355/3355 [==============================] - 23s 7ms/step - loss: 0.1684 - pose_loss: 0.0054 - rotation_loss: 2.2967 - pose_mean_absolute_error: 0.0439 - rotation_mean_absolute_error: 1.0341 - val_loss: 0.2121 - val_pose_loss: 0.0052 - val_rotation_loss: 3.1996 - val_pose_mean_absolute_error: 0.0386 - val_rotation_mean_absolute_error: 0.9488
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0002058911320946491.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1710 - pose_loss: 0.0053 - rotation_loss: 2.3550 - pose_mean_absolute_error: 0.0439 - rotation_mean_absolute_error: 1.0382 - val_loss: 0.2051 - val_pose_loss: 0.0049 - val_rotation_loss: 3.1224 - val_pose_mean_absolute_error: 0.0359 - val_rotation_mean_absolute_error: 0.9461
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0002058911320946491.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1623 - pose_loss: 0.0052 - rotation_loss: 2.2137 - pose_mean_absolute_error: 0.0431 - rotation_mean_absolute_error: 1.0221 - val_loss: 0.2433 - val_pose_loss: 0.0053 - val_rotation_loss: 3.8084 - val_pose_mean_absolute_error: 0.0377 - val_rotation_mean_absolute_error: 0.9870
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0002058911320946491.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1662 - pose_loss: 0.0052 - rotation_loss: 2.2925 - pose_mean_absolute_error: 0.0431 - rotation_mean_absolute_error: 1.0285 - val_loss: 0.2199 - val_pose_loss: 0.0050 - val_rotation_loss: 3.3996 - val_pose_mean_absolute_error: 0.0361 - val_rotation_mean_absolute_error: 0.9450
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0002058911320946491.
# 3355/3355 [==============================] - 22s 7ms/step - loss: 0.1658 - pose_loss: 0.0054 - rotation_loss: 2.2463 - pose_mean_absolute_error: 0.0437 - rotation_mean_absolute_error: 1.0234 - val_loss: 0.2134 - val_pose_loss: 0.0047 - val_rotation_loss: 3.3224 - val_pose_mean_absolute_error: 0.0351 - val_rotation_mean_absolute_error: 0.9381
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping

# %% [markdown]
# # Section 4: Model Evaluation

# %%
model.evaluate(validation_dataset)
# Out:
# 592/592 [==============================] - 2s 3ms/step - loss: 0.2178 - pose_loss: 0.0049 - rotation_loss: 3.3811 - pose_mean_absolute_error: 0.0350 - rotation_mean_absolute_error: 0.9631
# [0.2178233563899994,
#  0.004876597318798304,
#  3.381148338317871,
#  0.03500441834330559,
#  0.9630863070487976]

# %%
# model.save("model_regression")
# from google.colab import files
# !zip -r model_regression.zip model_regression/
# files.download('model_regression.zip')

# %%
#evaluate model accuracy using testing dataset
testing_dataset = tf.data.Dataset.from_tensor_slices((x_testing, (y_testing[:,0:2],y_testing[:,2]))).batch(BATCH_SIZE)
model.evaluate(testing_dataset)
# Out:
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1600 - pose_loss: 0.0041 - rotation_loss: 2.3720 - pose_mean_absolute_error: 0.0350 - rotation_mean_absolute_error: 0.9611
# [0.16004642844200134,
#  0.004144479054957628,
#  2.372032642364502,
#  0.03504437580704689,
#  0.9611061811447144]

# %% [markdown]
# ## Test from new environment

# %%
testing_range_pairs,testing_translation_rels,testing_rotation_rels = read_from_pickle(dir_name,'test')

testing_translation_rels_norm=LA.norm(testing_translation_rels, axis=1)
testing_nonzeros_indices=np.where((testing_translation_rels_norm>1e-4) | (np.abs(testing_rotation_rels)>1e-4))
testing_nonfar_indices=np.where((testing_rotation_rels<=1.0) & (testing_rotation_rels>=-1.0))
testing_chosen_indices=np.intersect1d(testing_nonzeros_indices,testing_nonfar_indices)
testing_translation_rels=testing_translation_rels[testing_chosen_indices]
testing_rotation_rels=testing_rotation_rels[testing_chosen_indices]
testing_range_pairs=laser_compression(testing_range_pairs[testing_chosen_indices],Flag_compression,Karaman_method)

testing_rotation_rels=np.round(np.double(testing_rotation_rels*180/math.pi),4)
#pose_rels_grid_all=np.hstack((np.expand_dims(pose_rels_grid, axis=1),np.expand_dims(rotation_rels, axis=1)))
testing_pose_rels_all=np.hstack((testing_translation_rels,np.expand_dims(testing_rotation_rels, axis=1)))
#print(np.shape(range_pairs_compressed),np.shape(pose_rels_grid),np.shape(rotation_rels_grid),np.shape(pose_rels_grid_all),np.shape(pose_rels_all))
testing_range_pairs_all=np.clip(testing_range_pairs, a_min=None, a_max=40)    #remove the inf value of range to a large number

x_test_new, y_test_new, y_test_new_ground_truth = shuffle(testing_range_pairs_all,testing_pose_rels_all, testing_pose_rels_all)

x_testing2 = np.array(x_test_new, dtype=float)
y_testing2 = np.array(y_test_new, dtype=float)
y_testing_ground_truth2=np.array(y_test_new, dtype=float)
print('Size of testing data: ', x_testing2.shape)
print('Size of testing labels: ',y_testing2.shape)
testing_dataset2 = tf.data.Dataset.from_tensor_slices((x_testing2, (y_testing2[:,0:2],y_testing2[:,2]))).batch(BATCH_SIZE)
model.evaluate(testing_dataset2)
# Out:
# for %s dataset test
# size of range_pairs:  (24562, 361, 2)
# size of pose_rels:  (24562, 2)
# size of rotation_rels:  (24562,)
# <------------->
# size of range_pairs_compressed:  (18556, 361, 3)
# Size of testing data:  (18556, 361, 3)
# Size of testing labels:  (18556, 3)
# 580/580 [==============================] - 2s 3ms/step - loss: 1.3157 - pose_loss: 0.0234 - rotation_loss: 21.6241 - pose_mean_absolute_error: 0.0777 - rotation_mean_absolute_error: 1.8165
# [1.3156551122665405,
#  0.023445308208465576,
#  21.62406349182129,
#  0.07768901437520981,
#  1.8165488243103027]

# %%
y_testing3=y_testing2
x_testing3=x_testing2
y_testing_ground_truth3=y_testing_ground_truth2

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.losses import MAE
def inverse_projection_2d(predict_idx):
  y_idx=predict_idx%40
  x_idx=(predict_idx-y_idx)/40
  grid_offset=np.transpose(np.array([[-1.8,-1.2]]))
  grid_spacing=np.transpose(np.array([[0.05,0.05]]))
  grid_point=grid_offset+np.array([x_idx,y_idx])*grid_spacing
  return grid_point

def inverse_projection_1d(predict_idx):
  grid_offset=np.array([-1.0*180/np.pi])
  grid_spacing=np.array([0.5])
  grid_point=grid_offset+predict_idx*grid_spacing
  print(grid_point[0:2])
  print(predict_idx[0:2])
  return grid_point


y_predict=model.predict(x_testing3)

print(y_predict[0].shape, y_predict[1].shape, y_testing3[:,2].shape,y_testing3[:,0:2].shape)
# predict_pose=np.argmax(y_predict[0],axis=1)
# predict_pose_point=np.transpose(inverse_projection_2d(predict_pose))
predict_pose_point=y_predict[0]


# predict_rotation=np.argmax(y_predict[1],axis=1)
# predict_rotation_value=np.transpose(inverse_projection_1d(predict_rotation))
predict_rotation_value=tf.squeeze(y_predict[1])
  

# print(np.shape(predict_rotation))
print("prediction of translation MSE: ", tf.reduce_sum(MAE(y_testing3[:,0:2],predict_pose_point))/y_testing3.shape[0])
print("prediction of rotation MAE: ", MAE(y_testing3[:,2], predict_rotation_value))
nSamples=200
predict_list=np.zeros((nSamples,3))
for i in range(nSamples):
  predict_i=list(np.round(predict_pose_point[i],4))
  predict_i.append(np.round(np.float(predict_rotation_value[i]),4))
  predict_list[i]=predict_i
  if i%1==0:
    print("test: ", i, " ground_truth: ", np.round(y_testing_ground_truth3[i],4),
          " predicted: ",predict_i)
# Out:
# (18556, 2) (18556, 1) (18556,) (18556, 2)
# prediction of translation MSE:  tf.Tensor(0.07768898, shape=(), dtype=float32)
# prediction of rotation MAE:  tf.Tensor(1.8165494, shape=(), dtype=float32)
# test:  0  ground_truth:  [ 0.9869 -0.0212 -5.8844]  predicted:  [0.8993, -0.0093, -5.5503]
# test:  1  ground_truth:  [-0.9056 -0.1478 38.1943]  predicted:  [-0.4548, -0.1154, 32.5009]
# test:  2  ground_truth:  [-2.43000e-02 -5.80000e-03  5.22559e+01]  predicted:  [0.0706, 0.052, 51.4674]
# test:  3  ground_truth:  [-0.     0.    44.537]  predicted:  [-0.0331, -0.009, 41.1507]
# test:  4  ground_truth:  [0.7516 0.0078 2.3732]  predicted:  [0.8417, 0.0318, 2.8466]
# test:  5  ground_truth:  [ 0.3415 -0.001  -0.433 ]  predicted:  [0.3077, 0.0019, -1.3143]
# test:  6  ground_truth:  [-0.2977 -0.0011  0.4207]  predicted:  [-0.2198, -0.0032, -0.3102]
# test:  7  ground_truth:  [  0.6244  -0.169  -30.836 ]  predicted:  [0.5051, -0.0821, -25.2869]
# test:  8  ground_truth:  [ 4.5030e-01 -1.1000e-03 -1.3744e+00]  predicted:  [0.457, -0.0077, -1.7574]
# test:  9  ground_truth:  [ 0.4682 -0.0149 -5.3587]  predicted:  [0.5434, -0.0166, -3.8556]
# test:  10  ground_truth:  [-9.90000e-03  1.20000e-03 -1.54435e+01]  predicted:  [-0.0166, -0.0017, -14.8155]
# test:  11  ground_truth:  [0.4852 0.0099 1.7284]  predicted:  [0.5411, 0.0042, 1.4899]
# test:  12  ground_truth:  [-0.258  -0.0577 25.8983]  predicted:  [-0.1338, -0.0341, 28.4649]
# test:  13  ground_truth:  [1.8000e-02 7.0000e-04 3.5712e+00]  predicted:  [0.016, -0.0002, 2.6124]
# test:  14  ground_truth:  [ 0.5631 -0.0068  1.6984]  predicted:  [0.5075, 0.0016, 1.0361]
# test:  15  ground_truth:  [-1.30000e-03 -3.00000e-04  2.86078e+01]  predicted:  [-0.0304, -0.014, 30.3431]
# test:  16  ground_truth:  [-0.9736 -0.0315  4.5618]  predicted:  [-1.0095, -0.0153, 1.3455]
# test:  17  ground_truth:  [-0.3878  0.0073 -1.4612]  predicted:  [-0.3408, 0.001, -2.2502]
# test:  18  ground_truth:  [ 0.1487 -0.0003 -0.2098]  predicted:  [0.2166, -0.0013, -0.6]
# test:  19  ground_truth:  [0.5609 0.0359 3.4821]  predicted:  [0.4133, 0.0101, 3.632]
# test:  20  ground_truth:  [ 0.8709  0.115  11.0603]  predicted:  [0.8561, 0.0712, 10.9479]
# test:  21  ground_truth:  [0.2513 0.0127 2.6722]  predicted:  [0.2796, 0.0151, 7.8363]
# test:  22  ground_truth:  [ 0.2156 -0.0019 -0.9351]  predicted:  [0.2184, -0.0028, -0.5806]
# test:  23  ground_truth:  [  0.4845  -0.1316 -31.0411]  predicted:  [0.4979, -0.1165, -31.6847]
# test:  24  ground_truth:  [-0.4751  0.01   -4.4676]  predicted:  [-0.4773, 0.0057, -2.955]
# test:  25  ground_truth:  [-0.9336  0.0503 -7.7261]  predicted:  [-0.4584, 0.0141, -5.6883]
# test:  26  ground_truth:  [-7.00000e-02 -1.19000e-02  2.85984e+01]  predicted:  [-0.3214, -0.0833, 27.0505]
# test:  27  ground_truth:  [-5.657e-01  2.000e-04 -8.200e-02]  predicted:  [-0.4831, 0.0046, -0.6702]
# test:  28  ground_truth:  [-0.2761 -0.0395 15.9717]  predicted:  [-0.3099, -0.046, 14.2023]
# test:  29  ground_truth:  [-2.000e-04 -0.000e+00  4.172e+00]  predicted:  [-0.1568, -0.003, 4.3345]
# test:  30  ground_truth:  [-6.94000e-02 -1.76000e-02  3.58509e+01]  predicted:  [-0.1083, -0.0319, 29.4385]
# test:  31  ground_truth:  [2.60000e-02 1.23000e-02 3.78603e+01]  predicted:  [-0.2414, -0.0391, 31.3719]
# test:  32  ground_truth:  [0.2957 0.0334 6.552 ]  predicted:  [0.2836, 0.0068, 6.0382]
# test:  33  ground_truth:  [-0.2392 -0.0042  2.0136]  predicted:  [-0.2716, -0.0097, 1.8083]
# test:  34  ground_truth:  [-0.7316 -0.0282  3.3212]  predicted:  [-0.5821, -0.0059, 2.7039]
# test:  35  ground_truth:  [ 2.0000e-04 -0.0000e+00 -3.1349e+00]  predicted:  [0.0003, -0.0021, -2.9728]
# test:  36  ground_truth:  [-1.1043 -0.0053  0.3694]  predicted:  [-0.8946, -0.0054, 0.2681]
# test:  37  ground_truth:  [-0.4668  0.0024 -1.3939]  predicted:  [-0.3834, -0.0006, -0.2261]
# test:  38  ground_truth:  [-0.1393 -0.0346 23.5458]  predicted:  [-0.0333, -0.0284, 25.2525]
# test:  39  ground_truth:  [ 1.0670e-01 -6.8000e-03 -7.1216e+00]  predicted:  [0.0344, -0.0004, -6.727]
# test:  40  ground_truth:  [0.4729 0.0049 1.5599]  predicted:  [0.4604, -0.0026, 1.3207]
# test:  41  ground_truth:  [-0.2324 -0.002   0.6842]  predicted:  [-0.2283, -0.0057, 1.8202]
# test:  42  ground_truth:  [-1.9990e-01 -5.0000e-04  6.9365e+00]  predicted:  [-0.5818, -0.046, 8.479]
# test:  43  ground_truth:  [-0.5316 -0.016   6.0272]  predicted:  [-0.4332, -0.0172, 5.2136]
# test:  44  ground_truth:  [0.2303 0.0004 0.3097]  predicted:  [0.2435, -0.0014, 0.2721]
# test:  45  ground_truth:  [-4.900e-03  2.000e-04 -1.312e+01]  predicted:  [0.0194, -0.0045, -15.3629]
# test:  46  ground_truth:  [0.4916 0.0008 0.2451]  predicted:  [0.273, -0.0023, 0.2986]
# test:  47  ground_truth:  [ 0.913   0.1516 31.4292]  predicted:  [0.9032, 0.2832, 33.9488]
# test:  48  ground_truth:  [-0.4912 -0.0033 -0.1069]  predicted:  [-0.4907, 0.0009, -0.2145]
# test:  49  ground_truth:  [-0.4643 -0.003   0.2093]  predicted:  [-0.4217, -0.0016, 0.8284]
# test:  50  ground_truth:  [-0.222  -0.0024  0.1678]  predicted:  [-0.2238, -0.0039, -0.2819]
# test:  51  ground_truth:  [-0.2312 -0.0136  7.3623]  predicted:  [-0.212, -0.0088, 6.4811]
# test:  52  ground_truth:  [ 0.4679  0.0917 21.052 ]  predicted:  [0.522, 0.0836, 21.5269]
# test:  53  ground_truth:  [-0.2546 -0.0152 -1.2207]  predicted:  [-0.2404, -0.0029, -1.075]
# test:  54  ground_truth:  [-2.939e-01  2.000e-04 -1.893e-01]  predicted:  [-0.2932, 0.0005, -1.1802]
# test:  55  ground_truth:  [0.4453 0.0115 2.0125]  predicted:  [0.2838, -0.0044, 0.6151]
# test:  56  ground_truth:  [ 1.2699  0.5088 33.137 ]  predicted:  [0.7615, 0.2225, 31.5395]
# test:  57  ground_truth:  [1.65900e-01 8.40000e-03 1.29123e+01]  predicted:  [0.0123, 0.0009, 11.5939]
# test:  58  ground_truth:  [ 2.472e-01 -2.000e-04 -2.076e-01]  predicted:  [0.2578, -0.0031, -0.282]
# test:  59  ground_truth:  [ 0.0975 -0.0044 -2.8553]  predicted:  [0.098, -0.0018, -3.7188]
# test:  60  ground_truth:  [-0.2245 -0.0004 -0.0608]  predicted:  [-0.2384, -0.0037, -0.1432]
# test:  61  ground_truth:  [0.4796 0.0005 0.436 ]  predicted:  [0.4387, -0.0054, 0.6141]
# test:  62  ground_truth:  [-1.0657 -0.0042  1.455 ]  predicted:  [-0.8924, -0.015, 2.8227]
# test:  63  ground_truth:  [ -0.6269   0.1054 -21.9184]  predicted:  [-0.4598, 0.0746, -22.7004]
# test:  64  ground_truth:  [  0.4486  -0.1132 -12.8023]  predicted:  [0.5877, -0.1241, -17.7712]
# test:  65  ground_truth:  [  0.4779  -0.0666 -21.9591]  predicted:  [0.3748, -0.0604, -20.7282]
# test:  66  ground_truth:  [-0.2586 -0.0716 29.3961]  predicted:  [-0.1383, -0.0298, 27.2777]
# test:  67  ground_truth:  [4.40000e-02 3.80000e-03 1.22966e+01]  predicted:  [0.1562, 0.0231, 16.5801]
# test:  68  ground_truth:  [ -0.9659   0.1204 -23.7625]  predicted:  [-0.731, 0.1043, -21.2784]
# test:  69  ground_truth:  [  0.1974  -0.0225 -10.7921]  predicted:  [0.3026, -0.034, -11.4479]
# test:  70  ground_truth:  [-0.4769 -0.0437 12.5347]  predicted:  [-0.4545, -0.0674, 12.9084]
# test:  71  ground_truth:  [-0.9034  0.0203 -1.5625]  predicted:  [-0.9245, -0.0078, -0.8759]
# test:  72  ground_truth:  [ -0.5296   0.0969 -24.0483]  predicted:  [-0.3749, 0.0606, -20.5844]
# test:  73  ground_truth:  [  0.6451  -0.0947 -21.3152]  predicted:  [0.6616, -0.0959, -19.3217]
# test:  74  ground_truth:  [ -0.9421   0.1502 -27.8289]  predicted:  [-0.7767, 0.1468, -26.1662]
# test:  75  ground_truth:  [-4.40000e-03 -3.00000e-03  3.49442e+01]  predicted:  [-0.0335, -0.0237, 34.1315]
# test:  76  ground_truth:  [ 8.00000e-04 -1.00000e-04 -1.73556e+01]  predicted:  [0.0178, -0.0032, -16.5332]
# test:  77  ground_truth:  [-0.5602  0.0057 -1.1665]  predicted:  [-0.5172, 0.0038, 0.2553]
# test:  78  ground_truth:  [4.13000e-02 1.74000e-02 2.64041e+01]  predicted:  [0.0486, 0.0133, 25.4039]
# test:  79  ground_truth:  [-0.2844 -0.1435 47.9497]  predicted:  [0.235, 0.1075, 42.1446]
# test:  80  ground_truth:  [-0.6549  0.0214  4.6667]  predicted:  [-0.3457, -0.0216, 4.8881]
# test:  81  ground_truth:  [ -1.0278   0.2523 -15.8917]  predicted:  [-1.0197, 0.0798, -8.8054]
# test:  82  ground_truth:  [-1.1217e+00 -4.0000e-04 -2.3610e-01]  predicted:  [-0.7149, 0.0042, -0.838]
# test:  83  ground_truth:  [ -0.       0.     -33.2525]  predicted:  [0.1498, -0.0575, -36.3567]
# test:  84  ground_truth:  [-0.2563 -0.0008  0.3632]  predicted:  [-0.2301, -0.005, 0.9841]
# test:  85  ground_truth:  [0.2366 0.0004 0.2813]  predicted:  [0.2438, -0.0046, 0.4248]
# test:  86  ground_truth:  [ -0.       0.     -31.7618]  predicted:  [0.0255, -0.0021, -30.9069]
# test:  87  ground_truth:  [-0.9341  0.0079 -1.9307]  predicted:  [-0.8934, -0.0093, -1.7629]
# test:  88  ground_truth:  [-0.5911 -0.1982  4.7226]  predicted:  [-0.4897, -0.002, 2.5243]
# test:  89  ground_truth:  [  0.4808  -0.1971 -41.6362]  predicted:  [0.3827, -0.3372, -54.8047]
# test:  90  ground_truth:  [0.2491 0.004  2.0094]  predicted:  [0.2466, -0.0004, 1.6249]
# test:  91  ground_truth:  [ 0.8692  0.2335 35.1385]  predicted:  [1.0085, 0.2627, 34.2071]
# test:  92  ground_truth:  [-0.2552 -0.0118  6.5815]  predicted:  [-0.2713, -0.0097, 6.5567]
# test:  93  ground_truth:  [-0.4816  0.0104 -2.0258]  predicted:  [-0.4121, 0.0033, -1.9957]
# test:  94  ground_truth:  [1.21300e-01 7.00000e-03 1.15053e+01]  predicted:  [0.1884, 0.0204, 12.1742]
# test:  95  ground_truth:  [-2.581e-01 -2.000e-04  7.462e-01]  predicted:  [-0.219, -0.0046, 1.1415]
# test:  96  ground_truth:  [ 0.3184  0.0337 11.5566]  predicted:  [0.3677, 0.0265, 12.6433]
# test:  97  ground_truth:  [0.2586 0.0006 0.0329]  predicted:  [0.248, 0.0012, 0.1854]
# test:  98  ground_truth:  [  0.1295  -0.0429 -33.0661]  predicted:  [0.0318, -0.0075, -28.6658]
# test:  99  ground_truth:  [ 0.4085 -0.0119 -2.9931]  predicted:  [0.4139, -0.0129, -2.8293]
# test:  100  ground_truth:  [ -0.       0.     -33.8805]  predicted:  [-0.1879, 0.0424, -32.202]
# test:  101  ground_truth:  [ 0.5296 -0.0443 -7.8684]  predicted:  [0.7787, -0.0512, -6.979]
# test:  102  ground_truth:  [  0.2718  -0.064  -25.1347]  predicted:  [-0.0885, 0.0178, -26.5018]
# test:  103  ground_truth:  [-0.7326  0.035  -2.6588]  predicted:  [-0.8512, 0.011, -1.8674]
# test:  104  ground_truth:  [  1.0936  -0.3215 -22.3977]  predicted:  [0.8723, -0.2184, -31.3019]
# test:  105  ground_truth:  [  0.1004  -0.0399 -32.0643]  predicted:  [0.1982, -0.0593, -33.3524]
# test:  106  ground_truth:  [-0.4976 -0.0087  1.3968]  predicted:  [-0.4339, -0.002, 0.5946]
# test:  107  ground_truth:  [ 0.4275  0.1096 24.7194]  predicted:  [0.0517, 0.0088, 25.2313]
# test:  108  ground_truth:  [ 0.5173  0.0923 25.1091]  predicted:  [0.3179, 0.0455, 25.0817]
# test:  109  ground_truth:  [ -0.3756   0.0914 -19.2119]  predicted:  [-0.5009, 0.0855, -22.2211]
# test:  110  ground_truth:  [-0.23    0.003  -1.4255]  predicted:  [-0.2206, -0.0018, -1.6322]
# test:  111  ground_truth:  [  0.3523  -0.0611 -18.7271]  predicted:  [0.3269, -0.0409, -15.6337]
# test:  112  ground_truth:  [0.4765 0.0071 1.8318]  predicted:  [0.3866, -0.0035, 1.0533]
# test:  113  ground_truth:  [-6.59000e-02  8.20000e-03 -1.22945e+01]  predicted:  [0.068, -0.0154, -13.2209]
# test:  114  ground_truth:  [-0.6999 -0.2165 29.0346]  predicted:  [-0.6613, -0.1776, 30.5433]
# test:  115  ground_truth:  [ -0.7054   0.0758 -13.885 ]  predicted:  [-0.5008, 0.0333, -8.8214]
# test:  116  ground_truth:  [-0.2258  0.0372 -6.2194]  predicted:  [-0.1634, 0.0026, -4.3944]
# test:  117  ground_truth:  [-0.2291 -0.0093  4.4969]  predicted:  [-0.2312, -0.0055, 4.9694]
# test:  118  ground_truth:  [0.2454 0.0191 7.7351]  predicted:  [0.2546, 0.0138, 7.3518]
# test:  119  ground_truth:  [ 1.0835 -0.018   1.5186]  predicted:  [0.9708, 0.0047, 0.7763]
# test:  120  ground_truth:  [ 3.0000e-04 -0.0000e+00 -5.8539e+00]  predicted:  [-0.0246, -0.0015, -6.9119]
# test:  121  ground_truth:  [ 2.392e-01  1.000e-04 -1.321e-01]  predicted:  [0.2632, -0.0025, 0.1121]
# test:  122  ground_truth:  [0.391  0.0018 0.9601]  predicted:  [0.4424, 0.0, 1.6129]
# test:  123  ground_truth:  [  0.207   -0.1592 -56.5319]  predicted:  [0.2025, -0.1145, -52.4397]
# test:  124  ground_truth:  [4.8000e-03 1.0000e-04 1.3363e+00]  predicted:  [0.0113, -0.002, -0.1595]
# test:  125  ground_truth:  [-1.0212  0.0171 -2.4615]  predicted:  [-0.6269, 0.013, -2.3717]
# test:  126  ground_truth:  [0.9184 0.0683 5.7993]  predicted:  [0.7257, 0.0446, 10.1408]
# test:  127  ground_truth:  [-0.2329  0.0005 -0.0505]  predicted:  [-0.2331, -0.0041, 0.3003]
# test:  128  ground_truth:  [1.29000e-02 2.70000e-03 1.36618e+01]  predicted:  [0.0246, 0.0033, 13.5374]
# test:  129  ground_truth:  [ 0.4484  0.0847 19.3277]  predicted:  [0.1412, 0.0307, 22.6172]
# test:  130  ground_truth:  [  0.241   -0.0575 -25.405 ]  predicted:  [0.1927, -0.0425, -26.0703]
# test:  131  ground_truth:  [-1.1684  0.0542 -2.6382]  predicted:  [-1.0985, 0.0419, -2.9911]
# test:  132  ground_truth:  [-1.020e-02  5.000e-04 -7.789e+00]  predicted:  [0.0146, -0.0027, -6.9369]
# test:  133  ground_truth:  [-2.00000e-03  2.00000e-04  1.75557e+01]  predicted:  [0.1025, 0.0158, 17.2223]
# test:  134  ground_truth:  [ 0.1635  0.0777 47.0033]  predicted:  [-0.0843, -0.0114, 44.2302]
# test:  135  ground_truth:  [-0.9952 -0.0179  0.6564]  predicted:  [-0.9912, 0.0015, -1.0426]
# test:  136  ground_truth:  [ 0.8589  0.3761 45.5542]  predicted:  [-0.2022, 0.289, 7.9003]
# test:  137  ground_truth:  [ 0.0421 -0.0024 -0.2202]  predicted:  [0.11, -0.0002, 0.1896]
# test:  138  ground_truth:  [0.4731 0.0241 5.1572]  predicted:  [0.0931, 0.0045, 4.9918]
# test:  139  ground_truth:  [-1.0963  0.0398 -3.1368]  predicted:  [-0.9575, 0.0143, -2.3868]
# test:  140  ground_truth:  [-0.2202 -0.0006  0.3113]  predicted:  [-0.2128, -0.0042, 0.3764]
# test:  141  ground_truth:  [-0.585   0.0172 -4.211 ]  predicted:  [-0.4408, 0.0103, -4.0343]
# test:  142  ground_truth:  [ 0.5175 -0.0108 -1.6599]  predicted:  [0.5127, -0.0036, -0.5698]
# test:  143  ground_truth:  [ -0.588    0.0596 -10.9969]  predicted:  [-0.4658, 0.0509, -14.4118]
# test:  144  ground_truth:  [-0.5047 -0.0097  1.719 ]  predicted:  [-0.5587, -0.0128, 2.9897]
# test:  145  ground_truth:  [ 0.9841 -0.0118 -3.2415]  predicted:  [0.9992, -0.0134, -1.1401]
# test:  146  ground_truth:  [-0.9112 -0.4094 37.8174]  predicted:  [-0.9629, -0.3689, 34.2292]
# test:  147  ground_truth:  [0.2521 0.0068 3.302 ]  predicted:  [0.2552, 0.0026, 3.4945]
# test:  148  ground_truth:  [-0.8201  0.1622  5.2169]  predicted:  [-0.9086, 0.0136, 7.334]
# test:  149  ground_truth:  [ -0.5119   0.1366 -46.8667]  predicted:  [-0.6001, 0.1743, -46.8774]
# test:  150  ground_truth:  [ 0.      0.     18.6725]  predicted:  [0.144, 0.0187, 16.5855]
# test:  151  ground_truth:  [-0.2837 -0.0236 11.3199]  predicted:  [-0.5252, -0.0483, 12.3435]
# test:  152  ground_truth:  [-0.972  -0.1246 54.0174]  predicted:  [-0.1871, -0.1617, -4.1072]
# test:  153  ground_truth:  [-0.1699 -0.0004  0.2404]  predicted:  [-0.1854, -0.0033, -0.0488]
# test:  154  ground_truth:  [-0.5647 -0.0008  0.1996]  predicted:  [-0.4554, 0.0005, -0.2077]
# test:  155  ground_truth:  [0.2465 0.0011 0.4854]  predicted:  [0.2519, -0.0018, 0.1232]
# test:  156  ground_truth:  [-1.0354  0.123  -6.0254]  predicted:  [-1.0751, 0.0522, 0.0493]
# test:  157  ground_truth:  [  0.2697  -0.0606 -23.5517]  predicted:  [0.3793, -0.0705, -24.4067]
# test:  158  ground_truth:  [ 0.1648 -0.0033  2.6781]  predicted:  [0.191, -0.0021, 1.2875]
# test:  159  ground_truth:  [-0.2594  0.0011 -0.5106]  predicted:  [-0.2845, -0.0037, 0.0693]
# test:  160  ground_truth:  [-1.46000e-02  1.70000e-03 -1.24359e+01]  predicted:  [-0.0248, 0.0008, -12.0023]
# test:  161  ground_truth:  [-0.2055  0.0007 -0.381 ]  predicted:  [-0.2192, -0.0044, 0.1702]
# test:  162  ground_truth:  [-3.2000e-02  9.2000e-03 -3.7312e+01]  predicted:  [0.0451, -0.0035, -34.8909]
# test:  163  ground_truth:  [7.1200e-02 1.0000e-03 1.2575e+00]  predicted:  [0.1181, -0.0017, 1.4912]
# test:  164  ground_truth:  [ 0.899   0.4094 35.608 ]  predicted:  [0.3719, 0.1069, 33.9492]
# test:  165  ground_truth:  [ -0.684    0.2836 -38.4792]  predicted:  [-0.5425, 0.1709, -36.879]
# test:  166  ground_truth:  [0.9633 0.0711 4.6891]  predicted:  [0.9146, 0.0075, 1.7038]
# test:  167  ground_truth:  [ -0.9428   0.3238 -38.2702]  predicted:  [-0.8129, 0.2292, -31.6055]
# test:  168  ground_truth:  [ -1.0868   0.0554 -18.9561]  predicted:  [-0.7391, 0.0784, -19.1561]
# test:  169  ground_truth:  [-1.0132 -0.181  30.138 ]  predicted:  [-0.8901, -0.16, 25.8013]
# test:  170  ground_truth:  [ 0.8806 -0.0234 -2.7837]  predicted:  [0.6962, -0.0218, -4.0734]
# test:  171  ground_truth:  [ 0.2452 -0.0115 -4.4548]  predicted:  [0.2154, -0.0072, -5.2467]
# test:  172  ground_truth:  [ 0.5246 -0.003  -0.3563]  predicted:  [0.4364, -0.0037, -0.0582]
# test:  173  ground_truth:  [-0.2937 -0.0041  0.1538]  predicted:  [-0.2994, -0.0052, 0.187]
# test:  174  ground_truth:  [-2.584e-01 -1.000e-04  1.905e-01]  predicted:  [-0.2285, -0.0044, -0.3025]
# test:  175  ground_truth:  [0.2599 0.0215 8.4132]  predicted:  [0.1861, 0.0182, 11.4254]
# test:  176  ground_truth:  [ 0.      0.     17.4393]  predicted:  [0.0038, -0.0003, 16.5808]
# test:  177  ground_truth:  [ 1.9480e-01 -7.1000e-03 -8.5297e+00]  predicted:  [0.2659, -0.0167, -9.0041]
# test:  178  ground_truth:  [-0.9196  0.031  -5.9287]  predicted:  [-0.8407, 0.0067, -4.7939]
# test:  179  ground_truth:  [-0.5184 -0.2515 51.1297]  predicted:  [-0.5069, -0.2004, 48.3903]
# test:  180  ground_truth:  [-0.2677 -0.0009  0.8051]  predicted:  [-0.2492, -0.0049, 0.305]
# test:  181  ground_truth:  [ 0.9456  0.4423 41.6082]  predicted:  [0.8533, 0.292, 35.6264]
# test:  182  ground_truth:  [-0.2512  0.0067 -3.0466]  predicted:  [-0.2311, -0.0011, -2.22]
# test:  183  ground_truth:  [0.5463 0.0046 2.5625]  predicted:  [0.4862, 0.0026, 1.3354]
# test:  184  ground_truth:  [-0.5369 -0.0036  0.76  ]  predicted:  [-0.4286, -0.0026, 0.3181]
# test:  185  ground_truth:  [ 0.0739 -0.0007 -0.4546]  predicted:  [0.0595, -0.0023, -0.752]
# test:  186  ground_truth:  [-5.749e-01 -1.000e-04  9.340e-02]  predicted:  [-0.4499, 0.0004, -0.5293]
# test:  187  ground_truth:  [0.5333 0.0443 9.2176]  predicted:  [0.6498, 0.0562, 8.7119]
# test:  188  ground_truth:  [-0.554   0.048  -9.5007]  predicted:  [-0.5211, 0.0346, -8.472]
# test:  189  ground_truth:  [-0.5268 -0.0611  9.2533]  predicted:  [-0.5118, -0.0552, 10.5568]
# test:  190  ground_truth:  [ 2.572e-01  1.000e-04 -3.514e-01]  predicted:  [0.2488, -0.0057, -1.0898]
# test:  191  ground_truth:  [-1.0000e-03 -2.0000e-04  2.1189e+01]  predicted:  [0.0188, 0.0009, 19.8164]
# test:  192  ground_truth:  [  0.6152  -0.4509 -49.407 ]  predicted:  [0.1755, -0.0809, -37.2292]
# test:  193  ground_truth:  [-0.9802 -0.4147 37.3953]  predicted:  [-0.9338, -0.361, 37.2726]
# test:  194  ground_truth:  [-0.5898  0.0063 -1.233 ]  predicted:  [-0.4989, 0.003, -0.332]
# test:  195  ground_truth:  [ 0.4058 -0.0033  1.0943]  predicted:  [0.3486, -0.0043, 0.4984]
# test:  196  ground_truth:  [  0.4075  -0.2209 -37.2315]  predicted:  [-0.2443, -0.0717, -17.8439]
# test:  197  ground_truth:  [  0.9643  -0.0917 -25.9625]  predicted:  [0.6486, -0.1565, -28.155]
# test:  198  ground_truth:  [-0.2935 -0.0046 -2.9171]  predicted:  [-0.1819, -0.0018, -2.6967]
# test:  199  ground_truth:  [ 1.1769 -0.0079  1.3814]  predicted:  [1.2929, 0.0442, 4.9222]

# %%
t=range(nSamples)
plt.figure()
plt.subplot(311)
plt.plot(t, predict_list[:,0], color='orange')
plt.plot(t, y_testing_ground_truth3[0:nSamples,0], color='black',linestyle='--')
plt.ylabel('$\Delta x$')

plt.subplot(312)
plt.plot(t, predict_list[:,1], color='green')
plt.plot(t, y_testing_ground_truth3[0:nSamples,1], color='black',linestyle='--')
plt.ylabel('$\Delta y$')

plt.subplot(313)
plt.plot(t, predict_list[:,2], color='blue')
plt.plot(t, y_testing_ground_truth3[0:nSamples,2], color='black',linestyle='--')
plt.ylabel('$\Delta \Theta$')
#plt.legend(['predicted','ground_truth'])
plt.show()

# %%
# errors
t=range(nSamples)
plt.figure()
plt.subplot(311)
plt.plot(t, predict_list[:,0]-y_testing_ground_truth3[0:nSamples,0], color='orange')
plt.ylabel('$\Delta x$')

plt.subplot(312)
plt.plot(t, predict_list[:,1]-y_testing_ground_truth3[0:nSamples,1], color='green')
plt.ylabel('$\Delta y$')

plt.subplot(313)
plt.plot(t, predict_list[:,2]-y_testing_ground_truth3[0:nSamples,2], color='blue')
plt.ylabel('$\Delta \Theta$')
#plt.legend(['predicted','ground_truth'])
plt.show()

# %% [markdown]
# ## with additional sensor noise

# %%
x_testing2_noise=x_testing2+np.random.normal(0,0.05,np.shape(x_testing2))
testing_dataset_noise = tf.data.Dataset.from_tensor_slices((x_testing2_noise, (y_testing2[:,0:2],y_testing2[:,2]))).batch(BATCH_SIZE)
model.evaluate(testing_dataset_noise)
# Out:
# 580/580 [==============================] - 2s 3ms/step - loss: 1.3748 - pose_loss: 0.0249 - rotation_loss: 22.5113 - pose_mean_absolute_error: 0.0813 - rotation_mean_absolute_error: 1.8953
# [1.3748443126678467,
#  0.024927804246544838,
#  22.511335372924805,
#  0.08133412897586823,
#  1.8953410387039185]

# %% [markdown]
# ## Visualize feature map

# %%
# kernels in first conv layer
filters, biases = model.layers[1].get_weights()
print(np.shape(filters))
square = 8
ix = 1
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.plot(filters[:,0,ix-1])
		ix += 1
# show the figure
plt.show()

# %%
# define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)
# run our image through our network, thus obtaining all
# intermediate representations for this range data.
successive_feature_maps = visualization_model.predict(x_training[0:5])
# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers]
visualization_model = Model(inputs=model.inputs, outputs=model.layers[1].output)
feature_maps = visualization_model.predict(np.expand_dims(x_training[500], axis=0))
square = 8
ix = 1
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.plot(feature_maps[0, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## Odometry-based Localization

# %%
# !gdown --id 1Jq9xPARjAEY8DmJL0Q5uvFSOVHo-bwkf #simple wall
#!gdown --id 1IyOf-VK_8eqDl00seI36Eo_FIcThVqio #simple maze:
world_name = 'simple_wall'
local_zip = 'test_'+world_name+'.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('test_'+world_name)
zip_ref.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Jq9xPARjAEY8DmJL0Q5uvFSOVHo-bwkf
# To: /content/test_simple_wall.zip
# 100% 1.66M/1.66M [00:00<00:00, 107MB/s]

# %%
with open('test_'+world_name+'/test_simple_range_pairs_3.pickle', 'rb') as handle:
    test_simple_range_pairs = pickle.load(handle)

with open('test_'+world_name+'/test_simple_pose_rels_3.pickle', 'rb') as handle:
    test_simple_pose_rels = pickle.load(handle)
test_simple_range_pairs = np.swapaxes(test_simple_range_pairs, 1, 2)
test_simple_range_pairs = test_simple_range_pairs[:,::2,:]
test_simple_range_pairs = laser_compression(test_simple_range_pairs[:,90:451,:],Flag_compression,Karaman_method)
test_simple_translation_rels=test_simple_pose_rels[:,0:2]
test_simple_rotation_rels=test_simple_pose_rels[:,2]
print("size of range_pairs: ", test_simple_range_pairs.shape)
print("size of pose_rels: ", test_simple_translation_rels.shape)
print("size of rotation_rels: ", test_simple_rotation_rels.shape)
# Out:
# size of range_pairs_compressed:  (243, 361, 3)
# size of range_pairs:  (243, 361, 3)
# size of pose_rels:  (243, 2)
# size of rotation_rels:  (243,)

# %%
from matplotlib.animation import FuncAnimation
def rels_to_abs(pose_rels):
    pose_i = np.array([[0],[0]])
    poses = pose_i.T
    theta_i = 0.0
    for i in range(pose_rels.shape[0]):
        [rels_x,rels_y,rels_theta] = pose_rels[i,0:3]
        T_matrix = np.array([[np.cos(theta_i),-np.sin(theta_i)],[np.sin(theta_i),np.cos(theta_i)]])
        pose_ic =np.dot(T_matrix,np.array([[rels_x],[rels_y]]))+pose_i
        poses = np.concatenate((poses,pose_ic.T))
        pose_i = pose_ic
        if isinstance(rels_theta,np.ndarray):
          theta_i += rels_theta[0,0]
        else:
          theta_i += rels_theta
    return poses

dataSet = rels_to_abs(np.array(test_simple_pose_rels))
plt.plot(dataSet[:,0],dataSet[:,1], 'C3', lw=1)
plt.scatter(dataSet[:,0],dataSet[:,1], s=1)

# %%
from matplotlib.animation import FuncAnimation
test_pose_predict=model.predict(test_simple_range_pairs[0:-1,:])
predict_test_translation_value = np.array(test_pose_predict[0])
predict_test_rotation_value=np.expand_dims(np.array(tf.squeeze(test_pose_predict[1])), axis=1)*np.pi/180
predict_test_pose = np.concatenate((predict_test_translation_value,predict_test_rotation_value),axis=-1)
dataSet_estimate = rels_to_abs(np.array(predict_test_pose))
# dataSet_ground_truth = rels_to_abs(np.array(test_simple_pose_rels))
plt.plot(dataSet_estimate[:,0],dataSet_estimate[:,1], 'C3', lw=1)
plt.scatter(dataSet_estimate[:,0],dataSet_estimate[:,1], s=1)

# %% [markdown]
# compare ground-truth trajectory with predicted trajector

# %%
plt.plot(dataSet[:,0],dataSet[:,1], 'C3', lw=1, label='true')
plt.scatter(dataSet[:,0],dataSet[:,1], s=1)

plt.plot(dataSet_estimate[:,0],dataSet_estimate[:,1], 'C10', lw=1, label='estimate')
plt.scatter(dataSet_estimate[:,0],dataSet_estimate[:,1], s=1)

plt.legend(loc='upper right')

# %%
for i in range(100):
  predict_i=list(np.round(predict_test_translation_value[i],4))
  predict_i.append(np.round(np.float(predict_test_rotation_value[i]),4))
  if i%1==0:
    print("test: ", i, " ground_truth: ", np.round(np.double(test_simple_pose_rels[i,:]),4),
          " predicted: ",predict_i)
# Out:
# test:  0  ground_truth:  [-0. -0.  0.]  predicted:  [-0.003, -0.0002, 0.0144]
# test:  1  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0035, -1e-04, 0.008]
# test:  2  ground_truth:  [0. 0. 0.]  predicted:  [-0.003, -1e-04, -0.0112]
# test:  3  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0028, -0.0002, -0.0034]
# test:  4  ground_truth:  [-0. -0.  0.]  predicted:  [-0.003, -0.0002, 0.0054]
# test:  5  ground_truth:  [0. 0. 0.]  predicted:  [-0.0033, -1e-04, -0.0133]
# test:  6  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0043, -1e-04, 0.0136]
# test:  7  ground_truth:  [-0. -0.  0.]  predicted:  [0.0012, -0.0004, 0.0137]
# test:  8  ground_truth:  [0. 0. 0.]  predicted:  [0.0012, -0.0003, 0.0173]
# test:  9  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0026, -0.0002, -0.0031]
# test:  10  ground_truth:  [0. 0. 0.]  predicted:  [-0.0002, -0.0003, 0.0171]
# test:  11  ground_truth:  [-0.  0.  0.]  predicted:  [-0.005, -1e-04, -0.0045]
# test:  12  ground_truth:  [-0. -0.  0.]  predicted:  [-0.004, -1e-04, 0.0002]
# test:  13  ground_truth:  [0. 0. 0.]  predicted:  [-0.002, -0.0002, 0.0]
# test:  14  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0057, -0.0, -0.005]
# test:  15  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0021, -0.0002, 0.013]
# test:  16  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0079, 0.0, -0.0011]
# test:  17  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0011, -0.0002, 0.0087]
# test:  18  ground_truth:  [-0. -0.  0.]  predicted:  [-0.004, -1e-04, 0.0085]
# test:  19  ground_truth:  [0. 0. 0.]  predicted:  [-0.0015, -0.0002, 0.0107]
# test:  20  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0028, -0.0002, 0.0091]
# test:  21  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0038, -1e-04, 0.0043]
# test:  22  ground_truth:  [-0. -0.  0.]  predicted:  [0.003, -0.0005, 0.0231]
# test:  23  ground_truth:  [0. 0. 0.]  predicted:  [-0.0034, -1e-04, 0.0007]
# test:  24  ground_truth:  [-0.  0.  0.]  predicted:  [0.001, -0.0003, 0.0266]
# test:  25  ground_truth:  [-0. -0.  0.]  predicted:  [0.0006, -0.0003, 0.0315]
# test:  26  ground_truth:  [-0. -0.  0.]  predicted:  [1e-04, -0.0003, 0.0074]
# test:  27  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0058, -0.0, 0.0006]
# test:  28  ground_truth:  [0. 0. 0.]  predicted:  [-0.0034, -1e-04, 0.0011]
# test:  29  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0032, -1e-04, 0.0031]
# test:  30  ground_truth:  [ 0. -0.  0.]  predicted:  [0.0027, -0.0004, 0.0208]
# test:  31  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0042, -1e-04, -0.0024]
# test:  32  ground_truth:  [0. 0. 0.]  predicted:  [-0.0045, -1e-04, 0.0066]
# test:  33  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0021, -0.0002, 0.0265]
# test:  34  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0013, -0.0003, 0.0087]
# test:  35  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0004, -0.0003, -0.0037]
# test:  36  ground_truth:  [0. 0. 0.]  predicted:  [-0.005, -1e-04, 0.0007]
# test:  37  ground_truth:  [-0. -0.  0.]  predicted:  [-0.004, -1e-04, -0.0021]
# test:  38  ground_truth:  [0. 0. 0.]  predicted:  [-0.0028, -0.0002, -0.0021]
# test:  39  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0023, -0.0002, 0.0329]
# test:  40  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0006, -0.0002, 0.0011]
# test:  41  ground_truth:  [0. 0. 0.]  predicted:  [-0.0035, -1e-04, 0.0167]
# test:  42  ground_truth:  [ 0.0182 -0.0027 -0.3072]  predicted:  [0.0081, -0.0018, -0.3437]
# test:  43  ground_truth:  [ 0.014  -0.0017 -0.2515]  predicted:  [0.0103, -0.0013, -0.2062]
# test:  44  ground_truth:  [-0. -0.  0.]  predicted:  [0.0003, -0.0004, 0.006]
# test:  45  ground_truth:  [ 0.0275 -0.0045 -0.2918]  predicted:  [-0.0077, -0.0007, -0.2951]
# test:  46  ground_truth:  [ 0.0321 -0.0042 -0.2798]  predicted:  [0.0046, -0.0011, -0.2105]
# test:  47  ground_truth:  [-0.      0.     -0.0003]  predicted:  [0.0051, -0.0005, -0.0717]
# test:  48  ground_truth:  [ 0.0347 -0.0069 -0.3357]  predicted:  [0.0035, -0.0019, -0.2898]
# test:  49  ground_truth:  [ 0.0448 -0.0076 -0.4093]  predicted:  [-0.0087, -0.0008, -0.3064]
# test:  50  ground_truth:  [ 0.0166 -0.0028 -0.3372]  predicted:  [0.0114, -0.0046, -0.3208]
# test:  51  ground_truth:  [ 0.0383 -0.0071 -0.3401]  predicted:  [0.0407, -0.0107, -0.3613]
# test:  52  ground_truth:  [ 0.0607 -0.0121 -0.3602]  predicted:  [-0.0091, -0.0009, -0.2825]
# test:  53  ground_truth:  [ 0.0955 -0.0174 -0.3613]  predicted:  [0.1477, -0.0335, -0.362]
# test:  54  ground_truth:  [ 0.1278 -0.0239 -0.3485]  predicted:  [0.0282, -0.0055, -0.3325]
# test:  55  ground_truth:  [ 0.1633 -0.022  -0.239 ]  predicted:  [0.0172, -0.0048, -0.2345]
# test:  56  ground_truth:  [ 0.1888 -0.0178 -0.183 ]  predicted:  [0.1338, -0.0099, -0.1664]
# test:  57  ground_truth:  [ 0.1661 -0.009  -0.1165]  predicted:  [0.1611, -0.0084, -0.1267]
# test:  58  ground_truth:  [ 0.2048 -0.0134 -0.1374]  predicted:  [0.1673, -0.0062, -0.109]
# test:  59  ground_truth:  [0.0133 0.0013 0.1355]  predicted:  [0.0151, 0.0005, 0.0873]
# test:  60  ground_truth:  [0.0288 0.0019 0.1174]  predicted:  [0.0264, 0.0017, 0.1104]
# test:  61  ground_truth:  [0.0446 0.0033 0.1367]  predicted:  [0.0486, 0.0038, 0.1396]
# test:  62  ground_truth:  [0.0905 0.0075 0.1554]  predicted:  [0.1041, 0.0111, 0.1624]
# test:  63  ground_truth:  [0.1189 0.0099 0.1556]  predicted:  [0.196, 0.0159, 0.1753]
# test:  64  ground_truth:  [0.1337 0.0087 0.1303]  predicted:  [0.1416, 0.0068, 0.1567]
# test:  65  ground_truth:  [0.1632 0.012  0.142 ]  predicted:  [0.1331, 0.0058, 0.149]
# test:  66  ground_truth:  [0.1642 0.0099 0.1168]  predicted:  [0.1914, 0.0013, 0.1196]
# test:  67  ground_truth:  [0.1387 0.0021 0.03  ]  predicted:  [0.1835, -0.0044, 0.0404]
# test:  68  ground_truth:  [0.1631 0.0009 0.0054]  predicted:  [0.2138, -0.0036, 0.0063]
# test:  69  ground_truth:  [ 0.1566 -0.0004 -0.0077]  predicted:  [0.1725, -0.0039, -0.0131]
# test:  70  ground_truth:  [ 0.1578 -0.0018 -0.0237]  predicted:  [0.1807, -0.0033, -0.0351]
# test:  71  ground_truth:  [ 0.1648 -0.0066 -0.08  ]  predicted:  [0.1796, -0.0082, -0.0917]
# test:  72  ground_truth:  [ 0.1691 -0.0075 -0.0995]  predicted:  [0.191, -0.0092, -0.105]
# test:  73  ground_truth:  [ 0.195  -0.016  -0.1711]  predicted:  [0.2423, -0.02, -0.1962]
# test:  74  ground_truth:  [ 0.1559 -0.0139 -0.275 ]  predicted:  [0.1614, -0.0159, -0.2398]
# test:  75  ground_truth:  [0.0035 0.     0.0104]  predicted:  [-0.0059, -0.001, 0.0376]
# test:  76  ground_truth:  [0.0271 0.0019 0.14  ]  predicted:  [0.0141, -0.0004, 0.1552]
# test:  77  ground_truth:  [0.0027 0.     0.0199]  predicted:  [0.0022, -0.0004, 0.0081]
# test:  78  ground_truth:  [0.0058 0.0001 0.0232]  predicted:  [0.0034, -0.0004, 0.043]
# test:  79  ground_truth:  [0.0183 0.0008 0.1003]  predicted:  [0.0034, -0.0004, 0.094]
# test:  80  ground_truth:  [0.     0.     0.1197]  predicted:  [0.0032, -0.0004, 0.1238]
# test:  81  ground_truth:  [ 0.     -0.      0.1273]  predicted:  [-0.0149, 0.0005, 0.1393]
# test:  82  ground_truth:  [0.0113 0.0006 0.0146]  predicted:  [0.0102, -0.0022, 0.0015]
# test:  83  ground_truth:  [ 0.0539 -0.001  -0.004 ]  predicted:  [0.0512, -0.0028, -0.0001]
# test:  84  ground_truth:  [ 0.0771 -0.0036 -0.1428]  predicted:  [0.0456, -0.0032, -0.1067]
# test:  85  ground_truth:  [ 0.0927 -0.0148 -0.3172]  predicted:  [0.0858, -0.0136, -0.4129]
# test:  86  ground_truth:  [ 0.1196 -0.0191 -0.3123]  predicted:  [0.0595, -0.0103, -0.3604]
# test:  87  ground_truth:  [ 0.1606 -0.0236 -0.2727]  predicted:  [0.0815, -0.0075, -0.2625]
# test:  88  ground_truth:  [ 0.2104 -0.0389 -0.3556]  predicted:  [0.1496, -0.0275, -0.3446]
# test:  89  ground_truth:  [ 0.1743 -0.0206 -0.2305]  predicted:  [0.1788, -0.0361, -0.2975]
# test:  90  ground_truth:  [ 0.2533 -0.0369 -0.2603]  predicted:  [0.191, -0.0086, -0.1992]
# test:  91  ground_truth:  [ 0.1926 -0.0131 -0.123 ]  predicted:  [0.2138, -0.0066, -0.1414]
# test:  92  ground_truth:  [ 0.1989 -0.0076 -0.0791]  predicted:  [0.2022, -0.0056, -0.0907]
# test:  93  ground_truth:  [ 0.0007 -0.      0.0166]  predicted:  [0.0143, -0.0011, 0.0023]
# test:  94  ground_truth:  [-0.     -0.     -0.2302]  predicted:  [0.0024, -0.0028, -0.2331]
# test:  95  ground_truth:  [-0.      0.     -0.3534]  predicted:  [0.1531, -0.0329, -0.3531]
# test:  96  ground_truth:  [ 0.     -0.     -0.3578]  predicted:  [0.1477, -0.0327, -0.3988]
# test:  97  ground_truth:  [ 0.0064 -0.0018 -0.3263]  predicted:  [0.0487, -0.0067, -0.3738]
# test:  98  ground_truth:  [ 0.0289 -0.0061 -0.3693]  predicted:  [0.0594, -0.0115, -0.3745]
# test:  99  ground_truth:  [ 0.0555 -0.0104 -0.3461]  predicted:  [0.008, -0.002, -0.3585]

# %% [markdown]
# # Section 5: Load Saved Model

# %%
model.save_weights('./model_weights_0404_361samples/base_model_weights', save_format='tf')
# !zip -r model_weights_0404_361samples.zip model_weights_0404_361samples/

# %%
from google.colab import files
files.download('model_weights_0404_361samples.zip')
