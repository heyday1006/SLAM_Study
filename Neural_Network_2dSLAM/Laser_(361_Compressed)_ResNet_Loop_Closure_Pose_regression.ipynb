# %% [markdown]
# <a href="https://colab.research.google.com/github/heyday1006/2D-Lidar-DNN/blob/main/Laser_(361_Compressed)_ResNet_Loop_Closure_Pose_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import os, re, math, json, shutil, pprint
import PIL.Image, PIL.ImageFont, PIL.ImageDraw
import IPython.display as display
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.4.1

# %% [markdown]
# # Section 1: Data Extraction

# %% [markdown]
# Data is saved to multiple csv files.

# %%
# !gdown --id 1kMnzpnvonfZg-WBuzCO9QXhCRFb-6KXG #174lnAK9zW-L-vI7BgQPc42mVcVo7VWuv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1kMnzpnvonfZg-WBuzCO9QXhCRFb-6KXG
# To: /content/pose0220.zip
# 1.43GB [00:06, 224MB/s]

# %%
import zipfile
dir_name='pose0220' #'data_pickle.zip'
local_zip = dir_name+'.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall(dir_name)
zip_ref.close()

# %%
# !pip3 install pickle5
# Out:
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.11)

# %%
import pickle5 as pickle
def read_from_pickle(dir_name,type_name):
  with open(dir_name+'/'+dir_name+'/'+type_name+'_range_pairs.pickle', 'rb') as handle:
      range_pairs_all = pickle.load(handle)

  with open(dir_name+'/'+dir_name+'/'+type_name+'_pose_rels.pickle', 'rb') as handle:
      pose_rels_all = pickle.load(handle)
  range_pairs = np.swapaxes(range_pairs_all, 1, 2)
  translation_rels=np.round(np.double(pose_rels_all[:,0:2]),4)
  rotation_rels=np.double(pose_rels_all[:,2])
  range_pairs = range_pairs[:,::2,:]
  range_pairs = range_pairs[:,90:451,:]
  print("for %s dataset",type_name)
  print("size of range_pairs: ", range_pairs.shape)
  print("size of pose_rels: ", translation_rels.shape)
  print("size of rotation_rels: ", rotation_rels.shape)
  print("<------------->")
  return range_pairs,translation_rels,rotation_rels

range_pairs,pose_rels,rotation_rels = read_from_pickle(dir_name,'train')
# Out:
# for %s dataset train
# size of range_pairs:  (147344, 361, 2)
# size of pose_rels:  (147344, 2)
# size of rotation_rels:  (147344,)
# <------------->

# %% [markdown]
# ## Remove inbalanced values

# %%
#too many zeros!!!
from numpy import linalg as LA
import math
# range_pairs = np.double(np.swapaxes(range_pairs_all, 1, 2))
# pose_rels=np.double(pose_rels_all[:,0:2])
# rotation_rels=np.double(pose_rels_all[:,2])

pose_rels_norm=LA.norm(pose_rels, axis=1)
nonzeros_indices=np.where((pose_rels_norm>1e-4) | (np.abs(rotation_rels)>1e-4))
nonfar_indices=np.where((rotation_rels<=1.0) & (rotation_rels>=-1.0) )
chosen_indices=np.intersect1d(nonzeros_indices,nonfar_indices)
pose_rels=pose_rels[chosen_indices]
rotation_rels=rotation_rels[chosen_indices]
range_pairs=range_pairs[chosen_indices]
print("size of pose_rels: ", pose_rels.shape)
# Out:
# size of pose_rels:  (127570, 2)

# %% [markdown]
# ## Convert to grid coordinates

# %%
print(min(pose_rels[:,0]),max(pose_rels[:,0]))
print(min(pose_rels[:,1]),max(pose_rels[:,1]))
#discretize the values
grid_offset=np.array([-1.8,-1.2])
grid_spacing=np.array([0.05,0.05])
grid_indices=np.round((np.array(pose_rels)-grid_offset)/grid_spacing)
pose_rels_grid=np.array(grid_indices)
print(np.shape(pose_rels_grid))
pose_rels_grid=pose_rels_grid.astype(int)
# Out:
# -1.7247 1.6685
# -0.9242 0.7726
# (127570, 2)

# %%
# with rotations
rotation_gridspace=0.5
rotation_rels=np.round(np.double(rotation_rels*180/math.pi),4)
rotation_rels_grid=np.array(np.round((np.array(rotation_rels)-np.array([-1.0*180/math.pi]))/rotation_gridspace))
rotation_rels_grid=rotation_rels_grid.astype(int)

# %% [markdown]
# ## Check discretized label distributions

# %% [markdown]
# Visualize the distribution of discretized values

# %%
pose_rels_1d=pose_rels_grid[:,0]*(np.max(pose_rels_grid[:,1])+1)+pose_rels_grid[:,1]
pose_rels_1d_bincount=np.bincount((pose_rels_1d).astype(int))
x_dim=np.int(np.max(pose_rels_grid[:,0])+1)
y_dim=np.int(np.max(pose_rels_grid[:,1])+1)
pose_rels_1d_bincount_full=np.zeros(x_dim*y_dim)
pose_rels_1d_bincount_full[:len(pose_rels_1d_bincount)]=pose_rels_1d_bincount
print(x_dim,y_dim,np.shape(pose_rels_1d_bincount))
pose_rels_2d_bincount=np.reshape(pose_rels_1d_bincount_full, [x_dim,-1], order='C')
#setup the 2D grid with Numpy
x_grid, y_grid = np.meshgrid(np.arange(-1.8,1.7,0.05), np.arange(-1.2,0.8,0.05))
#convert intensity (list of lists) to a numpy array for plotting
intensity = np.array(pose_rels_2d_bincount)
#now just plug the data into pcolormesh, it's that easy!
plt.pcolormesh(x_grid, y_grid, np.swapaxes(intensity,0,1))
plt.colorbar() #need a colorbar to show the intensity scale
plt.show() #boom
# Out:
# 70 40 (2786,)

# %%
#rotation
plt.hist(rotation_rels_grid,bins=20);

# %%
pose_rels_grid=pose_rels_1d
print(np.max(pose_rels_grid))
print(np.max(rotation_rels_grid))
# Out:
# 2785
# 229

# %% [markdown]
# ## Compressive Sensing

# %%
x=np.array([[1,2,3],[3,4,5]])
y=np.array([0,1])
mask = np.ones(x.shape,dtype=bool) #np.ones_like(a,dtype=bool)
mask[:,y] = False
x[mask] = 999
print(x)
# Out:
# [[  1   2 999]
#  [  3   4 999]]

# %%
import random
Flag_compression=True
Karaman_method = False
def laser_compression(range_pairs,Flag_compression,Karaman_method):
  if Flag_compression:
    percent_compressed=0.5
    range_pairs_compressed=np.array(range_pairs.copy())#=range_pairs[:,indices,:]
    mask=np.ones(range_pairs_compressed.shape,dtype=bool)
    if Karaman_method:
      indices_pre=np.array(random.sample(range(1,539),np.int(1079*percent_compresed/2)))
      indices_pre=np.append(2*indices_pre,2*indices_pre+1)
      print(np.shape(indices_pre))
      indices=np.array(np.append(1,np.sort(indices_pre),1081))
      mask[:,indices,:]=Fals
    else:
      for irow in range(2):
        for isample in range(range_pairs_compressed.shape[0]):
          indices=np.random.choice(range(361),np.int(361*percent_compressed))
          # print(indices)
          mask[isample,indices,irow]=False
    range_pairs_compressed[mask]=0
  else:
    range_pairs_compressed=range_pairs

  print("size of range_pairs_compressed: ", range_pairs_compressed.shape)
  return range_pairs_compressed
range_pairs_compressed = laser_compression(range_pairs,Flag_compression,Karaman_method)
# Out:
# size of range_pairs_compressed:  (127570, 361, 2)

# %%
plt.figure(1)
plt.subplot(211)
plt.scatter([range(361)], [range_pairs[1,:,0]], s=0.1, label="original")
plt.subplot(212)
plt.scatter([range(361)], [range_pairs_compressed[1,:,0]], s=0.1, label="compressive")
# if Flag_compression:
#   for xc in indices:
#     plt.axvline(x=xc,c='r',linewidth=0.1,linestyle='-.')
    
plt.show()

# %% [markdown]
# # Section 2: Data Preparation

# %%
print(range_pairs[:,:,1].shape)
add_compression_network = True
# Out:
# (127570, 361)

# %%
from sklearn.utils import shuffle
#pose_rels_grid_all=np.hstack((np.expand_dims(pose_rels_grid, axis=1),np.expand_dims(rotation_rels, axis=1)))
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

pose_rels_value_all=np.hstack((sigmoid(pose_rels),np.expand_dims(sigmoid(rotation_rels), axis=1)))
# pose_rels_value_all = range_pairs
# xs, ys = shuffle(range_pairs_compressed, pose_rels_value_all)
xs, ys_range, ys_pose = shuffle(sigmoid(range_pairs_compressed), sigmoid(np.clip(range_pairs, a_min=None, a_max=40)), pose_rels_value_all)

percent_of_trainSet=0.99*0.85
percent_of_validationSet=0.99*0.15
percent_of_testSet=0.01
num_of_trainSet=np.int(ys_range.shape[0]*percent_of_trainSet)
num_of_validationSet=np.int(ys_range.shape[0]*percent_of_validationSet)
num_of_testSet=np.int(ys_range.shape[0]*percent_of_testSet)

x_training = np.array(xs[0:num_of_trainSet], dtype=float)
y_range_training = np.array(ys_range[0:num_of_trainSet], dtype=float)
y_pose_training = np.array(ys_pose[0:num_of_trainSet], dtype=float)
# y_training_ground_truth = np.array(ys_ground_truth[0:num_of_trainSet], dtype=float)
print('Size of training data: ', x_training.shape)
print('Size of training labels: ',y_pose_training.shape)

x_validation = np.array(xs[num_of_trainSet:num_of_trainSet+num_of_validationSet], dtype=float)
y_range_validation = np.array(ys_range[num_of_trainSet:num_of_trainSet+num_of_validationSet], dtype=float)
y_pose_validation = np.array(ys_pose[num_of_trainSet:num_of_trainSet+num_of_validationSet], dtype=float)
# y_validation_ground_truth = np.array(ys_ground_truth[num_of_trainSet:num_of_trainSet+num_of_validationSet], dtype=float)
print('Size of validation data: ', x_validation.shape)
print('Size of validation labels: ',y_pose_validation.shape)

x_testing = np.array(xs[num_of_trainSet+num_of_validationSet:], dtype=float)
y_range_testing = np.array(ys_range[num_of_trainSet+num_of_validationSet:], dtype=float)
y_pose_testing = np.array(ys_pose[num_of_trainSet+num_of_validationSet:], dtype=float)
# y_testing_ground_truth=np.array(ys_ground_truth[num_of_trainSet+num_of_validationSet:], dtype=float)
print('Size of testing data: ', x_testing.shape)
print('Size of testing labels: ',y_pose_testing.shape)
# Out:
# Size of training data:  (107350, 361, 2)
# Size of training labels:  (107350, 3)
# Size of validation data:  (18944, 361, 2)
# Size of validation labels:  (18944, 3)
# Size of testing data:  (1276, 361, 2)
# Size of testing labels:  (1276, 3)

# %%
plt.figure(1)
plt.subplot(211)
plt.scatter([range(361)], [x_training[1,:,0]], s=0.1, label="original")
plt.subplot(212)
plt.scatter([range(361)], [y_range_training[1,:,0]], s=0.1, label="compressive")
# if Flag_compression:
#   for xc in indices:
#     plt.axvline(x=xc,c='r',linewidth=0.1,linestyle='-.')
    
plt.show()

# %% [markdown]
# # Section 3: Model Traning

# %%
# from tensorflow.keras.layers import Input, Conv1D, Activation, MaxPooling1D, Add, AveragePooling1D, Dense, Dropout, Flatten
# from tensorflow.keras import Model
# BATCH_SIZE = 32
# def residual_block(x):
#       temp = x
#       x = Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(x)
#       x = Conv1D(filters=16, kernel_size=3, padding='same')(x)
#       x = Add()([Activation('relu')(x), temp])
#       return x
# def Res1DFlat_easy(dropout_rate,input_shape,add_compression_network):
#   # input size = (batch_size, 2, 1081)
#   input_data = Input(shape=input_shape)
#   x= Conv1D(filters=16, kernel_size=7,activation='relu', padding='same')(input_data)
#   x=residual_block(x)
#   x=residual_block(x)
#   output2= Conv1D(filters=2, kernel_size=7, activation='relu', padding='same')(x)
#   model = Model(inputs=input_data, outputs=output2)
#   return model      
# dropout_rate=0.0
# optimizer_lr=0.001
# model = Res1DFlat_easy(dropout_rate,np.shape(x_training[0]),add_compression_network)
# optimizer = tf.keras.optimizers.Adam(optimizer_lr)

# model.compile(optimizer=optimizer,
#             loss= keras.losses.mse,#sparse_categorical_crossentropy,losses.mse},
#             metrics=tf.keras.metrics.MeanAbsoluteError())#SparseCategoricalAccuracy,MeanAbsoluteError()})
# model.summary()
# def lr_decay(epoch):
#   return 0.001 * math.pow(0.9, np.floor(epoch/5))
# # lr schedule callback
# lr_decay_callback = tf.keras.callbacks.LearningRateScheduler(lr_decay, verbose=True)
# def sigmoid(x):
#   return 1 / (1 + np.exp(-x))

# EPOCHS=40
# early_stopper = tf.keras.callbacks.EarlyStopping(monitor='val_mean_absolute_error', mode='min', patience=7, restore_best_weights=True, verbose=1)
# model.fit(x_training[0:20000],y_range_training[0:20000],batch_size=32,validation_data=(x_validation[0:2000],y_range_validation[0:2000]),epochs=EPOCHS, callbacks=[early_stopper,lr_decay_callback])

# %%
# y_predict=model.predict(x_testing[0:100])
# def inverse_sigmoid(y):
#   return np.log(y/(1-y))
# plot_index = 24
# plt.figure(1)
# ax1=plt.subplot(311)
# ax1.scatter([range(361)], [inverse_sigmoid(y_range_testing[plot_index,:,0])], s=0.1)
# ax2=plt.subplot(312,sharex=ax1,sharey=ax1)
# ax2.scatter([range(361)], [inverse_sigmoid(x_testing[plot_index][:,0])], s=0.1)
# ax3=plt.subplot(313,sharex=ax1,sharey=ax1)
# ax3.scatter([range(361)], [inverse_sigmoid(y_predict[plot_index][:,0])], s=0.1)
# ax1.title.set_text('Original Measurement')
# ax2.title.set_text('Sampled Measurement')
# ax3.title.set_text('Reconstructed Measurement')
# # if Flag_compression:
# #   for xc in indices:
# #     plt.axvline(x=xc,c='r',linewidth=0.1,linestyle='-.')
# plt.tight_layout()

# %%
BATCH_SIZE = 32
add_compression_network=True
if add_compression_network:
  training_dataset = tf.data.Dataset.from_tensor_slices((x_training,(y_range_training[:,:,0],y_range_training[:,:,1],y_pose_training[:,0:2],y_pose_training[:,2]))).batch(BATCH_SIZE)#
  validation_dataset = tf.data.Dataset.from_tensor_slices((x_validation, (y_range_validation[:,:,0],y_range_validation[:,:,1],y_pose_validation[:,0:2],y_pose_validation[:,2]))).batch(BATCH_SIZE)         
else:
  training_dataset = tf.data.Dataset.from_tensor_slices((x_training,(y_pose_training[:,0:2],y_pose_training[:,2]))).batch(BATCH_SIZE)#
  validation_dataset = tf.data.Dataset.from_tensor_slices((x_validation, (y_pose_validation[:,0:2],y_pose_validation[:,2]))).batch(BATCH_SIZE)

# %%
print(y_range_validation.shape,y_pose_validation.shape)
# Out:
# (18944, 361, 2) (18944, 3)

# %%
from tensorflow.keras.layers import Input, Conv1D, Activation, MaxPooling1D, Add, AveragePooling1D, Dense, Dropout, Flatten
from tensorflow.keras import Model
def residual_block(x):
      temp = x
      x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(x)
      x = Conv1D(filters=64, kernel_size=3, padding='same')(x)
      x = Add()([Activation('relu')(x), temp])
      return x

class SoftArgmax(tf.keras.layers.Layer):
    def __init__(self, name):
        super(SoftArgmax, self).__init__()
        self._name = name
    
    def call(self, input):
        # range
        x = input
        input_size=tf.shape(input)
        pos = tf.convert_to_tensor(range(input_size[1]),dtype=tf.float32)
        x *= pos
        x = tf.reduce_sum(x, axis=1, keepdims=True)
        return x

def Res1DFlat(dropout_rate,input_shape,add_compression_network):
  # input size = (batch_size, 2, 1081)
  input_data = Input(shape=input_shape)
  #x = Dense(1024, activation='relu')(1081)
  x = Conv1D(filters=64, kernel_size=7, strides=3, activation='relu', padding='same')(input_data)
  x = MaxPooling1D(pool_size=3)(x)
  x=residual_block(x)
  # second resnet block
  x=residual_block(x)
  # third resnet block
  x=residual_block(x)
  # fourth resnet block
  x=residual_block(x)
  # fifth resnet block
  x=residual_block(x)
 
  # Average pooling
  x = AveragePooling1D(pool_size=7)(x)
  x = Flatten()(x) # (batch_size, 2, channel)
  
  # Dense Layers
  x = Dense(256, activation='relu')(x)
  x = Dropout(dropout_rate)(x)
  x = Dense(256, activation='relu')(x)
  x = Dropout(dropout_rate)(x)

  x1 = Dense(256, activation='relu')(x)
  x1 = Dropout(dropout_rate)(x1)
  #output1 = Dense(2786, activation='softmax', name='pose')(x1)
  output1 = Dense(2, activation='sigmoid', name='pose')(x1)

  x2 = Dense(256, activation='relu')(x)
  x2 = Dropout(dropout_rate)(x2)
  output2 = Dense(1, activation='sigmoid',name='rotation')(x2)
    #x2 = Dense(230, activation='softmax')(x2)
    #output2 = SoftArgmax(name='rotation')(x2,10)#Dense(230, activation='softmax', name='rotation')(x2)
  if add_compression_network:
  #   x3 = Dense(512, activation='relu')(x)
  #   x3 = Dropout(dropout_rate)(x2)
    output3 = Dense(361, activation='sigmoid',name='recons1')(x)
    # x4 = Dense(512, activation='relu')(x)
    # x4 = Dropout(dropout_rate)(x2)
    output4 = Dense(361, activation='sigmoid',name='recons2')(x)
    model = Model(inputs=input_data, outputs=[output3, output4,output1, output2])
  else:
    model = Model(inputs=input_data, outputs=[output1, output2])
  return model

# %% [markdown]
# check if the soft-argmax function is working

# %%
import tensorflow.keras.backend as kb
from tensorflow.keras.losses import MSE
from tensorflow import stack,argmax,cast

dropout_rate=0.2
optimizer_lr=0.001
model = Res1DFlat(dropout_rate,np.shape(x_training[0]),add_compression_network)
optimizer = tf.keras.optimizers.Adam(optimizer_lr)
if add_compression_network:
  model.compile(optimizer=optimizer,
                  loss={"recons1": keras.losses.mse,"recons2": keras.losses.mse, "pose": keras.losses.mse, "rotation": keras.losses.mse},#sparse_categorical_crossentropy,losses.mse},
                  loss_weights=[10.0,10.0,10.0,0.5],
                  metrics={"recons1": tf.keras.metrics.MeanAbsoluteError(),"recons2": tf.keras.metrics.MeanAbsoluteError(),"pose": tf.keras.metrics.MeanAbsoluteError(), "rotation": tf.keras.metrics.MeanAbsoluteError()})#SparseCategoricalAccuracy,MeanAbsoluteError()})
else:
  model.compile(optimizer=optimizer,
                  loss={ "pose": keras.losses.mse, "rotation": keras.losses.mse},#sparse_categorical_crossentropy,losses.mse},
                  loss_weights=[10.0,0.5],
                  metrics={"pose": tf.keras.metrics.MeanAbsoluteError(), "rotation": tf.keras.metrics.MeanAbsoluteError()})#SparseCategoricalAccuracy,MeanAbsoluteError()})
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 361, 2)]     0
# __________________________________________________________________________________________________
# conv1d_88 (Conv1D)              (None, 121, 64)      960         input_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 40, 64)       0           conv1d_88[0][0]
# __________________________________________________________________________________________________
# conv1d_89 (Conv1D)              (None, 40, 64)       12352       max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_90 (Conv1D)              (None, 40, 64)       12352       conv1d_89[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 40, 64)       0           conv1d_90[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 40, 64)       0           activation_40[0][0]
#                                                                  max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_91 (Conv1D)              (None, 40, 64)       12352       add_40[0][0]
# __________________________________________________________________________________________________
# conv1d_92 (Conv1D)              (None, 40, 64)       12352       conv1d_91[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 40, 64)       0           conv1d_92[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 40, 64)       0           activation_41[0][0]
#                                                                  add_40[0][0]
# __________________________________________________________________________________________________
# conv1d_93 (Conv1D)              (None, 40, 64)       12352       add_41[0][0]
# __________________________________________________________________________________________________
# conv1d_94 (Conv1D)              (None, 40, 64)       12352       conv1d_93[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 40, 64)       0           conv1d_94[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 40, 64)       0           activation_42[0][0]
#                                                                  add_41[0][0]
# __________________________________________________________________________________________________
# conv1d_95 (Conv1D)              (None, 40, 64)       12352       add_42[0][0]
# __________________________________________________________________________________________________
# conv1d_96 (Conv1D)              (None, 40, 64)       12352       conv1d_95[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 40, 64)       0           conv1d_96[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 40, 64)       0           activation_43[0][0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# conv1d_97 (Conv1D)              (None, 40, 64)       12352       add_43[0][0]
# __________________________________________________________________________________________________
# conv1d_98 (Conv1D)              (None, 40, 64)       12352       conv1d_97[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 40, 64)       0           conv1d_98[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 40, 64)       0           activation_44[0][0]
#                                                                  add_43[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_8 (AveragePoo (None, 5, 64)        0           add_44[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 320)          0           average_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 256)          82176       flatten_8[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 256)          0           dense_36[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 256)          65792       dropout_36[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 256)          0           dense_37[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 256)          65792       dropout_37[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 256)          65792       dropout_37[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 256)          0           dense_38[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 256)          0           dense_39[0][0]
# __________________________________________________________________________________________________
# recons1 (Dense)                 (None, 361)          92777       dropout_37[0][0]
# __________________________________________________________________________________________________
# recons2 (Dense)                 (None, 361)          92777       dropout_37[0][0]
# __________________________________________________________________________________________________
# pose (Dense)                    (None, 2)            514         dropout_38[0][0]
# __________________________________________________________________________________________________
# rotation (Dense)                (None, 1)            257         dropout_39[0][0]
# ==================================================================================================
# Total params: 590,357
# Trainable params: 590,357
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# lr decay function
def lr_decay(epoch):
  return 0.001 * math.pow(0.9, np.floor(epoch/5))
# lr schedule callback
lr_decay_callback = tf.keras.callbacks.LearningRateScheduler(lr_decay, verbose=True)

EPOCHS=100
early_stopper = tf.keras.callbacks.EarlyStopping(monitor='val_pose_mean_absolute_error', mode='min', patience=7, restore_best_weights=True, verbose=1)
model.fit(training_dataset, validation_data=validation_dataset, epochs=EPOCHS, callbacks=[early_stopper,lr_decay_callback])
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 29s 8ms/step - loss: 0.3377 - recons1_loss: 0.0081 - recons2_loss: 0.0079 - pose_loss: 0.0087 - rotation_loss: 0.1827 - recons1_mean_absolute_error: 0.0582 - recons2_mean_absolute_error: 0.0578 - pose_mean_absolute_error: 0.0590 - rotation_mean_absolute_error: 0.3934 - val_loss: 0.2197 - val_recons1_loss: 0.0026 - val_recons2_loss: 0.0024 - val_pose_loss: 0.0080 - val_rotation_loss: 0.1794 - val_recons1_mean_absolute_error: 0.0329 - val_recons2_mean_absolute_error: 0.0322 - val_pose_mean_absolute_error: 0.0548 - val_rotation_mean_absolute_error: 0.3903
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.1929 - recons1_loss: 0.0027 - recons2_loss: 0.0026 - pose_loss: 0.0071 - rotation_loss: 0.1386 - recons1_mean_absolute_error: 0.0345 - recons2_mean_absolute_error: 0.0339 - pose_mean_absolute_error: 0.0513 - rotation_mean_absolute_error: 0.3151 - val_loss: 0.1296 - val_recons1_loss: 0.0017 - val_recons2_loss: 0.0016 - val_pose_loss: 0.0052 - val_rotation_loss: 0.0885 - val_recons1_mean_absolute_error: 0.0267 - val_recons2_mean_absolute_error: 0.0257 - val_pose_mean_absolute_error: 0.0420 - val_rotation_mean_absolute_error: 0.2202
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.1346 - recons1_loss: 0.0021 - recons2_loss: 0.0021 - pose_loss: 0.0052 - rotation_loss: 0.0830 - recons1_mean_absolute_error: 0.0301 - recons2_mean_absolute_error: 0.0300 - pose_mean_absolute_error: 0.0419 - rotation_mean_absolute_error: 0.2060 - val_loss: 0.1132 - val_recons1_loss: 0.0015 - val_recons2_loss: 0.0017 - val_pose_loss: 0.0044 - val_rotation_loss: 0.0762 - val_recons1_mean_absolute_error: 0.0249 - val_recons2_mean_absolute_error: 0.0268 - val_pose_mean_absolute_error: 0.0374 - val_rotation_mean_absolute_error: 0.1906
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.1143 - recons1_loss: 0.0019 - recons2_loss: 0.0019 - pose_loss: 0.0043 - rotation_loss: 0.0658 - recons1_mean_absolute_error: 0.0287 - recons2_mean_absolute_error: 0.0286 - pose_mean_absolute_error: 0.0375 - rotation_mean_absolute_error: 0.1718 - val_loss: 0.0867 - val_recons1_loss: 0.0013 - val_recons2_loss: 0.0013 - val_pose_loss: 0.0034 - val_rotation_loss: 0.0531 - val_recons1_mean_absolute_error: 0.0224 - val_recons2_mean_absolute_error: 0.0224 - val_pose_mean_absolute_error: 0.0331 - val_rotation_mean_absolute_error: 0.1482
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.1033 - recons1_loss: 0.0018 - recons2_loss: 0.0018 - pose_loss: 0.0038 - rotation_loss: 0.0570 - recons1_mean_absolute_error: 0.0279 - recons2_mean_absolute_error: 0.0276 - pose_mean_absolute_error: 0.0351 - rotation_mean_absolute_error: 0.1537 - val_loss: 0.0774 - val_recons1_loss: 0.0013 - val_recons2_loss: 0.0013 - val_pose_loss: 0.0030 - val_rotation_loss: 0.0441 - val_recons1_mean_absolute_error: 0.0223 - val_recons2_mean_absolute_error: 0.0219 - val_pose_mean_absolute_error: 0.0300 - val_rotation_mean_absolute_error: 0.1293
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0920 - recons1_loss: 0.0017 - recons2_loss: 0.0017 - pose_loss: 0.0033 - rotation_loss: 0.0483 - recons1_mean_absolute_error: 0.0268 - recons2_mean_absolute_error: 0.0267 - pose_mean_absolute_error: 0.0326 - rotation_mean_absolute_error: 0.1362 - val_loss: 0.0839 - val_recons1_loss: 0.0014 - val_recons2_loss: 0.0015 - val_pose_loss: 0.0031 - val_rotation_loss: 0.0470 - val_recons1_mean_absolute_error: 0.0237 - val_recons2_mean_absolute_error: 0.0255 - val_pose_mean_absolute_error: 0.0310 - val_rotation_mean_absolute_error: 0.1289
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0865 - recons1_loss: 0.0017 - recons2_loss: 0.0017 - pose_loss: 0.0031 - rotation_loss: 0.0438 - recons1_mean_absolute_error: 0.0264 - recons2_mean_absolute_error: 0.0263 - pose_mean_absolute_error: 0.0313 - rotation_mean_absolute_error: 0.1269 - val_loss: 0.0627 - val_recons1_loss: 0.0011 - val_recons2_loss: 0.0011 - val_pose_loss: 0.0023 - val_rotation_loss: 0.0335 - val_recons1_mean_absolute_error: 0.0203 - val_recons2_mean_absolute_error: 0.0202 - val_pose_mean_absolute_error: 0.0260 - val_rotation_mean_absolute_error: 0.1053
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0826 - recons1_loss: 0.0017 - recons2_loss: 0.0017 - pose_loss: 0.0029 - rotation_loss: 0.0413 - recons1_mean_absolute_error: 0.0260 - recons2_mean_absolute_error: 0.0260 - pose_mean_absolute_error: 0.0302 - rotation_mean_absolute_error: 0.1213 - val_loss: 0.0701 - val_recons1_loss: 0.0011 - val_recons2_loss: 0.0012 - val_pose_loss: 0.0027 - val_rotation_loss: 0.0389 - val_recons1_mean_absolute_error: 0.0206 - val_recons2_mean_absolute_error: 0.0211 - val_pose_mean_absolute_error: 0.0291 - val_rotation_mean_absolute_error: 0.1171
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0792 - recons1_loss: 0.0016 - recons2_loss: 0.0016 - pose_loss: 0.0027 - rotation_loss: 0.0385 - recons1_mean_absolute_error: 0.0257 - recons2_mean_absolute_error: 0.0257 - pose_mean_absolute_error: 0.0295 - rotation_mean_absolute_error: 0.1155 - val_loss: 0.0575 - val_recons1_loss: 0.0011 - val_recons2_loss: 0.0011 - val_pose_loss: 0.0020 - val_rotation_loss: 0.0297 - val_recons1_mean_absolute_error: 0.0208 - val_recons2_mean_absolute_error: 0.0200 - val_pose_mean_absolute_error: 0.0240 - val_rotation_mean_absolute_error: 0.0983
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0757 - recons1_loss: 0.0016 - recons2_loss: 0.0016 - pose_loss: 0.0025 - rotation_loss: 0.0362 - recons1_mean_absolute_error: 0.0256 - recons2_mean_absolute_error: 0.0255 - pose_mean_absolute_error: 0.0283 - rotation_mean_absolute_error: 0.1104 - val_loss: 0.0553 - val_recons1_loss: 0.0011 - val_recons2_loss: 0.0011 - val_pose_loss: 0.0020 - val_rotation_loss: 0.0279 - val_recons1_mean_absolute_error: 0.0199 - val_recons2_mean_absolute_error: 0.0197 - val_pose_mean_absolute_error: 0.0237 - val_rotation_mean_absolute_error: 0.0923
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0718 - recons1_loss: 0.0016 - recons2_loss: 0.0016 - pose_loss: 0.0024 - rotation_loss: 0.0332 - recons1_mean_absolute_error: 0.0251 - recons2_mean_absolute_error: 0.0251 - pose_mean_absolute_error: 0.0274 - rotation_mean_absolute_error: 0.1043 - val_loss: 0.0554 - val_recons1_loss: 0.0011 - val_recons2_loss: 0.0011 - val_pose_loss: 0.0019 - val_rotation_loss: 0.0287 - val_recons1_mean_absolute_error: 0.0204 - val_recons2_mean_absolute_error: 0.0197 - val_pose_mean_absolute_error: 0.0232 - val_rotation_mean_absolute_error: 0.0942
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0684 - recons1_loss: 0.0016 - recons2_loss: 0.0015 - pose_loss: 0.0022 - rotation_loss: 0.0307 - recons1_mean_absolute_error: 0.0249 - recons2_mean_absolute_error: 0.0248 - pose_mean_absolute_error: 0.0266 - rotation_mean_absolute_error: 0.0989 - val_loss: 0.0531 - val_recons1_loss: 0.0011 - val_recons2_loss: 0.0011 - val_pose_loss: 0.0018 - val_rotation_loss: 0.0261 - val_recons1_mean_absolute_error: 0.0196 - val_recons2_mean_absolute_error: 0.0208 - val_pose_mean_absolute_error: 0.0225 - val_rotation_mean_absolute_error: 0.0875
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0668 - recons1_loss: 0.0015 - recons2_loss: 0.0015 - pose_loss: 0.0021 - rotation_loss: 0.0294 - recons1_mean_absolute_error: 0.0248 - recons2_mean_absolute_error: 0.0248 - pose_mean_absolute_error: 0.0261 - rotation_mean_absolute_error: 0.0959 - val_loss: 0.0515 - val_recons1_loss: 0.0011 - val_recons2_loss: 0.0011 - val_pose_loss: 0.0018 - val_rotation_loss: 0.0246 - val_recons1_mean_absolute_error: 0.0196 - val_recons2_mean_absolute_error: 0.0200 - val_pose_mean_absolute_error: 0.0222 - val_rotation_mean_absolute_error: 0.0853
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0651 - recons1_loss: 0.0015 - recons2_loss: 0.0015 - pose_loss: 0.0021 - rotation_loss: 0.0282 - recons1_mean_absolute_error: 0.0245 - recons2_mean_absolute_error: 0.0246 - pose_mean_absolute_error: 0.0256 - rotation_mean_absolute_error: 0.0929 - val_loss: 0.0493 - val_recons1_loss: 0.0010 - val_recons2_loss: 0.0011 - val_pose_loss: 0.0017 - val_rotation_loss: 0.0233 - val_recons1_mean_absolute_error: 0.0190 - val_recons2_mean_absolute_error: 0.0194 - val_pose_mean_absolute_error: 0.0218 - val_rotation_mean_absolute_error: 0.0802
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0638 - recons1_loss: 0.0015 - recons2_loss: 0.0015 - pose_loss: 0.0020 - rotation_loss: 0.0276 - recons1_mean_absolute_error: 0.0244 - recons2_mean_absolute_error: 0.0244 - pose_mean_absolute_error: 0.0252 - rotation_mean_absolute_error: 0.0915 - val_loss: 0.0569 - val_recons1_loss: 0.0010 - val_recons2_loss: 0.0011 - val_pose_loss: 0.0021 - val_rotation_loss: 0.0308 - val_recons1_mean_absolute_error: 0.0194 - val_recons2_mean_absolute_error: 0.0193 - val_pose_mean_absolute_error: 0.0242 - val_rotation_mean_absolute_error: 0.0976
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0613 - recons1_loss: 0.0015 - recons2_loss: 0.0015 - pose_loss: 0.0019 - rotation_loss: 0.0256 - recons1_mean_absolute_error: 0.0242 - recons2_mean_absolute_error: 0.0242 - pose_mean_absolute_error: 0.0245 - rotation_mean_absolute_error: 0.0872 - val_loss: 0.0497 - val_recons1_loss: 0.0010 - val_recons2_loss: 0.0010 - val_pose_loss: 0.0017 - val_rotation_loss: 0.0249 - val_recons1_mean_absolute_error: 0.0191 - val_recons2_mean_absolute_error: 0.0189 - val_pose_mean_absolute_error: 0.0222 - val_rotation_mean_absolute_error: 0.0843
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0598 - recons1_loss: 0.0015 - recons2_loss: 0.0015 - pose_loss: 0.0018 - rotation_loss: 0.0244 - recons1_mean_absolute_error: 0.0240 - recons2_mean_absolute_error: 0.0240 - pose_mean_absolute_error: 0.0241 - rotation_mean_absolute_error: 0.0844 - val_loss: 0.0452 - val_recons1_loss: 9.9465e-04 - val_recons2_loss: 0.0010 - val_pose_loss: 0.0015 - val_rotation_loss: 0.0207 - val_recons1_mean_absolute_error: 0.0188 - val_recons2_mean_absolute_error: 0.0192 - val_pose_mean_absolute_error: 0.0205 - val_rotation_mean_absolute_error: 0.0756
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0590 - recons1_loss: 0.0015 - recons2_loss: 0.0015 - pose_loss: 0.0018 - rotation_loss: 0.0236 - recons1_mean_absolute_error: 0.0240 - recons2_mean_absolute_error: 0.0240 - pose_mean_absolute_error: 0.0239 - rotation_mean_absolute_error: 0.0830 - val_loss: 0.0432 - val_recons1_loss: 9.7375e-04 - val_recons2_loss: 9.7298e-04 - val_pose_loss: 0.0013 - val_rotation_loss: 0.0207 - val_recons1_mean_absolute_error: 0.0184 - val_recons2_mean_absolute_error: 0.0182 - val_pose_mean_absolute_error: 0.0195 - val_rotation_mean_absolute_error: 0.0739
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0581 - recons1_loss: 0.0015 - recons2_loss: 0.0015 - pose_loss: 0.0017 - rotation_loss: 0.0230 - recons1_mean_absolute_error: 0.0239 - recons2_mean_absolute_error: 0.0239 - pose_mean_absolute_error: 0.0236 - rotation_mean_absolute_error: 0.0814 - val_loss: 0.0423 - val_recons1_loss: 9.8151e-04 - val_recons2_loss: 9.7184e-04 - val_pose_loss: 0.0014 - val_rotation_loss: 0.0185 - val_recons1_mean_absolute_error: 0.0186 - val_recons2_mean_absolute_error: 0.0183 - val_pose_mean_absolute_error: 0.0194 - val_rotation_mean_absolute_error: 0.0697
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0563 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0017 - rotation_loss: 0.0215 - recons1_mean_absolute_error: 0.0238 - recons2_mean_absolute_error: 0.0237 - pose_mean_absolute_error: 0.0231 - rotation_mean_absolute_error: 0.0784 - val_loss: 0.0426 - val_recons1_loss: 9.8886e-04 - val_recons2_loss: 0.0010 - val_pose_loss: 0.0013 - val_rotation_loss: 0.0193 - val_recons1_mean_absolute_error: 0.0188 - val_recons2_mean_absolute_error: 0.0191 - val_pose_mean_absolute_error: 0.0192 - val_rotation_mean_absolute_error: 0.0708
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0550 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0016 - rotation_loss: 0.0212 - recons1_mean_absolute_error: 0.0235 - recons2_mean_absolute_error: 0.0235 - pose_mean_absolute_error: 0.0227 - rotation_mean_absolute_error: 0.0775 - val_loss: 0.0435 - val_recons1_loss: 9.7916e-04 - val_recons2_loss: 9.8416e-04 - val_pose_loss: 0.0014 - val_rotation_loss: 0.0197 - val_recons1_mean_absolute_error: 0.0185 - val_recons2_mean_absolute_error: 0.0184 - val_pose_mean_absolute_error: 0.0199 - val_rotation_mean_absolute_error: 0.0740
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0541 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0015 - rotation_loss: 0.0206 - recons1_mean_absolute_error: 0.0234 - recons2_mean_absolute_error: 0.0234 - pose_mean_absolute_error: 0.0224 - rotation_mean_absolute_error: 0.0758 - val_loss: 0.0385 - val_recons1_loss: 9.5704e-04 - val_recons2_loss: 9.3434e-04 - val_pose_loss: 0.0012 - val_rotation_loss: 0.0160 - val_recons1_mean_absolute_error: 0.0183 - val_recons2_mean_absolute_error: 0.0177 - val_pose_mean_absolute_error: 0.0179 - val_rotation_mean_absolute_error: 0.0636
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0533 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0015 - rotation_loss: 0.0199 - recons1_mean_absolute_error: 0.0233 - recons2_mean_absolute_error: 0.0233 - pose_mean_absolute_error: 0.0222 - rotation_mean_absolute_error: 0.0744 - val_loss: 0.0385 - val_recons1_loss: 9.2020e-04 - val_recons2_loss: 9.1813e-04 - val_pose_loss: 0.0012 - val_rotation_loss: 0.0165 - val_recons1_mean_absolute_error: 0.0177 - val_recons2_mean_absolute_error: 0.0176 - val_pose_mean_absolute_error: 0.0178 - val_rotation_mean_absolute_error: 0.0636
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 27s 8ms/step - loss: 0.0533 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0015 - rotation_loss: 0.0202 - recons1_mean_absolute_error: 0.0233 - recons2_mean_absolute_error: 0.0233 - pose_mean_absolute_error: 0.0220 - rotation_mean_absolute_error: 0.0751 - val_loss: 0.0376 - val_recons1_loss: 9.1086e-04 - val_recons2_loss: 9.5069e-04 - val_pose_loss: 0.0011 - val_rotation_loss: 0.0158 - val_recons1_mean_absolute_error: 0.0176 - val_recons2_mean_absolute_error: 0.0179 - val_pose_mean_absolute_error: 0.0177 - val_rotation_mean_absolute_error: 0.0637
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0517 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0014 - rotation_loss: 0.0190 - recons1_mean_absolute_error: 0.0232 - recons2_mean_absolute_error: 0.0232 - pose_mean_absolute_error: 0.0217 - rotation_mean_absolute_error: 0.0723 - val_loss: 0.0388 - val_recons1_loss: 9.2967e-04 - val_recons2_loss: 9.0871e-04 - val_pose_loss: 0.0011 - val_rotation_loss: 0.0178 - val_recons1_mean_absolute_error: 0.0178 - val_recons2_mean_absolute_error: 0.0176 - val_pose_mean_absolute_error: 0.0176 - val_rotation_mean_absolute_error: 0.0672
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0509 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0014 - rotation_loss: 0.0181 - recons1_mean_absolute_error: 0.0230 - recons2_mean_absolute_error: 0.0230 - pose_mean_absolute_error: 0.0214 - rotation_mean_absolute_error: 0.0703 - val_loss: 0.0363 - val_recons1_loss: 9.2631e-04 - val_recons2_loss: 9.0501e-04 - val_pose_loss: 0.0010 - val_rotation_loss: 0.0151 - val_recons1_mean_absolute_error: 0.0178 - val_recons2_mean_absolute_error: 0.0174 - val_pose_mean_absolute_error: 0.0167 - val_rotation_mean_absolute_error: 0.0615
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0499 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0014 - rotation_loss: 0.0174 - recons1_mean_absolute_error: 0.0229 - recons2_mean_absolute_error: 0.0228 - pose_mean_absolute_error: 0.0212 - rotation_mean_absolute_error: 0.0686 - val_loss: 0.0359 - val_recons1_loss: 8.8766e-04 - val_recons2_loss: 9.0720e-04 - val_pose_loss: 0.0011 - val_rotation_loss: 0.0148 - val_recons1_mean_absolute_error: 0.0173 - val_recons2_mean_absolute_error: 0.0174 - val_pose_mean_absolute_error: 0.0171 - val_rotation_mean_absolute_error: 0.0597
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0492 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0013 - rotation_loss: 0.0173 - recons1_mean_absolute_error: 0.0229 - recons2_mean_absolute_error: 0.0228 - pose_mean_absolute_error: 0.0209 - rotation_mean_absolute_error: 0.0683 - val_loss: 0.0381 - val_recons1_loss: 9.2348e-04 - val_recons2_loss: 9.3384e-04 - val_pose_loss: 0.0011 - val_rotation_loss: 0.0169 - val_recons1_mean_absolute_error: 0.0179 - val_recons2_mean_absolute_error: 0.0179 - val_pose_mean_absolute_error: 0.0173 - val_rotation_mean_absolute_error: 0.0655
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0494 - recons1_loss: 0.0014 - recons2_loss: 0.0014 - pose_loss: 0.0014 - rotation_loss: 0.0175 - recons1_mean_absolute_error: 0.0228 - recons2_mean_absolute_error: 0.0228 - pose_mean_absolute_error: 0.0210 - rotation_mean_absolute_error: 0.0689 - val_loss: 0.0380 - val_recons1_loss: 8.8141e-04 - val_recons2_loss: 9.3165e-04 - val_pose_loss: 0.0011 - val_rotation_loss: 0.0170 - val_recons1_mean_absolute_error: 0.0174 - val_recons2_mean_absolute_error: 0.0178 - val_pose_mean_absolute_error: 0.0179 - val_rotation_mean_absolute_error: 0.0653
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.00059049.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0489 - recons1_loss: 0.0013 - recons2_loss: 0.0014 - pose_loss: 0.0013 - rotation_loss: 0.0170 - recons1_mean_absolute_error: 0.0227 - recons2_mean_absolute_error: 0.0228 - pose_mean_absolute_error: 0.0208 - rotation_mean_absolute_error: 0.0677 - val_loss: 0.0363 - val_recons1_loss: 8.8873e-04 - val_recons2_loss: 8.9003e-04 - val_pose_loss: 0.0011 - val_rotation_loss: 0.0157 - val_recons1_mean_absolute_error: 0.0174 - val_recons2_mean_absolute_error: 0.0173 - val_pose_mean_absolute_error: 0.0173 - val_rotation_mean_absolute_error: 0.0617
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.000531441.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0472 - recons1_loss: 0.0013 - recons2_loss: 0.0013 - pose_loss: 0.0013 - rotation_loss: 0.0160 - recons1_mean_absolute_error: 0.0225 - recons2_mean_absolute_error: 0.0225 - pose_mean_absolute_error: 0.0203 - rotation_mean_absolute_error: 0.0653 - val_loss: 0.0377 - val_recons1_loss: 8.6257e-04 - val_recons2_loss: 8.8234e-04 - val_pose_loss: 0.0012 - val_rotation_loss: 0.0163 - val_recons1_mean_absolute_error: 0.0169 - val_recons2_mean_absolute_error: 0.0172 - val_pose_mean_absolute_error: 0.0179 - val_rotation_mean_absolute_error: 0.0636
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.000531441.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0466 - recons1_loss: 0.0013 - recons2_loss: 0.0013 - pose_loss: 0.0012 - rotation_loss: 0.0155 - recons1_mean_absolute_error: 0.0225 - recons2_mean_absolute_error: 0.0224 - pose_mean_absolute_error: 0.0200 - rotation_mean_absolute_error: 0.0642 - val_loss: 0.0358 - val_recons1_loss: 8.7935e-04 - val_recons2_loss: 8.7544e-04 - val_pose_loss: 0.0011 - val_rotation_loss: 0.0153 - val_recons1_mean_absolute_error: 0.0173 - val_recons2_mean_absolute_error: 0.0172 - val_pose_mean_absolute_error: 0.0170 - val_rotation_mean_absolute_error: 0.0607
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.000531441.
# 3355/3355 [==============================] - 28s 8ms/step - loss: 0.0465 - recons1_loss: 0.0013 - recons2_loss: 0.0013 - pose_loss: 0.0012 - rotation_loss: 0.0156 - recons1_mean_absolute_error: 0.0224 - recons2_mean_absolute_error: 0.0224 - pose_mean_absolute_error: 0.0200 - rotation_mean_absolute_error: 0.0645 - val_loss: 0.0365 - val_recons1_loss: 8.7054e-04 - val_recons2_loss: 8.8898e-04 - val_pose_loss: 0.0011 - val_rotation_loss: 0.0165 - val_recons1_mean_absolute_error: 0.0172 - val_recons2_mean_absolute_error: 0.0172 - val_pose_mean_absolute_error: 0.0172 - val_rotation_mean_absolute_error: 0.0639
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping

# %% [markdown]
# # Section 4: Model Evaluation

# %%
model.evaluate(validation_dataset)
# Out:
# 592/592 [==============================] - 2s 4ms/step - loss: 0.0363 - recons1_loss: 9.2631e-04 - recons2_loss: 9.0501e-04 - pose_loss: 0.0010 - rotation_loss: 0.0151 - recons1_mean_absolute_error: 0.0178 - recons2_mean_absolute_error: 0.0174 - pose_mean_absolute_error: 0.0167 - rotation_mean_absolute_error: 0.0615
# [0.03626994416117668,
#  0.0009263069368898869,
#  0.0009050118387676775,
#  0.0010388686787337065,
#  0.015136167407035828,
#  0.017759066075086594,
#  0.017368890345096588,
#  0.016714690253138542,
#  0.06152540445327759]

# %%
# model.save("model_regression")
# from google.colab import files
# !zip -r model_regression.zip model_regression/
# files.download('model_regression.zip')

# %%
#evaluate model accuracy using testing dataset
testing_dataset = tf.data.Dataset.from_tensor_slices((x_testing, (y_range_testing[:,:,0],y_range_testing[:,:,1],y_pose_testing[:,0:2],y_pose_testing[:,2]))).batch(BATCH_SIZE)
model.evaluate(testing_dataset)
# Out:
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0355 - recons1_loss: 9.4335e-04 - recons2_loss: 9.0179e-04 - pose_loss: 0.0010 - rotation_loss: 0.0141 - recons1_mean_absolute_error: 0.0179 - recons2_mean_absolute_error: 0.0173 - pose_mean_absolute_error: 0.0164 - rotation_mean_absolute_error: 0.0615
# [0.035515956580638885,
#  0.000943351595196873,
#  0.0009017855627462268,
#  0.001001450465992093,
#  0.014100159518420696,
#  0.017925359308719635,
#  0.017283806577324867,
#  0.01636769250035286,
#  0.0615144819021225]

# %%
y_predict=model.predict(x_testing)
print(y_predict[2][0].shape)
# Out:
# (2,)

# %%
def inverse_sigmoid(y):
  return np.log(y/(1-y))
plot_index = 45
plt.figure(1)
ax1=plt.subplot(311)
ax1.scatter([range(361)], [inverse_sigmoid(y_range_testing[plot_index,:,0])], s=0.1)
ax2=plt.subplot(312,sharex=ax1,sharey=ax1)
ax2.scatter([range(361)], [inverse_sigmoid(x_testing[plot_index][:,0])], s=0.1)
ax3=plt.subplot(313,sharex=ax1,sharey=ax1)
ax3.scatter([range(361)], [inverse_sigmoid(y_predict[0][plot_index])], s=0.1)
ax1.title.set_text('Original Measurement')
ax2.title.set_text('Sampled Measurement')
ax3.title.set_text('Reconstructed Measurement')
# if Flag_compression:
#   for xc in indices:
#     plt.axvline(x=xc,c='r',linewidth=0.1,linestyle='-.')
plt.tight_layout()

# %% [markdown]
# ## Test from new environment

# %%
testing_range_pairs,testing_translation_rels,testing_rotation_rels = read_from_pickle(dir_name,'test')

testing_translation_rels_norm=LA.norm(testing_translation_rels, axis=1)
testing_nonzeros_indices=np.where((testing_translation_rels_norm>1e-4) | (np.abs(testing_rotation_rels)>1e-4))
testing_nonfar_indices=np.where((testing_rotation_rels<=1.0) & (testing_rotation_rels>=-1.0))
testing_chosen_indices=np.intersect1d(testing_nonzeros_indices,testing_nonfar_indices)
testing_translation_rels=testing_translation_rels[testing_chosen_indices]
testing_rotation_rels=testing_rotation_rels[testing_chosen_indices]
testing_range_pairs=testing_range_pairs[testing_chosen_indices]

testing_rotation_rels=np.round(np.double(testing_rotation_rels*180/math.pi),4)
#pose_rels_grid_all=np.hstack((np.expand_dims(pose_rels_grid, axis=1),np.expand_dims(rotation_rels, axis=1)))
testing_pose_rels_all=np.hstack((testing_translation_rels,np.expand_dims(testing_rotation_rels, axis=1)))
#print(np.shape(range_pairs_compressed),np.shape(pose_rels_grid),np.shape(rotation_rels_grid),np.shape(pose_rels_grid_all),np.shape(pose_rels_all))
testing_range_pairs_all=np.clip(testing_range_pairs, a_min=None, a_max=40)    #remove the inf value of range to a large number

x_test_new, y_range_test_new, y_pose_test_new = shuffle(testing_range_pairs_all,laser_compression(testing_range_pairs_all,Flag_compression,Karaman_method),testing_pose_rels_all)

x_testing2 = sigmoid(np.array(x_test_new, dtype=float))
y_range_testing2 = sigmoid(np.array(y_range_test_new, dtype=float))
y_pose_testing2 = sigmoid(np.array(y_pose_test_new, dtype=float))
print('Size of testing data: ', x_testing2.shape)
print('Size of testing labels: ',y_range_testing2.shape)
testing_dataset2 = tf.data.Dataset.from_tensor_slices((x_testing2, (y_range_testing2[:,:,0],y_range_testing2[:,:,1],y_pose_testing2[:,0:2],y_pose_testing2[:,2]))).batch(BATCH_SIZE)
model.evaluate(testing_dataset2)
# Out:
# for %s dataset test
# size of range_pairs:  (24562, 361, 2)
# size of pose_rels:  (24562, 2)
# size of rotation_rels:  (24562,)
# <------------->
# size of range_pairs_compressed:  (18556, 361, 2)
# Size of testing data:  (18556, 361, 2)
# Size of testing labels:  (18556, 361, 2)
# 580/580 [==============================] - 2s 4ms/step - loss: 2.3152 - recons1_loss: 0.1136 - recons2_loss: 0.1134 - pose_loss: 0.0027 - rotation_loss: 0.0367 - recons1_mean_absolute_error: 0.2606 - recons2_mean_absolute_error: 0.2601 - pose_mean_absolute_error: 0.0271 - rotation_mean_absolute_error: 0.0961
# [2.315173864364624,
#  0.11355998367071152,
#  0.1133752167224884,
#  0.002749052131548524,
#  0.036665551364421844,
#  0.26062560081481934,
#  0.260067343711853,
#  0.027129769325256348,
#  0.09613700956106186]

# %%
y_range_testing3=y_range_testing2
y_pose_testing3=y_pose_testing2
x_testing3=x_testing2
# y_testing_ground_truth3=y_testing_ground_truth2

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.losses import MAE
def inverse_projection_2d(predict_idx):
  y_idx=predict_idx%40
  x_idx=(predict_idx-y_idx)/40
  grid_offset=np.transpose(np.array([[-1.8,-1.2]]))
  grid_spacing=np.transpose(np.array([[0.05,0.05]]))
  grid_point=grid_offset+np.array([x_idx,y_idx])*grid_spacing
  return grid_point

def inverse_projection_1d(predict_idx):
  grid_offset=np.array([-1.0*180/np.pi])
  grid_spacing=np.array([0.5])
  grid_point=grid_offset+predict_idx*grid_spacing
  print(grid_point[0:2])
  print(predict_idx[0:2])
  return grid_point


y_predict=model.predict(x_testing3)

# print(y_predict[0].shape, y_predict[1].shape, y_testing3[:,2].shape,y_testing3[:,0:2].shape)
# predict_pose=np.argmax(y_predict[0],axis=1)
# predict_pose_point=np.transpose(inverse_projection_2d(predict_pose))
predict_pose_point=y_predict[2]


# predict_rotation=np.argmax(y_predict[1],axis=1)
# predict_rotation_value=np.transpose(inverse_projection_1d(predict_rotation))
predict_rotation_value=tf.squeeze(y_predict[3])
  

# print(np.shape(predict_rotation))
# print("prediction of translation MSE: ", tf.reduce_sum(MAE(y_testing3[:,0:2],predict_pose_point))/y_testing3.shape[0])
# print("prediction of rotation MAE: ", MAE(y_testing3[:,2], predict_rotation_value))
nSamples=200
predict_list=np.zeros((nSamples,3))
for i in range(nSamples):
  predict_i=list(np.round(predict_pose_point[i],4))
  predict_i.append(np.round(np.float(predict_rotation_value[i]),4))
  predict_list[i]=inverse_sigmoid(np.array(predict_i))
  if i%1==0:
    print("test: ", i, " ground_truth: ", np.round(inverse_sigmoid(y_pose_testing3[i]),4),
          " predicted: ",inverse_sigmoid(np.array(predict_i)))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# test:  0  ground_truth:  [9.5000e-03 9.0000e-04 1.0202e+01]  predicted:  [-0.02320108 -0.00320006         inf]
# test:  1  ground_truth:  [ 1.0165 -0.0138 -9.4333]  predicted:  [ 0.90170627 -0.03440338 -1.76232011]
# test:  2  ground_truth:  [-0.0752 -0.0558     inf]  predicted:  [0.19259302 0.09928148 5.84014033]
# test:  3  ground_truth:  [  0.4918  -0.2229 -44.1611]  predicted:  [ 0.11251862 -0.00759999 -6.43615037]
# test:  4  ground_truth:  [-0.2239 -0.0677 33.2104]  predicted:  [-0.13540653 -0.04440727         inf]
# test:  5  ground_truth:  [-0.233  -0.0007  0.3369]  predicted:  [-3.42509597e-01 -3.99947172e-04  1.08850448e+00]
# test:  6  ground_truth:  [-0.2275 -0.0028  1.6348]  predicted:  [-0.07283222 -0.00600006  4.00489242]
# test:  7  ground_truth:  [-0.4651 -0.0294  5.2508]  predicted:  [-0.46162674 -0.02440121  5.04503672]
# test:  8  ground_truth:  [-1.70000e-03 -5.00000e-04  3.60437e+01]  predicted:  [-0.05721556 -0.01880057         inf]
# test:  9  ground_truth:  [-4.50800e-01 -4.30000e-03 -3.04864e+01]  predicted:  [-5.24119877e-02 -3.60000522e-03 -3.63522827e+00]
# test:  10  ground_truth:  [8.52000e-02 6.30000e-03 1.26293e+01]  predicted:  [0.01160015 0.00160003        inf]
# test:  11  ground_truth:  [ 1.2110e-01 -2.9000e-03  4.4244e+00]  predicted:  [ 0.3116994  -0.02680164 -2.96999403]
# test:  12  ground_truth:  [ 2.014e-01 -2.000e-04 -2.346e-01]  predicted:  [-0.11211729  0.00720003 -1.85317966]
# test:  13  ground_truth:  [  0.4359  -0.0883 -20.7958]  predicted:  [-0.45741176 -0.09847951  4.17114315]
# test:  14  ground_truth:  [-0.2685  0.0115 -5.6414]  predicted:  [-0.22656421  0.01440025 -3.99921955]
# test:  15  ground_truth:  [  1.0468  -0.3558 -21.3636]  predicted:  [ 0.56193441 -0.00279999 -2.57294594]
# test:  16  ground_truth:  [ 6.25000e-01  6.80000e-03 -1.64231e+01]  predicted:  [ 0.85970972 -0.03040238 -1.38005604]
# test:  17  ground_truth:  [ 3.16000e-02 -5.80000e-03 -1.72431e+01]  predicted:  [ 0.01960054 -0.01640035 -7.82364593]
# test:  18  ground_truth:  [  0.2462  -0.0328 -15.6275]  predicted:  [ 0.2314275  -0.05361279        -inf]
# test:  19  ground_truth:  [0.2326 0.     0.0042]  predicted:  [ 0.25741205 -0.00520004  0.27247332]
# test:  20  ground_truth:  [ -0.3523   0.1238 -47.9264]  predicted:  [-0.32646913  0.06722525 -8.51699317]
# test:  21  ground_truth:  [ 4.0000e-04  0.0000e+00 -7.6612e+00]  predicted:  [-0.05321256 -0.01880057 -7.13009851]
# test:  22  ground_truth:  [5.9500e-02 2.1000e-03 4.8682e+00]  predicted:  [-2.20008426e-02 -3.20005690e-03  6.90675478e+00]
# test:  23  ground_truth:  [-0.1645  0.011  -2.6781]  predicted:  [-1.15327699e-01 -3.99947172e-04 -7.21785159e-01]
# test:  24  ground_truth:  [0.207  0.0007 0.4028]  predicted:  [0.34498111 0.00040007 0.02240094]
# test:  25  ground_truth:  [ 0.2943  0.0008 -0.3712]  predicted:  [ 0.29532797  0.00320006 -0.26025917]
# test:  26  ground_truth:  [ 0.651  -0.0746 -4.6667]  predicted:  [ 0.64374712 -0.06882713 -4.44508238]
# test:  27  ground_truth:  [ -0.4227   0.0733 -20.4107]  predicted:  [-0.49421982  0.11211729        -inf]
# test:  28  ground_truth:  [ 0.2265 -0.0053 -1.5034]  predicted:  [ 0.3942276  -0.00720003 -0.86066704]
# test:  29  ground_truth:  [0.5634 0.0124 2.2554]  predicted:  [0.42007004 0.01320024 3.50042994]
# test:  30  ground_truth:  [-0.2675  0.0004 -0.225 ]  predicted:  [-0.40963356  0.00200009 -0.10810516]
# test:  31  ground_truth:  [ 1.28400e-01 -1.64000e-02 -2.89945e+01]  predicted:  [ 0.56972626 -0.17202294        -inf]
# test:  32  ground_truth:  [ 0.3038 -0.0039 -1.0766]  predicted:  [0.337981   0.00559999 0.28389143]
# test:  33  ground_truth:  [0.4803 0.0079 0.5149]  predicted:  [ 0.34951511 -0.00920004 -0.10248962]
# test:  34  ground_truth:  [-1.948e-01  2.000e-04 -6.889e-01]  predicted:  [-0.26799248 -0.00199997  1.15926975]
# test:  35  ground_truth:  [-1.0536 -0.0116  0.744 ]  predicted:  [-0.68924973 -0.05361279  3.79446722]
# test:  36  ground_truth:  [-0.2275 -0.0123  5.9145]  predicted:  [-0.19380433 -0.02080074  8.51699317]
# test:  37  ground_truth:  [ 0.1655  0.0141 11.8579]  predicted:  [-0.10248956 -0.01000007  4.80775823]
# test:  38  ground_truth:  [-1.045e-01 -2.000e-04 -2.056e-01]  predicted:  [-0.26147969  0.00760011  0.10810516]
# test:  39  ground_truth:  [-1.0409 -0.0511 13.1794]  predicted:  [-0.50997237 -0.04160599  2.67773528]
# test:  40  ground_truth:  [-0.1633  0.0129 -8.1761]  predicted:  [-0.14384752  0.01240007 -6.81134449]
# test:  41  ground_truth:  [ 0.8934  0.2105 16.291 ]  predicted:  [0.58623138 0.12697036 8.51699317]
# test:  42  ground_truth:  [-0.2233 -0.0013  0.1337]  predicted:  [-0.22656421  0.00760011  0.33222231]
# test:  43  ground_truth:  [-8.740e-02 -1.000e-04  1.233e-01]  predicted:  [0.10569842 0.01320024 2.49229638]
# test:  44  ground_truth:  [ 0.      0.     16.2717]  predicted:  [0.01520019 0.00160003        inf]
# test:  45  ground_truth:  [ 0.4936 -0.0155 -2.741 ]  predicted:  [ 0.448994   -0.04240636 -2.38142686]
# test:  46  ground_truth:  [ 0.213   0.0273 20.4957]  predicted:  [0.24400345 0.07603659 9.21024037]
# test:  47  ground_truth:  [-1.0378 -0.0451  9.8979]  predicted:  [-0.67893075 -0.0480092   1.92774847]
# test:  48  ground_truth:  [0.8806 0.0185 0.8364]  predicted:  [0.77638273 0.00799994 0.72360333]
# test:  49  ground_truth:  [  0.5572  -0.1012 -22.2804]  predicted:  [ 0.48361021 -0.09687566 -6.37542558]
# test:  50  ground_truth:  [-0.9196  0.031  -5.9287]  predicted:  [-0.80245784  0.05441339 -3.47609869]
# test:  51  ground_truth:  [ 0.7836 -0.0087  1.2785]  predicted:  [ 0.87748134  0.00200009 -0.94346976]
# test:  52  ground_truth:  [0.4477 0.0082 1.5371]  predicted:  [ 0.53050114 -0.00399995  0.19622723]
# test:  53  ground_truth:  [-0.2834  0.0005 -0.3192]  predicted:  [-0.33633507 -0.00039995 -0.12215166]
# test:  54  ground_truth:  [0.6896 0.3593    inf]  predicted:  [-9.24657798e-02 -3.99995383e-03  9.21024037e+00]
# test:  55  ground_truth:  [-1.0369 -0.0133  1.4667]  predicted:  [-0.96039055 -0.16275835  4.21202612]
# test:  56  ground_truth:  [-0.6647 -0.0159  4.4645]  predicted:  [-0.01720042 -0.01760051  9.21024037]
# test:  57  ground_truth:  [ -0.7192   0.1982 -32.8638]  predicted:  [-0.82643217  0.2030952         -inf]
# test:  58  ground_truth:  [  0.4453  -0.122  -30.188 ]  predicted:  [ 0.19865065 -0.05361279 -8.51699317]
# test:  59  ground_truth:  [ -0.4582   0.0486 -15.371 ]  predicted:  [-1.25765488e-01  2.79998962e-03 -9.21024037e+00]
# test:  60  ground_truth:  [-0.2117 -0.0657 11.0855]  predicted:  [-0.01880057 -0.00399995         inf]
# test:  61  ground_truth:  [-0.2571 -0.027  11.5964]  predicted:  [-3.78038813e-01 -6.80008171e-03  7.60040233e+00]
# test:  62  ground_truth:  [-0.4688  0.0132 -2.6246]  predicted:  [ 0.20471192 -0.01720042 -1.69667522]
# test:  63  ground_truth:  [  0.4075  -0.2209 -37.2315]  predicted:  [0.08204601 0.01600037 0.76021311]
# test:  64  ground_truth:  [-1.05000e-02 -2.10000e-03  2.97822e+01]  predicted:  [0.2063289  0.07563595        inf]
# test:  65  ground_truth:  [-1.055   0.0051 -0.12  ]  predicted:  [-0.4158927   0.         -0.02840191]
# test:  66  ground_truth:  [-0.5479  0.0107 -2.0514]  predicted:  [-0.53135887  0.01520019 -0.4439507 ]
# test:  67  ground_truth:  [  0.4066  -0.1827 -47.0915]  predicted:  [ 0.00559999 -0.01560028        -inf]
# test:  68  ground_truth:  [ 0.1383 -0.0036 -0.9803]  predicted:  [ 0.22413369 -0.00320006 -0.47302719]
# test:  69  ground_truth:  [  0.2648  -0.0544 -24.8555]  predicted:  [ 0.02680152 -0.01600037        -inf]
# test:  70  ground_truth:  [ 0.1145  0.     -0.1789]  predicted:  [-0.05281233  0.00519992 -0.23548216]
# test:  71  ground_truth:  [ 0.3755  0.0877 23.5091]  predicted:  [ 7.60010563e-03 -8.00013585e-04  6.81134449e+00]
# test:  72  ground_truth:  [  0.       0.     -32.1047]  predicted:  [-7.88407763e-02 -3.99947172e-04 -3.39985489e+00]
# test:  73  ground_truth:  [ 2.86800e-01 -2.25000e-02 -2.66957e+01]  predicted:  [ 0.03120246 -0.03160263 -9.21024037]
# test:  74  ground_truth:  [ 5.617e-01 -4.000e-04 -2.600e-02]  predicted:  [ 0.48615398 -0.00720003 -0.42048792]
# test:  75  ground_truth:  [-0.5182  0.0074 -1.4152]  predicted:  [-0.42466922  0.00799994 -1.95416424]
# test:  76  ground_truth:  [-0.2826 -0.0332 13.12  ]  predicted:  [-0.30555534 -0.05841664  5.94964045]
# test:  77  ground_truth:  [-0.4355 -0.1642     inf]  predicted:  [ 0.02840185 -0.07163057  6.50078904]
# test:  78  ground_truth:  [0.9306 0.0457 8.8501]  predicted:  [0.64684885 0.07203115 4.13181919]
# test:  79  ground_truth:  [ 1.9480e-01 -7.1000e-03 -8.5297e+00]  predicted:  [ 0.36644635 -0.04760902        -inf]
# test:  80  ground_truth:  [ -0.2593   0.0546 -29.3586]  predicted:  [-0.16759113  0.08925923 -3.10260328]
# test:  81  ground_truth:  [-0.5361  0.0316 -4.8484]  predicted:  [-0.57579821  0.02240084 -1.96432264]
# test:  82  ground_truth:  [-0.2538  0.0028 -0.6409]  predicted:  [-0.44899387 -0.00160003  0.39797069]
# test:  83  ground_truth:  [ 0.2952 -0.009  -2.931 ]  predicted:  [ 0.2631074   0.00239992 -0.37762436]
# test:  84  ground_truth:  [ -0.8592   0.3759 -52.2263]  predicted:  [-0.67043249  0.239133   -9.21024037]
# test:  85  ground_truth:  [ 0.7407 -0.0239 -4.2774]  predicted:  [0.46837897 0.01560028 0.15390306]
# test:  86  ground_truth:  [ 0.5624 -0.0112 -2.3289]  predicted:  [ 0.69509787  0.00399995 -1.96246987]
# test:  87  ground_truth:  [-1.0265 -0.0898 17.2411]  predicted:  [-0.6820676 -0.1446517        inf]
# test:  88  ground_truth:  [-0.2749  0.0078 -2.9193]  predicted:  [-0.31866963  0.01520019 -3.12966633]
# test:  89  ground_truth:  [ 0.334  -0.0006  0.0967]  predicted:  [ 0.09607379  0.00239992 -0.03320305]
# test:  90  ground_truth:  [-0.1573 -0.0431 32.6097]  predicted:  [-0.1812949  -0.00960012  2.03575198]
# test:  91  ground_truth:  [ 0.3044 -0.015  -2.9697]  predicted:  [0.25456594 0.00720003 0.04760899]
# test:  92  ground_truth:  [ -0.5306   0.0658 -11.5055]  predicted:  [-0.60237728  0.07924147 -7.41798072]
# test:  93  ground_truth:  [-0.7925 -0.134  15.5395]  predicted:  [-0.65928607 -0.10369284  6.50078904]
# test:  94  ground_truth:  [-1.097e-01 -1.000e-04  1.548e-01]  predicted:  [0.12295478 0.01720042 3.08572357]
# test:  95  ground_truth:  [-0.2271  0.0109 -6.1228]  predicted:  [-0.38259986  0.02440121 -2.69110962]
# test:  96  ground_truth:  [0.2886 0.0057 2.4549]  predicted:  [0.24684581 0.01400017 3.25353694]
# test:  97  ground_truth:  [ 0.4543 -0.0029 -0.9423]  predicted:  [ 0.47344988  0.02160085 -0.28021935]
# test:  98  ground_truth:  [0.2841 0.0104 1.7663]  predicted:  [0.37969695 0.06962822 5.19749201]
# test:  99  ground_truth:  [-0.2286 -0.0038  1.8546]  predicted:  [-0.13460287 -0.00440002  2.21738655]
# test:  100  ground_truth:  [0.2924 0.0096 2.4835]  predicted:  [ 0.36892831  0.00359989 -0.09567291]
# test:  101  ground_truth:  [0.4967 0.0129 3.2945]  predicted:  [0.45404266 0.01240007 1.10341806]
# test:  102  ground_truth:  [-0.0077 -0.0033     inf]  predicted:  [-0.08605303 -0.05721556         inf]
# test:  103  ground_truth:  [-0.6374 -0.1779 32.9082]  predicted:  [-0.48954825 -0.11572898         inf]
# test:  104  ground_truth:  [-9.90000e-03  1.80000e-03 -1.54683e+01]  predicted:  [-0.08324802  0.00399995        -inf]
# test:  105  ground_truth:  [-0.2841  0.0345 -7.9732]  predicted:  [-0.34704167  0.02720166 -3.29625176]
# test:  106  ground_truth:  [-5.324e-01 -1.000e-04 -1.525e-01]  predicted:  [-0.42425086  0.00079989 -0.09727664]
# test:  107  ground_truth:  [-0.9118 -0.0357  2.5109]  predicted:  [-0.7359061  -0.01520031  2.4234755 ]
# test:  108  ground_truth:  [-0.5199 -0.2494     inf]  predicted:  [-0.35735501 -0.12777351         inf]
# test:  109  ground_truth:  [0.2974 0.0141 5.268 ]  predicted:  [0.28838219 0.03960507 9.21024037]
# test:  110  ground_truth:  [ 9.0000e-04 -3.0000e-04 -5.9331e+00]  predicted:  [-1.64003472e-02  4.00066381e-04 -4.89884776e+00]
# test:  111  ground_truth:  [-0.3423 -0.0318  5.4977]  predicted:  [-0.32277345  0.00519992  1.22475923]
# test:  112  ground_truth:  [ 0.0276  0.     -0.0391]  predicted:  [0.01000007 0.01120007 0.45867583]
# test:  113  ground_truth:  [ 0.4755  0.0009 -0.8395]  predicted:  [ 5.21506623e-01  4.00066381e-04 -9.12443901e-01]
# test:  114  ground_truth:  [ -0.2475   0.0293 -13.384 ]  predicted:  [-0.05401315  0.         -4.08775726]
# test:  115  ground_truth:  [-4.384e-01  3.000e-04 -4.090e-01]  predicted:  [-0.49549475  0.01480034 -0.10168753]
# test:  116  ground_truth:  [0.2242 0.0019 1.1564]  predicted:  [ 2.57005331e-01 -3.99947172e-04  4.26761165e-01]
# test:  117  ground_truth:  [0.2526 0.0113 4.5163]  predicted:  [0.24725201 0.01720042 5.56894697]
# test:  118  ground_truth:  [-0.2301  0.0015 -0.8547]  predicted:  [-0.25497241  0.00720003 -0.59058779]
# test:  119  ground_truth:  [-0.532   0.0188 -2.8484]  predicted:  [-0.61684218  0.01360032 -1.75593646]
# test:  120  ground_truth:  [ -0.9052   0.227  -23.4266]  predicted:  [-0.91244387  0.1812949  -3.18852075]
# test:  121  ground_truth:  [1.0128 0.0167 4.4408]  predicted:  [0.75423151 0.02600149 2.00193413]
# test:  122  ground_truth:  [-1.47300e-01 -7.90000e-03  2.22637e+01]  predicted:  [-0.34869047 -0.10609937         inf]
# test:  123  ground_truth:  [ 0.      0.     17.4125]  predicted:  [-7.16305723e-02 -7.59998642e-03  9.21024037e+00]
# test:  124  ground_truth:  [ 0.4977 -0.0122 -4.3592]  predicted:  [ 4.17563325e-01 -8.00013585e-04 -8.64979674e-01]
# test:  125  ground_truth:  [2.316e-01 5.000e-04 8.048e-01]  predicted:  [ 0.24887678 -0.00479997  0.45530583]
# test:  126  ground_truth:  [-0.2387 -0.0038  1.7439]  predicted:  [-0.34415724  0.00119996  1.12545954]
# test:  127  ground_truth:  [ 1.138e-01 -3.000e-04 -3.163e-01]  predicted:  [-0.09126329  0.00519992 -0.74322192]
# test:  128  ground_truth:  [-0.5524  0.0212 -4.4308]  predicted:  [-0.34992753  0.00920016 -0.16034265]
# test:  129  ground_truth:  [-1.0358  0.0078 -0.4345]  predicted:  [-0.28062728  0.         -0.23264363]
# test:  130  ground_truth:  [0.5693 0.0079 2.7514]  predicted:  [0.43262378 0.02200096 3.09775389]
# test:  131  ground_truth:  [0.2307 0.0009 0.4386]  predicted:  [ 0.31415856 -0.01080011 -0.19703499]
# test:  132  ground_truth:  [-0.9279  0.0478 -4.3672]  predicted:  [-0.82879461 -0.00559999 -0.21765521]
# test:  133  ground_truth:  [-3.0300e-02 -2.5000e-03  6.8556e+00]  predicted:  [1.60002743e-03 2.88020016e-02 1.88251729e+00]
# test:  134  ground_truth:  [-0.4871 -0.0069  2.2733]  predicted:  [-0.55631727 -0.00520004  1.57926219]
# test:  135  ground_truth:  [-9.90000e-03  1.00000e-03 -1.07204e+01]  predicted:  [0.00279999 0.               -inf]
# test:  136  ground_truth:  [-1.20000e-03  1.00000e-04  1.44594e+01]  predicted:  [0.08645384 0.00679996        inf]
# test:  137  ground_truth:  [0.0389 0.013     inf]  predicted:  [0.07643724 0.03240273        inf]
# test:  138  ground_truth:  [-0.2524 -0.0272 12.8067]  predicted:  [-0.35364006 -0.06882713  9.21024037]
# test:  139  ground_truth:  [-0.2774 -0.0525 21.5063]  predicted:  [-4.44072729e-02 -6.00005996e-03  9.21024037e+00]
# test:  140  ground_truth:  [-1.18e+00  9.00e-04  4.00e-03]  predicted:  [-0.78473625  0.00480009 -1.35778828]
# test:  141  ground_truth:  [0.9599 0.0893 8.2624]  predicted:  [0.4654236  0.05401303 7.01221539]
# test:  142  ground_truth:  [ 8.00000e-04 -1.00000e-04 -1.55778e+01]  predicted:  [-0.0328029   0.00320006        -inf]
# test:  143  ground_truth:  [-0.2931 -0.0061  3.3163]  predicted:  [-0.13781767 -0.00840001  4.48057831]
# test:  144  ground_truth:  [-0.111  -0.0398 29.1369]  predicted:  [-0.16718837  0.03720426  4.48964811]
# test:  145  ground_truth:  [-0.5475  0.0767 -9.8551]  predicted:  [-0.61991849  0.10609937 -3.92289156]
# test:  146  ground_truth:  [ 0.22    0.0179 14.4308]  predicted:  [0.09888043 0.03760447 2.44643012]
# test:  147  ground_truth:  [ 0.2516 -0.0003 -0.2083]  predicted:  [0.239133   0.00279999 0.08725532]
# test:  148  ground_truth:  [ -0.564    0.2055 -44.2177]  predicted:  [-0.51936814  0.12897842        -inf]
# test:  149  ground_truth:  [-0.2459 -0.0007  0.3481]  predicted:  [-0.28919888 -0.00080001  0.10048447]
# test:  150  ground_truth:  [9.50000e-03 2.00000e-04 2.57534e+01]  predicted:  [0.27369591 0.09326752        inf]
# test:  151  ground_truth:  [-8.7000e-03  3.0000e-04 -7.0983e+00]  predicted:  [0.00279999 0.               -inf]
# test:  152  ground_truth:  [ 0.831  -0.0639 -7.1413]  predicted:  [ 0.4700687 -0.0360039       -inf]
# test:  153  ground_truth:  [ -1.0809   0.4406 -43.3316]  predicted:  [-0.95042176  0.22737445        -inf]
# test:  154  ground_truth:  [-0.4442  0.0037 -1.3179]  predicted:  [-0.37430995  0.00359989  0.05841661]
# test:  155  ground_truth:  [ -0.5417   0.0701 -21.8002]  predicted:  [-0.43094789  0.04840938        -inf]
# test:  156  ground_truth:  [  0.2311  -0.0458 -21.6908]  predicted:  [-0.03520364 -0.00160003        -inf]
# test:  157  ground_truth:  [ 0.2819 -0.001  -0.814 ]  predicted:  [0.32154196 0.00559999 0.90024574]
# test:  158  ground_truth:  [-0.9083 -0.008   1.321 ]  predicted:  [-0.77453     0.00640013  1.47423347]
# test:  159  ground_truth:  [-1.0586 -0.0172 -4.4571]  predicted:  [-0.80620397  0.01280015 -1.27267313]
# test:  160  ground_truth:  [0.5339 0.0179 5.9957]  predicted:  [0.37099762 0.00720003 1.62003531]
# test:  161  ground_truth:  [1.1360e-01 1.0000e-04 6.0693e+00]  predicted:  [5.36129110e-02 5.59999022e-03 7.26372998e+00]
# test:  162  ground_truth:  [  0.       0.     -17.7797]  predicted:  [ 2.39992257e-03  0.00000000e+00 -8.51699317e+00]
# test:  163  ground_truth:  [-4.8720e-01 -1.4000e-03  1.5998e+00]  predicted:  [-0.11412367 -0.00880009  4.60527119]
# test:  164  ground_truth:  [9.9000e-03 8.0000e-04 1.7278e+01]  predicted:  [0.18936394 0.0512111         inf]
# test:  165  ground_truth:  [  1.0638  -0.2522 -19.0286]  predicted:  [ 0.82548778 -0.11613039        -inf]
# test:  166  ground_truth:  [-4.38000e-02  5.70000e-03 -1.22966e+01]  predicted:  [-0.12134866  0.00880009        -inf]
# test:  167  ground_truth:  [ 1.1034 -0.0037 -0.3713]  predicted:  [ 0.72223957 -0.00399995 -0.36065921]
# test:  168  ground_truth:  [4.50000e-03 1.00000e-03 1.33572e+01]  predicted:  [-0.01240019 -0.00279999         inf]
# test:  169  ground_truth:  [-0.5048  0.0026 -0.2304]  predicted:  [-0.51509452  0.00160003 -0.4154752 ]
# test:  170  ground_truth:  [ 0.6722  0.0886 14.6912]  predicted:  [0.41672788 0.07483492 7.82364593]
# test:  171  ground_truth:  [0.2395 0.0037 1.2483]  predicted:  [-1.99997492e-03 -3.99947172e-04  6.55283066e-01]
# test:  172  ground_truth:  [-2.3040e-01  2.3000e-03 -2.3907e+00]  predicted:  [-0.26839978  0.00920016 -2.63531341]
# test:  173  ground_truth:  [-0.2894  0.0014 -0.4048]  predicted:  [ 0.17726272 -0.00360001 -0.33263346]
# test:  174  ground_truth:  [ -0.4562   0.0744 -20.4314]  predicted:  [-0.16195305  0.02560135        -inf]
# test:  175  ground_truth:  [-4.74000e-02 -2.70000e-03  1.05707e+01]  predicted:  [-0.11211729  0.0276018   0.85683992]
# test:  176  ground_truth:  [-0.8086 -0.1452 14.9063]  predicted:  [-0.75377184 -0.12335624  5.37708836]
# test:  177  ground_truth:  [ 0.2327 -0.0039 -1.9472]  predicted:  [ 0.29328425 -0.00119996 -0.6526172 ]
# test:  178  ground_truth:  [-8.1500e-02  6.0000e-03 -8.7195e+00]  predicted:  [-0.2602592   0.04840938 -9.21024037]
# test:  179  ground_truth:  [  1.1141  -0.4359 -30.3168]  predicted:  [-0.47937379 -0.12656869  0.16396637]
# test:  180  ground_truth:  [-5.7230e-01 -3.0000e-04 -3.7035e+00]  predicted:  [-0.49974748  0.01079999 -0.40713205]
# test:  181  ground_truth:  [ 5.00000e-04 -2.00000e-04 -2.61709e+01]  predicted:  [ 0.02920215 -0.00479997        -inf]
# test:  182  ground_truth:  [-5.09000e-02  4.40000e-03 -1.15555e+01]  predicted:  [-0.2018829   0.02600149        -inf]
# test:  183  ground_truth:  [3.67000e-02 3.50000e-03 1.02912e+01]  predicted:  [0.01120007 0.00160003        inf]
# test:  184  ground_truth:  [-8.2000e-03  3.0000e-04 -6.9774e+00]  predicted:  [0.00279999 0.               -inf]
# test:  185  ground_truth:  [0.9094 0.0179 2.3395]  predicted:  [0.58101108 0.02120074 0.35859384]
# test:  186  ground_truth:  [-1.7230e-01  5.0000e-04  1.2465e+00]  predicted:  [-0.22940074  0.00679996  0.85779614]
# test:  187  ground_truth:  [ 1.0531 -0.0169 -2.0234]  predicted:  [0.05081101 0.00720003 0.04600811]
# test:  188  ground_truth:  [-0.2727  0.016  -6.0854]  predicted:  [-0.31047006  0.01520019 -5.14408048]
# test:  189  ground_truth:  [-1.1964  0.0057 -1.8866]  predicted:  [-1.15926973  0.06842659 -2.90921313]
# test:  190  ground_truth:  [ -0.6087   0.2179 -33.5935]  predicted:  [-0.22818501  0.02440121 -3.09533723]
# test:  191  ground_truth:  [  1.0676  -0.4468 -32.4787]  predicted:  [-0.33551228 -0.10008348 -1.1875355 ]
# test:  192  ground_truth:  [0.2545 0.0027 1.1786]  predicted:  [0.04600812 0.         0.31620867]
# test:  193  ground_truth:  [-5.6200e-02  2.2000e-03 -6.2921e+00]  predicted:  [-0.09246578  0.00600006 -5.94964045]
# test:  194  ground_truth:  [4.00000e-03 2.10000e-03 2.80106e+01]  predicted:  [-0.07563607 -0.02200084         inf]
# test:  195  ground_truth:  [0.9119 0.0206 1.46  ]  predicted:  [ 0.8900475  -0.00240004 -0.61376864]
# test:  196  ground_truth:  [ 1.9000e-03 -8.0000e-04 -1.9739e+01]  predicted:  [-0.12014432  0.00840001        -inf]
# test:  197  ground_truth:  [-0.2681 -0.0057 -3.8602]  predicted:  [-0.09607379  0.01079999  0.50570889]
# test:  198  ground_truth:  [-0.5067 -0.0063  2.7353]  predicted:  [-0.44269081 -0.04961018  5.21594169]
# test:  199  ground_truth:  [-0.9674 -0.0402  4.8629]  predicted:  [-9.31107888e-01 -8.00013585e-04  2.11029729e+00]

# %%
t=range(nSamples)
plt.figure()
plt.subplot(311)
plt.plot(t, predict_list[:,0], color='orange')
plt.plot(t, inverse_sigmoid(y_pose_testing3[0:nSamples,0]), color='black',linestyle='--')
plt.ylabel('$\Delta x$')

plt.subplot(312)
plt.plot(t, predict_list[:,1], color='green')
plt.plot(t, inverse_sigmoid(y_pose_testing3[0:nSamples,1]), color='black',linestyle='--')
plt.ylabel('$\Delta y$')

plt.subplot(313)
plt.plot(t, predict_list[:,2], color='blue')
plt.plot(t,inverse_sigmoid(y_pose_testing3[0:nSamples,2]), color='black',linestyle='--')
plt.ylabel('$\Delta \Theta$')
#plt.legend(['predicted','ground_truth'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# errors
t=range(nSamples)
plt.figure()
plt.subplot(311)
plt.plot(t, predict_list[:,0]-y_testing_ground_truth3[0:nSamples,0], color='orange')
plt.ylabel('$\Delta x$')

plt.subplot(312)
plt.plot(t, predict_list[:,1]-y_testing_ground_truth3[0:nSamples,1], color='green')
plt.ylabel('$\Delta y$')

plt.subplot(313)
plt.plot(t, predict_list[:,2]-y_testing_ground_truth3[0:nSamples,2], color='blue')
plt.ylabel('$\Delta \Theta$')
#plt.legend(['predicted','ground_truth'])
plt.show()

# %% [markdown]
# ## with additional sensor noise

# %%
x_testing2_noise=x_testing2+np.random.normal(0,0.05,np.shape(x_testing2))
testing_dataset_noise = tf.data.Dataset.from_tensor_slices((x_testing2_noise, (y_testing2[:,0:2],y_testing2[:,2]))).batch(BATCH_SIZE)
model.evaluate(testing_dataset_noise)
# Out:
# 580/580 [==============================] - 3s 4ms/step - loss: 1.3098 - pose_loss: 0.0162 - rotation_loss: 22.9457 - pose_mean_absolute_error: 0.0630 - rotation_mean_absolute_error: 1.5229
# [1.309757947921753,
#  0.016247401013970375,
#  22.945676803588867,
#  0.0629737451672554,
#  1.5228794813156128]

# %% [markdown]
# ## Visualize feature map

# %%
# kernels in first conv layer
filters, biases = model.layers[1].get_weights()
print(np.shape(filters))
square = 8
ix = 1
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.plot(filters[:,0,ix-1])
		ix += 1
# show the figure
plt.show()
# Out:
# (7, 2, 64)

# %%
# define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)
# run our image through our network, thus obtaining all
# intermediate representations for this range data.
successive_feature_maps = visualization_model.predict(x_training[0:5])
# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers]
visualization_model = Model(inputs=model.inputs, outputs=model.layers[1].output)
feature_maps = visualization_model.predict(np.expand_dims(x_training[500], axis=0))
square = 8
ix = 1
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.plot(feature_maps[0, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## Odometry-based Localization

# %%
# !gdown --id 1Jq9xPARjAEY8DmJL0Q5uvFSOVHo-bwkf #simple wall
#!gdown --id 1IyOf-VK_8eqDl00seI36Eo_FIcThVqio #simple maze:
world_name = 'simple_wall'
local_zip = 'test_'+world_name+'.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('test_'+world_name)
zip_ref.close()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Jq9xPARjAEY8DmJL0Q5uvFSOVHo-bwkf
# To: /content/test_simple_wall.zip
# 100% 1.66M/1.66M [00:00<00:00, 110MB/s]

# %%
with open('test_'+world_name+'/test_simple_range_pairs_3.pickle', 'rb') as handle:
    test_simple_range_pairs = pickle.load(handle)

with open('test_'+world_name+'/test_simple_pose_rels_3.pickle', 'rb') as handle:
    test_simple_pose_rels = pickle.load(handle)
test_simple_range_pairs = np.swapaxes(test_simple_range_pairs, 1, 2)
test_simple_range_pairs = test_simple_range_pairs[:,::2,:]
test_simple_range_pairs = test_simple_range_pairs[:,90:451,:]
test_simple_translation_rels=test_simple_pose_rels[:,0:2]
test_simple_rotation_rels=test_simple_pose_rels[:,2]
print("size of range_pairs: ", test_simple_range_pairs.shape)
print("size of pose_rels: ", test_simple_translation_rels.shape)
print("size of rotation_rels: ", test_simple_rotation_rels.shape)
# Out:
# size of range_pairs:  (243, 361, 2)
# size of pose_rels:  (243, 2)
# size of rotation_rels:  (243,)

# %%
from matplotlib.animation import FuncAnimation
def rels_to_abs(pose_rels):
    pose_i = np.array([[0],[0]])
    poses = pose_i.T
    theta_i = 0.0
    for i in range(pose_rels.shape[0]):
        [rels_x,rels_y,rels_theta] = pose_rels[i,0:3]
        T_matrix = np.array([[np.cos(theta_i),-np.sin(theta_i)],[np.sin(theta_i),np.cos(theta_i)]])
        pose_ic =np.dot(T_matrix,np.array([[rels_x],[rels_y]]))+pose_i
        poses = np.concatenate((poses,pose_ic.T))
        pose_i = pose_ic
        if isinstance(rels_theta,np.ndarray):
          theta_i += rels_theta[0,0]
        else:
          theta_i += rels_theta
    return poses

dataSet = rels_to_abs(np.array(test_simple_pose_rels))
plt.plot(dataSet[:,0],dataSet[:,1], 'C3', lw=1)
plt.scatter(dataSet[:,0],dataSet[:,1], s=1)

# %%
from matplotlib.animation import FuncAnimation
test_pose_predict=model.predict(test_simple_range_pairs[0:-1,:])
predict_test_translation_value = np.array(test_pose_predict[0])
predict_test_rotation_value=np.expand_dims(np.array(tf.squeeze(test_pose_predict[1])), axis=1)*np.pi/180
predict_test_pose = np.concatenate((predict_test_translation_value,predict_test_rotation_value),axis=-1)
dataSet_estimate = rels_to_abs(np.array(predict_test_pose))
# dataSet_ground_truth = rels_to_abs(np.array(test_simple_pose_rels))
plt.plot(dataSet_estimate[:,0],dataSet_estimate[:,1], 'C3', lw=1)
plt.scatter(dataSet_estimate[:,0],dataSet_estimate[:,1], s=1)

# %% [markdown]
# compare ground-truth trajectory with predicted trajector

# %%
plt.plot(dataSet[:,0],dataSet[:,1], 'C3', lw=1)
plt.scatter(dataSet[:,0],dataSet[:,1], s=1)

plt.plot(dataSet_estimate[:,0],dataSet_estimate[:,1], 'C10', lw=1)
plt.scatter(dataSet_estimate[:,0],dataSet_estimate[:,1], s=1)

# %%
for i in range(100):
  predict_i=list(np.round(predict_test_translation_value[i],4))
  predict_i.append(np.round(np.float(predict_test_rotation_value[i]),4))
  if i%1==0:
    print("test: ", i, " ground_truth: ", np.round(np.double(test_simple_pose_rels[i,:]),4),
          " predicted: ",predict_i)
# Out:
# test:  0  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0078, 0.0002, 0.0006]
# test:  1  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0068, 0.0002, 0.0002]
# test:  2  ground_truth:  [0. 0. 0.]  predicted:  [-0.0066, 0.0002, 0.0005]
# test:  3  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0073, 0.0002, 0.0003]
# test:  4  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0093, 0.0003, 0.0006]
# test:  5  ground_truth:  [0. 0. 0.]  predicted:  [-0.0059, 0.0002, 0.0]
# test:  6  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0091, 0.0003, 0.0006]
# test:  7  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0085, 0.0003, 0.0005]
# test:  8  ground_truth:  [0. 0. 0.]  predicted:  [-0.0069, 0.0002, 0.0003]
# test:  9  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0083, 0.0002, 0.0005]
# test:  10  ground_truth:  [0. 0. 0.]  predicted:  [-0.0059, 0.0002, 0.0005]
# test:  11  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0069, 0.0002, 0.0006]
# test:  12  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0071, 0.0003, 0.0001]
# test:  13  ground_truth:  [0. 0. 0.]  predicted:  [-0.0073, 0.0002, 0.0006]
# test:  14  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0089, 0.0003, 0.0002]
# test:  15  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0081, 0.0003, 0.0]
# test:  16  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0076, 0.0002, 0.0008]
# test:  17  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0068, 0.0002, 0.0004]
# test:  18  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0066, 0.0002, 0.0003]
# test:  19  ground_truth:  [0. 0. 0.]  predicted:  [-0.0074, 0.0002, 0.0004]
# test:  20  ground_truth:  [-0. -0.  0.]  predicted:  [-0.008, 0.0003, 0.0002]
# test:  21  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0077, 0.0002, 0.0004]
# test:  22  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0068, 0.0002, 0.0003]
# test:  23  ground_truth:  [0. 0. 0.]  predicted:  [-0.0066, 0.0002, 0.0004]
# test:  24  ground_truth:  [-0.  0.  0.]  predicted:  [-0.0079, 0.0003, 0.0001]
# test:  25  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0072, 0.0002, 0.0007]
# test:  26  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0065, 0.0002, 0.0005]
# test:  27  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0081, 0.0003, 0.0004]
# test:  28  ground_truth:  [0. 0. 0.]  predicted:  [-0.0084, 0.0002, 0.0004]
# test:  29  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0069, 0.0002, 0.0001]
# test:  30  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0077, 0.0002, 0.0004]
# test:  31  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0088, 0.0003, 0.0004]
# test:  32  ground_truth:  [0. 0. 0.]  predicted:  [-0.0071, 0.0002, 0.0005]
# test:  33  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0085, 0.0003, 0.0005]
# test:  34  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0068, 0.0002, 0.0003]
# test:  35  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0064, 0.0002, 0.0002]
# test:  36  ground_truth:  [0. 0. 0.]  predicted:  [-0.0074, 0.0002, 0.0004]
# test:  37  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0081, 0.0003, 0.0007]
# test:  38  ground_truth:  [0. 0. 0.]  predicted:  [-0.0079, 0.0003, 0.0]
# test:  39  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0079, 0.0002, 0.0008]
# test:  40  ground_truth:  [ 0. -0.  0.]  predicted:  [-0.0063, 0.0002, -0.0003]
# test:  41  ground_truth:  [0. 0. 0.]  predicted:  [-0.0092, 0.0003, 0.0009]
# test:  42  ground_truth:  [ 0.0182 -0.0027 -0.3072]  predicted:  [-0.0029, 0.0006, -0.3177]
# test:  43  ground_truth:  [ 0.014  -0.0017 -0.2515]  predicted:  [-0.0039, 0.0007, -0.2226]
# test:  44  ground_truth:  [-0. -0.  0.]  predicted:  [-0.0062, 0.0005, -0.0022]
# test:  45  ground_truth:  [ 0.0275 -0.0045 -0.2918]  predicted:  [-0.0007, 0.0004, -0.315]
# test:  46  ground_truth:  [ 0.0321 -0.0042 -0.2798]  predicted:  [0.0027, 0.0003, -0.2526]
# test:  47  ground_truth:  [-0.      0.     -0.0003]  predicted:  [0.0011, 0.0005, -0.0686]
# test:  48  ground_truth:  [ 0.0347 -0.0069 -0.3357]  predicted:  [0.0058, 0.0004, -0.2851]
# test:  49  ground_truth:  [ 0.0448 -0.0076 -0.4093]  predicted:  [-0.0019, 0.0005, -0.3049]
# test:  50  ground_truth:  [ 0.0166 -0.0028 -0.3372]  predicted:  [-0.0003, 0.0004, -0.3284]
# test:  51  ground_truth:  [ 0.0383 -0.0071 -0.3401]  predicted:  [-0.0072, 0.001, -0.3129]
# test:  52  ground_truth:  [ 0.0607 -0.0121 -0.3602]  predicted:  [-0.0025, 0.0005, -0.301]
# test:  53  ground_truth:  [ 0.0955 -0.0174 -0.3613]  predicted:  [-0.002, 0.0006, -0.3619]
# test:  54  ground_truth:  [ 0.1278 -0.0239 -0.3485]  predicted:  [0.0107, 0.0002, -0.3343]
# test:  55  ground_truth:  [ 0.1633 -0.022  -0.239 ]  predicted:  [0.0174, 0.0005, -0.2645]
# test:  56  ground_truth:  [ 0.1888 -0.0178 -0.183 ]  predicted:  [0.2131, -0.0117, -0.1632]
# test:  57  ground_truth:  [ 0.1661 -0.009  -0.1165]  predicted:  [0.1796, -0.009, -0.1314]
# test:  58  ground_truth:  [ 0.2048 -0.0134 -0.1374]  predicted:  [0.1913, -0.011, -0.1321]
# test:  59  ground_truth:  [0.0133 0.0013 0.1355]  predicted:  [0.0032, 1e-04, 0.0874]
# test:  60  ground_truth:  [0.0288 0.0019 0.1174]  predicted:  [0.0071, 0.0003, 0.1006]
# test:  61  ground_truth:  [0.0446 0.0033 0.1367]  predicted:  [0.0051, 0.0006, 0.1371]
# test:  62  ground_truth:  [0.0905 0.0075 0.1554]  predicted:  [0.016, 0.0016, 0.135]
# test:  63  ground_truth:  [0.1189 0.0099 0.1556]  predicted:  [0.0819, 0.0059, 0.1526]
# test:  64  ground_truth:  [0.1337 0.0087 0.1303]  predicted:  [0.1355, 0.0087, 0.1526]
# test:  65  ground_truth:  [0.1632 0.012  0.142 ]  predicted:  [0.17, 0.0129, 0.1536]
# test:  66  ground_truth:  [0.1642 0.0099 0.1168]  predicted:  [0.1346, 0.0071, 0.1156]
# test:  67  ground_truth:  [0.1387 0.0021 0.03  ]  predicted:  [0.1561, 0.0042, 0.0477]
# test:  68  ground_truth:  [0.1631 0.0009 0.0054]  predicted:  [0.1683, -0.0007, 0.0068]
# test:  69  ground_truth:  [ 0.1566 -0.0004 -0.0077]  predicted:  [0.1178, -0.0024, -0.0018]
# test:  70  ground_truth:  [ 0.1578 -0.0018 -0.0237]  predicted:  [0.1384, -0.0034, -0.0247]
# test:  71  ground_truth:  [ 0.1648 -0.0066 -0.08  ]  predicted:  [0.1559, -0.0042, -0.0843]
# test:  72  ground_truth:  [ 0.1691 -0.0075 -0.0995]  predicted:  [0.1613, -0.0051, -0.1027]
# test:  73  ground_truth:  [ 0.195  -0.016  -0.1711]  predicted:  [0.2271, -0.0122, -0.1758]
# test:  74  ground_truth:  [ 0.1559 -0.0139 -0.275 ]  predicted:  [0.2193, -0.0172, -0.2561]
# test:  75  ground_truth:  [0.0035 0.     0.0104]  predicted:  [-0.0072, 0.0002, 0.0317]
# test:  76  ground_truth:  [0.0271 0.0019 0.14  ]  predicted:  [0.0015, 0.0002, 0.1446]
# test:  77  ground_truth:  [0.0027 0.     0.0199]  predicted:  [0.0101, -0.0005, 0.012]
# test:  78  ground_truth:  [0.0058 0.0001 0.0232]  predicted:  [0.0096, -0.0005, 0.0274]
# test:  79  ground_truth:  [0.0183 0.0008 0.1003]  predicted:  [0.0023, 0.0002, 0.0886]
# test:  80  ground_truth:  [0.     0.     0.1197]  predicted:  [-0.0005, 0.0004, 0.1111]
# test:  81  ground_truth:  [ 0.     -0.      0.1273]  predicted:  [-0.0005, 0.0004, 0.14]
# test:  82  ground_truth:  [0.0113 0.0006 0.0146]  predicted:  [-0.0024, 0.0004, -0.0054]
# test:  83  ground_truth:  [ 0.0539 -0.001  -0.004 ]  predicted:  [0.0398, -0.0009, -0.0071]
# test:  84  ground_truth:  [ 0.0771 -0.0036 -0.1428]  predicted:  [0.0811, -0.0019, -0.1031]
# test:  85  ground_truth:  [ 0.0927 -0.0148 -0.3172]  predicted:  [0.0548, -0.0097, -0.3918]
# test:  86  ground_truth:  [ 0.1196 -0.0191 -0.3123]  predicted:  [0.1337, -0.0175, -0.3207]
# test:  87  ground_truth:  [ 0.1606 -0.0236 -0.2727]  predicted:  [0.1151, -0.0099, -0.2939]
# test:  88  ground_truth:  [ 0.2104 -0.0389 -0.3556]  predicted:  [0.0763, -0.0133, -0.369]
# test:  89  ground_truth:  [ 0.1743 -0.0206 -0.2305]  predicted:  [0.1922, -0.0219, -0.2854]
# test:  90  ground_truth:  [ 0.2533 -0.0369 -0.2603]  predicted:  [0.1986, -0.0117, -0.2232]
# test:  91  ground_truth:  [ 0.1926 -0.0131 -0.123 ]  predicted:  [0.2015, -0.008, -0.1311]
# test:  92  ground_truth:  [ 0.1989 -0.0076 -0.0791]  predicted:  [0.2398, -0.0056, -0.0758]
# test:  93  ground_truth:  [ 0.0007 -0.      0.0166]  predicted:  [-0.0056, -0.0003, 0.0318]
# test:  94  ground_truth:  [-0.     -0.     -0.2302]  predicted:  [-0.0064, 0.0011, -0.2467]
# test:  95  ground_truth:  [-0.      0.     -0.3534]  predicted:  [0.0052, 0.002, -0.341]
# test:  96  ground_truth:  [ 0.     -0.     -0.3578]  predicted:  [-0.1073, 0.0278, -0.3708]
# test:  97  ground_truth:  [ 0.0064 -0.0018 -0.3263]  predicted:  [-0.033, 0.003, -0.3462]
# test:  98  ground_truth:  [ 0.0289 -0.0061 -0.3693]  predicted:  [-0.0215, 0.0024, -0.3745]
# test:  99  ground_truth:  [ 0.0555 -0.0104 -0.3461]  predicted:  [-0.0591, 0.0098, -0.3964]

# %% [markdown]
# # Section 5: Load Saved Model

# %%
model.save_weights('./model_weights_0404_361samples/base_model_weights', save_format='tf')
# !zip -r model_weights_0404_361samples.zip model_weights_0404_361samples/
# Out:
#   adding: model_weights_0404_361samples/ (stored 0%)
#   adding: model_weights_0404_361samples/base_model_weights.data-00000-of-00001 (deflated 34%)
#   adding: model_weights_0404_361samples/checkpoint (deflated 43%)
#   adding: model_weights_0404_361samples/base_model_weights.index (deflated 76%)

# %%
from google.colab import files
files.download('model_weights_0404_361samples.zip')
